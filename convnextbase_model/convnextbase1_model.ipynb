# %% [markdown]
# # Artificial Neural Networks and Deep Learning - Homework 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# - Team: Bio.log(y)
#
#
#
#
#
#
#
# - Members: Luca Lepore, Arianna Rigamonti, Michele Sala, Jacopo Libero Tettamanti
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## ConvNeXtBase on pre-processed data

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/[2024 - 2025] AN2DL/Homework 1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/[2024 - 2025] AN2DL/Homework 1

# %% [markdown]
# ### ⚙️ Import Libraries

# %%
# !pip uninstall -y tensorflow keras
# Out:
# Found existing installation: tensorflow 2.17.1
# Uninstalling tensorflow-2.17.1:
#   Successfully uninstalled tensorflow-2.17.1
# Found existing installation: keras 3.5.0
# Uninstalling keras-3.5.0:
#   Successfully uninstalled keras-3.5.0

# %%
# !pip install tensorflow==2.17.0 keras==3.4.1
# Out:
# Collecting tensorflow==2.17.0
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting keras==3.4.1
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.0) (0.45.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.4.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.4.1) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.4.1) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.0.2)
# Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.9 MB/s eta 0:00:00
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.5 MB/s eta 0:00:00
# Installing collected packages: keras, tensorflow
# Successfully installed keras-3.4.1 tensorflow-2.17.0

# %%
# !pip install keras-cv --upgrade
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.7)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.5)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.66.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 39.4 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 59.6 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np
import pandas as pd

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
import keras as tfk
from keras.layers import Input, Dense, Dropout, Lambda
from keras import layers as tfkl
import keras_cv.layers as cv_layers

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {tfk.__version__}")

# Import other libraries
import cv2
from keras.applications import ConvNeXtBase
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from PIL import Image
import matplotlib.gridspec as gridspec
import requests
from io import BytesIO
from sklearn.utils import resample, shuffle
from sklearn.utils.class_weight import compute_class_weight
from ipywidgets import interact, IntSlider, Dropdown
from tensorflow.keras.utils import to_categorical
import plotly.express as px
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# TensorFlow version: 2.17.0
# Keras version: 3.4.1

# %% [markdown]
# ## ⏳ Load Data

# %%
# Load your dataset
train_augmented = np.load('X_train_augmented_3x.npz')
X_train = train_augmented['images']
y_train = train_augmented['labels']

val_augmented = np.load('X_val_augmented_3x.npz')
X_val = val_augmented['images']
y_val = val_augmented['labels']

test = np.load('X_test.npz')
X_test = test['images']
y_test = test['labels']

test_augmented = np.load('X_test_augmented_4x.npz')
X_test_augmented = test_augmented['images']
y_test_augmented = test_augmented['labels']

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Save unique labels
unique_labels = list(labels.values())
print(f'Unique labels: {unique_labels}')
# Out:
# Unique labels: ['Basophil', 'Eosinophil', 'Erythroblast', 'Immature granulocytes', 'Lymphocyte', 'Monocyte', 'Neutrophil', 'Platelet']

# %%
# Check the shape of the loaded images
print(f"Loaded X_train images shape: {X_train.shape}")
print(f"Loaded y_train labels shape: {y_train.shape}")
print(f"Min value X_train: {X_train.min()}, Max value X_train: {X_train.max()}\n")

print(f"Loaded X_val images shape: {X_val.shape}")
print(f"Loaded y_val labels shape: {y_val.shape}")
print(f"Min value X_val: {X_val.min()}, Max value X_val: {X_val.max()}\n")

print(f"Loaded X_test images shape: {X_test.shape}")
print(f"Loaded y_test labels shape: {y_test.shape}")
print(f"Min value X_test: {X_test.min()}, Max value X_test: {X_test.max()}\n")

print(f"Loaded X_test_augmented images shape: {X_test_augmented.shape}")
print(f"Loaded y_test_augmented labels shape: {y_test_augmented.shape}")
print(f"Min value X_test_augmented: {X_test_augmented.min()}, Max value X_test_augmented: {X_test_augmented.max()}")
# Out:
# Loaded X_train images shape: (21513, 96, 96, 3)
# Loaded y_train labels shape: (21513, 8)
# Min value X_train: 0.0, Max value X_train: 255.0
#
# Loaded X_val images shape: (7173, 96, 96, 3)
# Loaded y_val labels shape: (7173, 8)
# Min value X_val: 0.0, Max value X_val: 255.0
#
# Loaded X_test images shape: (2391, 96, 96, 3)
# Loaded y_test labels shape: (2391, 8)
# Min value X_test: 0, Max value X_test: 255
#
# Loaded X_test_augmented images shape: (9564, 96, 96, 3)
# Loaded y_test_augmented labels shape: (9564, 8)
# Min value X_test_augmented: 0.0, Max value X_test_augmented: 255.0

# %% [markdown]
# ## 🔎 Inspect Data

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_train)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_train[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_train[idx])
    label = labels[label_index]

    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_val)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_val[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_val[idx])
    label = labels[label_index]
    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_test)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_test[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_test[idx])
    label = labels[label_index]
    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_test_augmented)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_test_augmented[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_test_augmented[idx])
    label = labels[label_index]
    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Class balancing

# %%
# Flatten the labels to class indices since they're in one-hot encoding
y_train_flat = np.argmax(y_train, axis=1)

# Calculate class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_flat),
    y=y_train_flat
)

# Convert the class weights to a dictionary
class_weight_dict = dict(enumerate(class_weights))

# Print the calculated class weights
print("Class weights:")
for class_index, weight in class_weight_dict.items():
    print(f"Class {class_index}: Weight {weight:.2f}")
# Out:
# Class weights:
# Class 0: Weight 1.75
# Class 1: Weight 0.69
# Class 2: Weight 1.38
# Class 3: Weight 0.74
# Class 4: Weight 1.76
# Class 5: Weight 1.50
# Class 6: Weight 0.64
# Class 7: Weight 0.91

# %% [markdown]
# ## 🧮 Define Network Parameters

# %%
# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %%
# Number of training epochs
epochs = 200

# Batch size for training
batch_size = 64

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
# Out:
# Epochs: 200
# Batch Size: 64

# %% [markdown]
# ## 🛠️ Transfer Learning
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img src="https://radekosmulski.com/content/images/2021/08/imagenet_banner.jpeg" width="700"/>

# %%
# Initialise ConvNeXtBase model with pretrained weights, for transfer learning

mymodel = tf.keras.applications.ConvNeXtBase(
        include_top = False,
        include_preprocessing = True,
        weights = "imagenet",
        input_shape = input_shape,
        pooling = "avg",
    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 ━━━━━━━━━━━━━━━━━━━━ 16s 0us/step

# %%
# Display a summary of the model architecture
mymodel.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(mymodel, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Freeze all layers in ConvNeXtBase to use it solely as a feature extractor
mymodel.trainable = False  # Freeze pretrained weights

# Define input layer with shape matching the input images
inputs = tfk.Input(shape=input_shape, name='input_layer')

# Pass inputs through the ConvNeXtBase feature extractor
x = mymodel(inputs)
print("Shape after ConvNeXtBase:", x.shape)

# Add a Dense layer without activation
x = tfkl.Dense(128, name='dense1')(x)
print("Shape after Dense1:", x.shape)

# Add Batch Normalization layer
x = tfkl.BatchNormalization(name='batch_norm1')(x)
print("Shape after BatchNorm1:", x.shape)

# Add Activation layer
x = tfkl.Activation('relu', name='activation1')(x)
print("Shape after Activation1:", x.shape)

# Add Dropout layer for regularization
x = tfkl.Dropout(0.3, name='dropout1')(x)
print("Shape after Dropout1:", x.shape)

# Add a final Dense layer for classification with softmax activation
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='output_layer')(x)
print("Shape after output_layer:", outputs.shape)

# Define the complete model linking input and output
tl_model1 = tfk.Model(inputs=inputs, outputs=outputs, name='model1')

# Compile the model with categorical cross-entropy loss and Adam optimiser
tl_model1.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])  # default learning rate = 0.001
# Out:
# Shape after ConvNeXtBase: (None, 1024)
# Shape after Dense1: (None, 128)
# Shape after BatchNorm1: (None, 128)
# Shape after Activation1: (None, 128)
# Shape after Dropout1: (None, 128)
# Shape after output_layer: (None, 8)

# %%
# Display a summary of the model architecture
tl_model1.summary()

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(tl_model1, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Define the EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',       # Metric to monitor
    mode='max',                   # Mode ('max' for accuracy)
    patience=20,                  # Number of epochs with no improvement before stopping
    restore_best_weights=True     # Restore the model weights from the epoch with the best value of the monitored metric
)

# %%
# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',           # Metric to monitor
    factor=0.5,                   # Factor by which the learning rate will be reduced
    patience=5,                   # Number of epochs with no improvement before reducing learning rate
    verbose=1,                    # Verbosity mode (0 = silent, 1 = updates messages)
    min_lr=1e-6                   # Lower bound on the learning rate
)

# %%
# Train the model
tl_history1 = tl_model1.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy= round(max(tl_history1['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = f'ConvNeXtBase1_{final_val_accuracy}.keras'
tl_model1.save(model_filename)

# Free memory by deleting the model instance
del tl_model1
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 72s 128ms/step - accuracy: 0.5015 - loss: 1.4398 - val_accuracy: 0.7157 - val_loss: 0.8025 - learning_rate: 0.0010
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7016 - loss: 0.8646 - val_accuracy: 0.7439 - val_loss: 0.7391 - learning_rate: 0.0010
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7384 - loss: 0.7543 - val_accuracy: 0.7461 - val_loss: 0.7182 - learning_rate: 0.0010
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7582 - loss: 0.6799 - val_accuracy: 0.7510 - val_loss: 0.7188 - learning_rate: 0.0010
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7782 - loss: 0.6240 - val_accuracy: 0.7530 - val_loss: 0.7113 - learning_rate: 0.0010
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7938 - loss: 0.5731 - val_accuracy: 0.7548 - val_loss: 0.7102 - learning_rate: 0.0010
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8047 - loss: 0.5306 - val_accuracy: 0.7573 - val_loss: 0.7154 - learning_rate: 0.0010
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8225 - loss: 0.4928 - val_accuracy: 0.7553 - val_loss: 0.7238 - learning_rate: 0.0010
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8331 - loss: 0.4519 - val_accuracy: 0.7584 - val_loss: 0.7243 - learning_rate: 0.0010
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8423 - loss: 0.4224 - val_accuracy: 0.7581 - val_loss: 0.7559 - learning_rate: 0.0010
# Epoch 11/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8486 - loss: 0.3991
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8487 - loss: 0.3991 - val_accuracy: 0.7627 - val_loss: 0.7547 - learning_rate: 0.0010
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8615 - loss: 0.3576 - val_accuracy: 0.7659 - val_loss: 0.7238 - learning_rate: 5.0000e-04
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8867 - loss: 0.3033 - val_accuracy: 0.7691 - val_loss: 0.7378 - learning_rate: 5.0000e-04
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8891 - loss: 0.2903 - val_accuracy: 0.7631 - val_loss: 0.7618 - learning_rate: 5.0000e-04
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8947 - loss: 0.2747 - val_accuracy: 0.7691 - val_loss: 0.7637 - learning_rate: 5.0000e-04
# Epoch 16/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9032 - loss: 0.2610
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9033 - loss: 0.2609 - val_accuracy: 0.7645 - val_loss: 0.7881 - learning_rate: 5.0000e-04
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9069 - loss: 0.2392 - val_accuracy: 0.7711 - val_loss: 0.7735 - learning_rate: 2.5000e-04
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9173 - loss: 0.2183 - val_accuracy: 0.7707 - val_loss: 0.7832 - learning_rate: 2.5000e-04
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9196 - loss: 0.2110 - val_accuracy: 0.7732 - val_loss: 0.7819 - learning_rate: 2.5000e-04
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9241 - loss: 0.2041 - val_accuracy: 0.7719 - val_loss: 0.7874 - learning_rate: 2.5000e-04
# Epoch 21/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9241 - loss: 0.1984
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9242 - loss: 0.1984 - val_accuracy: 0.7751 - val_loss: 0.7992 - learning_rate: 2.5000e-04
# Epoch 22/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9298 - loss: 0.1875 - val_accuracy: 0.7737 - val_loss: 0.8015 - learning_rate: 1.2500e-04
# Epoch 23/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9310 - loss: 0.1813 - val_accuracy: 0.7767 - val_loss: 0.7965 - learning_rate: 1.2500e-04
# Epoch 24/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9363 - loss: 0.1710 - val_accuracy: 0.7732 - val_loss: 0.8091 - learning_rate: 1.2500e-04
# Epoch 25/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9365 - loss: 0.1648 - val_accuracy: 0.7743 - val_loss: 0.8120 - learning_rate: 1.2500e-04
# Epoch 26/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9361 - loss: 0.1634
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9361 - loss: 0.1634 - val_accuracy: 0.7725 - val_loss: 0.8172 - learning_rate: 1.2500e-04
# Epoch 27/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9423 - loss: 0.1568 - val_accuracy: 0.7742 - val_loss: 0.8178 - learning_rate: 6.2500e-05
# Epoch 28/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9480 - loss: 0.1482 - val_accuracy: 0.7753 - val_loss: 0.8196 - learning_rate: 6.2500e-05
# Epoch 29/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9437 - loss: 0.1501 - val_accuracy: 0.7746 - val_loss: 0.8239 - learning_rate: 6.2500e-05
# Epoch 30/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9452 - loss: 0.1492 - val_accuracy: 0.7749 - val_loss: 0.8275 - learning_rate: 6.2500e-05
# Epoch 31/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9463 - loss: 0.1470
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9463 - loss: 0.1469 - val_accuracy: 0.7753 - val_loss: 0.8278 - learning_rate: 6.2500e-05
# Epoch 32/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9503 - loss: 0.1434 - val_accuracy: 0.7771 - val_loss: 0.8287 - learning_rate: 3.1250e-05
# Epoch 33/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9464 - loss: 0.1424 - val_accuracy: 0.7762 - val_loss: 0.8322 - learning_rate: 3.1250e-05
# Epoch 34/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9469 - loss: 0.1455 - val_accuracy: 0.7757 - val_loss: 0.8336 - learning_rate: 3.1250e-05
# Epoch 35/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9469 - loss: 0.1380 - val_accuracy: 0.7755 - val_loss: 0.8337 - learning_rate: 3.1250e-05
# Epoch 36/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9488 - loss: 0.1379
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9488 - loss: 0.1379 - val_accuracy: 0.7765 - val_loss: 0.8366 - learning_rate: 3.1250e-05
# Epoch 37/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9489 - loss: 0.1373 - val_accuracy: 0.7764 - val_loss: 0.8370 - learning_rate: 1.5625e-05
# Epoch 38/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9492 - loss: 0.1383 - val_accuracy: 0.7760 - val_loss: 0.8379 - learning_rate: 1.5625e-05
# Epoch 39/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9479 - loss: 0.1373 - val_accuracy: 0.7762 - val_loss: 0.8393 - learning_rate: 1.5625e-05
# Epoch 40/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9517 - loss: 0.1318 - val_accuracy: 0.7774 - val_loss: 0.8403 - learning_rate: 1.5625e-05
# Epoch 41/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9523 - loss: 0.1350
# Epoch 41: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9523 - loss: 0.1350 - val_accuracy: 0.7755 - val_loss: 0.8410 - learning_rate: 1.5625e-05
# Epoch 42/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9493 - loss: 0.1343 - val_accuracy: 0.7765 - val_loss: 0.8418 - learning_rate: 7.8125e-06
# Epoch 43/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9476 - loss: 0.1373 - val_accuracy: 0.7767 - val_loss: 0.8421 - learning_rate: 7.8125e-06
# Epoch 44/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9495 - loss: 0.1326 - val_accuracy: 0.7768 - val_loss: 0.8425 - learning_rate: 7.8125e-06
# Epoch 45/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9508 - loss: 0.1349 - val_accuracy: 0.7776 - val_loss: 0.8428 - learning_rate: 7.8125e-06
# Epoch 46/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9517 - loss: 0.1325
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9517 - loss: 0.1325 - val_accuracy: 0.7769 - val_loss: 0.8429 - learning_rate: 7.8125e-06
# Epoch 47/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9523 - loss: 0.1317 - val_accuracy: 0.7774 - val_loss: 0.8430 - learning_rate: 3.9063e-06
# Epoch 48/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9509 - loss: 0.1322 - val_accuracy: 0.7778 - val_loss: 0.8434 - learning_rate: 3.9063e-06
# Epoch 49/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9522 - loss: 0.1307 - val_accuracy: 0.7778 - val_loss: 0.8437 - learning_rate: 3.9063e-06
# Epoch 50/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9498 - loss: 0.1353 - val_accuracy: 0.7776 - val_loss: 0.8438 - learning_rate: 3.9063e-06
# Epoch 51/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9549 - loss: 0.1268
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9549 - loss: 0.1268 - val_accuracy: 0.7772 - val_loss: 0.8440 - learning_rate: 3.9063e-06
# Epoch 52/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9507 - loss: 0.1336 - val_accuracy: 0.7776 - val_loss: 0.8444 - learning_rate: 1.9531e-06
# Epoch 53/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9525 - loss: 0.1289 - val_accuracy: 0.7772 - val_loss: 0.8443 - learning_rate: 1.9531e-06
# Epoch 54/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9522 - loss: 0.1325 - val_accuracy: 0.7776 - val_loss: 0.8442 - learning_rate: 1.9531e-06
# Epoch 55/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9508 - loss: 0.1344 - val_accuracy: 0.7779 - val_loss: 0.8444 - learning_rate: 1.9531e-06
# Epoch 56/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9553 - loss: 0.1254
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9553 - loss: 0.1254 - val_accuracy: 0.7775 - val_loss: 0.8445 - learning_rate: 1.9531e-06
# Epoch 57/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9517 - loss: 0.1336 - val_accuracy: 0.7775 - val_loss: 0.8445 - learning_rate: 1.0000e-06
# Epoch 58/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9526 - loss: 0.1311 - val_accuracy: 0.7775 - val_loss: 0.8446 - learning_rate: 1.0000e-06
# Epoch 59/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9515 - loss: 0.1322 - val_accuracy: 0.7774 - val_loss: 0.8447 - learning_rate: 1.0000e-06
# Epoch 60/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9528 - loss: 0.1325 - val_accuracy: 0.7776 - val_loss: 0.8448 - learning_rate: 1.0000e-06
# Epoch 61/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9511 - loss: 0.1329 - val_accuracy: 0.7774 - val_loss: 0.8448 - learning_rate: 1.0000e-06
# Epoch 62/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9537 - loss: 0.1282 - val_accuracy: 0.7774 - val_loss: 0.8448 - learning_rate: 1.0000e-06
# Epoch 63/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9523 - loss: 0.1275 - val_accuracy: 0.7774 - val_loss: 0.8449 - learning_rate: 1.0000e-06
# Epoch 64/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9491 - loss: 0.1367 - val_accuracy: 0.7775 - val_loss: 0.8449 - learning_rate: 1.0000e-06
# Epoch 65/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9499 - loss: 0.1347 - val_accuracy: 0.7778 - val_loss: 0.8450 - learning_rate: 1.0000e-06
# Epoch 66/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9495 - loss: 0.1342 - val_accuracy: 0.7779 - val_loss: 0.8450 - learning_rate: 1.0000e-06
# Epoch 67/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9509 - loss: 0.1319 - val_accuracy: 0.7779 - val_loss: 0.8450 - learning_rate: 1.0000e-06
# Epoch 68/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9527 - loss: 0.1315 - val_accuracy: 0.7778 - val_loss: 0.8451 - learning_rate: 1.0000e-06
# Epoch 69/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9528 - loss: 0.1306 - val_accuracy: 0.7774 - val_loss: 0.8451 - learning_rate: 1.0000e-06
# Epoch 70/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9528 - loss: 0.1297 - val_accuracy: 0.7774 - val_loss: 0.8453 - learning_rate: 1.0000e-06
# Epoch 71/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9510 - loss: 0.1349 - val_accuracy: 0.7772 - val_loss: 0.8452 - learning_rate: 1.0000e-06
# Epoch 72/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9492 - loss: 0.1353 - val_accuracy: 0.7774 - val_loss: 0.8453 - learning_rate: 1.0000e-06
# Epoch 73/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9487 - loss: 0.1365 - val_accuracy: 0.7772 - val_loss: 0.8453 - learning_rate: 1.0000e-06
# Epoch 74/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9534 - loss: 0.1307 - val_accuracy: 0.7771 - val_loss: 0.8453 - learning_rate: 1.0000e-06
# Epoch 75/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9524 - loss: 0.1313 - val_accuracy: 0.7771 - val_loss: 0.8454 - learning_rate: 1.0000e-06
# Final validation accuracy: 77.79%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(tl_history1['loss'], label='Training loss', alpha=.8)
plt.plot(tl_history1['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss before fine tuning')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(tl_history1['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(tl_history1['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy before fine tuning')
plt.legend()
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# ## 🛠️ Fine Tuning
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img src="https://www.researchgate.net/publication/359405075/figure/fig2/AS:1182999492214798@1659060466845/Concept-of-fine-tuning-and-feature-extraction_W640.jpg" width="700"/>

# %% [markdown]
# ### Initial Fine tuning

# %%
# Re-load the model after transfer learning
ft_model1 = tfk.models.load_model('ConvNeXtBase1_77.79.keras')

# %%
# Unfreeze the layers in the last two stages
trainable = False

for layer in ft_model1.get_layer('convnext_base').layers:
    if "stage_2" in layer.name or "stage_3" in layer.name:
        trainable = True
    layer.trainable = trainable

# Set the BatchNorm layers as non-trainable
for layer in ft_model1.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False


# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model1.get_layer('convnext_base').layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_layer False
# 1 convnext_base_prestem_normalization False
# 2 convnext_base_stem False
# 3 convnext_base_stage_0_block_0_depthwise_conv False
# 4 convnext_base_stage_0_block_0_layernorm False
# 5 convnext_base_stage_0_block_0_pointwise_conv_1 False
# 6 convnext_base_stage_0_block_0_gelu False
# 7 convnext_base_stage_0_block_0_pointwise_conv_2 False
# 8 convnext_base_stage_0_block_0_layer_scale False
# 9 convnext_base_stage_0_block_0_identity False
# 10 convnext_base_stage_0_block_1_depthwise_conv False
# 11 convnext_base_stage_0_block_1_layernorm False
# 12 convnext_base_stage_0_block_1_pointwise_conv_1 False
# 13 convnext_base_stage_0_block_1_gelu False
# 14 convnext_base_stage_0_block_1_pointwise_conv_2 False
# 15 convnext_base_stage_0_block_1_layer_scale False
# 16 convnext_base_stage_0_block_1_identity False
# 17 convnext_base_stage_0_block_2_depthwise_conv False
# 18 convnext_base_stage_0_block_2_layernorm False
# 19 convnext_base_stage_0_block_2_pointwise_conv_1 False
# 20 convnext_base_stage_0_block_2_gelu False
# 21 convnext_base_stage_0_block_2_pointwise_conv_2 False
# 22 convnext_base_stage_0_block_2_layer_scale False
# 23 convnext_base_stage_0_block_2_identity False
# 24 convnext_base_downsampling_block_0 False
# 25 convnext_base_stage_1_block_0_depthwise_conv False
# 26 convnext_base_stage_1_block_0_layernorm False
# 27 convnext_base_stage_1_block_0_pointwise_conv_1 False
# 28 convnext_base_stage_1_block_0_gelu False
# 29 convnext_base_stage_1_block_0_pointwise_conv_2 False
# 30 convnext_base_stage_1_block_0_layer_scale False
# 31 convnext_base_stage_1_block_0_identity False
# 32 convnext_base_stage_1_block_1_depthwise_conv False
# 33 convnext_base_stage_1_block_1_layernorm False
# 34 convnext_base_stage_1_block_1_pointwise_conv_1 False
# 35 convnext_base_stage_1_block_1_gelu False
# 36 convnext_base_stage_1_block_1_pointwise_conv_2 False
# 37 convnext_base_stage_1_block_1_layer_scale False
# 38 convnext_base_stage_1_block_1_identity False
# 39 convnext_base_stage_1_block_2_depthwise_conv False
# 40 convnext_base_stage_1_block_2_layernorm False
# 41 convnext_base_stage_1_block_2_pointwise_conv_1 False
# 42 convnext_base_stage_1_block_2_gelu False
# 43 convnext_base_stage_1_block_2_pointwise_conv_2 False
# 44 convnext_base_stage_1_block_2_layer_scale False
# 45 convnext_base_stage_1_block_2_identity False
# 46 convnext_base_downsampling_block_1 False
# 47 convnext_base_stage_2_block_0_depthwise_conv True
# 48 convnext_base_stage_2_block_0_layernorm False
# 49 convnext_base_stage_2_block_0_pointwise_conv_1 True
# 50 convnext_base_stage_2_block_0_gelu True
# 51 convnext_base_stage_2_block_0_pointwise_conv_2 True
# 52 convnext_base_stage_2_block_0_layer_scale True
# 53 convnext_base_stage_2_block_0_identity True
# 54 convnext_base_stage_2_block_1_depthwise_conv True
# 55 convnext_base_stage_2_block_1_layernorm False
# 56 convnext_base_stage_2_block_1_pointwise_conv_1 True
# 57 convnext_base_stage_2_block_1_gelu True
# 58 convnext_base_stage_2_block_1_pointwise_conv_2 True
# 59 convnext_base_stage_2_block_1_layer_scale True
# 60 convnext_base_stage_2_block_1_identity True
# 61 convnext_base_stage_2_block_2_depthwise_conv True
# 62 convnext_base_stage_2_block_2_layernorm False
# 63 convnext_base_stage_2_block_2_pointwise_conv_1 True
# 64 convnext_base_stage_2_block_2_gelu True
# 65 convnext_base_stage_2_block_2_pointwise_conv_2 True
# 66 convnext_base_stage_2_block_2_layer_scale True
# 67 convnext_base_stage_2_block_2_identity True
# 68 convnext_base_stage_2_block_3_depthwise_conv True
# 69 convnext_base_stage_2_block_3_layernorm False
# 70 convnext_base_stage_2_block_3_pointwise_conv_1 True
# 71 convnext_base_stage_2_block_3_gelu True
# 72 convnext_base_stage_2_block_3_pointwise_conv_2 True
# 73 convnext_base_stage_2_block_3_layer_scale True
# 74 convnext_base_stage_2_block_3_identity True
# 75 convnext_base_stage_2_block_4_depthwise_conv True
# 76 convnext_base_stage_2_block_4_layernorm False
# 77 convnext_base_stage_2_block_4_pointwise_conv_1 True
# 78 convnext_base_stage_2_block_4_gelu True
# 79 convnext_base_stage_2_block_4_pointwise_conv_2 True
# 80 convnext_base_stage_2_block_4_layer_scale True
# 81 convnext_base_stage_2_block_4_identity True
# 82 convnext_base_stage_2_block_5_depthwise_conv True
# 83 convnext_base_stage_2_block_5_layernorm False
# 84 convnext_base_stage_2_block_5_pointwise_conv_1 True
# 85 convnext_base_stage_2_block_5_gelu True
# 86 convnext_base_stage_2_block_5_pointwise_conv_2 True
# 87 convnext_base_stage_2_block_5_layer_scale True
# 88 convnext_base_stage_2_block_5_identity True
# 89 convnext_base_stage_2_block_6_depthwise_conv True
# 90 convnext_base_stage_2_block_6_layernorm False
# 91 convnext_base_stage_2_block_6_pointwise_conv_1 True
# 92 convnext_base_stage_2_block_6_gelu True
# 93 convnext_base_stage_2_block_6_pointwise_conv_2 True
# 94 convnext_base_stage_2_block_6_layer_scale True
# 95 convnext_base_stage_2_block_6_identity True
# 96 convnext_base_stage_2_block_7_depthwise_conv True
# 97 convnext_base_stage_2_block_7_layernorm False
# 98 convnext_base_stage_2_block_7_pointwise_conv_1 True
# 99 convnext_base_stage_2_block_7_gelu True
# 100 convnext_base_stage_2_block_7_pointwise_conv_2 True
# 101 convnext_base_stage_2_block_7_layer_scale True
# 102 convnext_base_stage_2_block_7_identity True
# 103 convnext_base_stage_2_block_8_depthwise_conv True
# 104 convnext_base_stage_2_block_8_layernorm False
# 105 convnext_base_stage_2_block_8_pointwise_conv_1 True
# 106 convnext_base_stage_2_block_8_gelu True
# 107 convnext_base_stage_2_block_8_pointwise_conv_2 True
# 108 convnext_base_stage_2_block_8_layer_scale True
# 109 convnext_base_stage_2_block_8_identity True
# 110 convnext_base_stage_2_block_9_depthwise_conv True
# 111 convnext_base_stage_2_block_9_layernorm False
# 112 convnext_base_stage_2_block_9_pointwise_conv_1 True
# 113 convnext_base_stage_2_block_9_gelu True
# 114 convnext_base_stage_2_block_9_pointwise_conv_2 True
# 115 convnext_base_stage_2_block_9_layer_scale True
# 116 convnext_base_stage_2_block_9_identity True
# 117 convnext_base_stage_2_block_10_depthwise_conv True
# 118 convnext_base_stage_2_block_10_layernorm False
# 119 convnext_base_stage_2_block_10_pointwise_conv_1 True
# 120 convnext_base_stage_2_block_10_gelu True
# 121 convnext_base_stage_2_block_10_pointwise_conv_2 True
# 122 convnext_base_stage_2_block_10_layer_scale True
# 123 convnext_base_stage_2_block_10_identity True
# 124 convnext_base_stage_2_block_11_depthwise_conv True
# 125 convnext_base_stage_2_block_11_layernorm False
# 126 convnext_base_stage_2_block_11_pointwise_conv_1 True
# 127 convnext_base_stage_2_block_11_gelu True
# 128 convnext_base_stage_2_block_11_pointwise_conv_2 True
# 129 convnext_base_stage_2_block_11_layer_scale True
# 130 convnext_base_stage_2_block_11_identity True
# 131 convnext_base_stage_2_block_12_depthwise_conv True
# 132 convnext_base_stage_2_block_12_layernorm False
# 133 convnext_base_stage_2_block_12_pointwise_conv_1 True
# 134 convnext_base_stage_2_block_12_gelu True
# 135 convnext_base_stage_2_block_12_pointwise_conv_2 True
# 136 convnext_base_stage_2_block_12_layer_scale True
# 137 convnext_base_stage_2_block_12_identity True
# 138 convnext_base_stage_2_block_13_depthwise_conv True
# 139 convnext_base_stage_2_block_13_layernorm False
# 140 convnext_base_stage_2_block_13_pointwise_conv_1 True
# 141 convnext_base_stage_2_block_13_gelu True
# 142 convnext_base_stage_2_block_13_pointwise_conv_2 True
# 143 convnext_base_stage_2_block_13_layer_scale True
# 144 convnext_base_stage_2_block_13_identity True
# 145 convnext_base_stage_2_block_14_depthwise_conv True
# 146 convnext_base_stage_2_block_14_layernorm False
# 147 convnext_base_stage_2_block_14_pointwise_conv_1 True
# 148 convnext_base_stage_2_block_14_gelu True
# 149 convnext_base_stage_2_block_14_pointwise_conv_2 True
# 150 convnext_base_stage_2_block_14_layer_scale True
# 151 convnext_base_stage_2_block_14_identity True
# 152 convnext_base_stage_2_block_15_depthwise_conv True
# 153 convnext_base_stage_2_block_15_layernorm False
# 154 convnext_base_stage_2_block_15_pointwise_conv_1 True
# 155 convnext_base_stage_2_block_15_gelu True
# 156 convnext_base_stage_2_block_15_pointwise_conv_2 True
# 157 convnext_base_stage_2_block_15_layer_scale True
# 158 convnext_base_stage_2_block_15_identity True
# 159 convnext_base_stage_2_block_16_depthwise_conv True
# 160 convnext_base_stage_2_block_16_layernorm False
# 161 convnext_base_stage_2_block_16_pointwise_conv_1 True
# 162 convnext_base_stage_2_block_16_gelu True
# 163 convnext_base_stage_2_block_16_pointwise_conv_2 True
# 164 convnext_base_stage_2_block_16_layer_scale True
# 165 convnext_base_stage_2_block_16_identity True
# 166 convnext_base_stage_2_block_17_depthwise_conv True
# 167 convnext_base_stage_2_block_17_layernorm False
# 168 convnext_base_stage_2_block_17_pointwise_conv_1 True
# 169 convnext_base_stage_2_block_17_gelu True
# 170 convnext_base_stage_2_block_17_pointwise_conv_2 True
# 171 convnext_base_stage_2_block_17_layer_scale True
# 172 convnext_base_stage_2_block_17_identity True
# 173 convnext_base_stage_2_block_18_depthwise_conv True
# 174 convnext_base_stage_2_block_18_layernorm False
# 175 convnext_base_stage_2_block_18_pointwise_conv_1 True
# 176 convnext_base_stage_2_block_18_gelu True
# 177 convnext_base_stage_2_block_18_pointwise_conv_2 True
# 178 convnext_base_stage_2_block_18_layer_scale True
# 179 convnext_base_stage_2_block_18_identity True
# 180 convnext_base_stage_2_block_19_depthwise_conv True
# 181 convnext_base_stage_2_block_19_layernorm False
# 182 convnext_base_stage_2_block_19_pointwise_conv_1 True
# 183 convnext_base_stage_2_block_19_gelu True
# 184 convnext_base_stage_2_block_19_pointwise_conv_2 True
# 185 convnext_base_stage_2_block_19_layer_scale True
# 186 convnext_base_stage_2_block_19_identity True
# 187 convnext_base_stage_2_block_20_depthwise_conv True
# 188 convnext_base_stage_2_block_20_layernorm False
# 189 convnext_base_stage_2_block_20_pointwise_conv_1 True
# 190 convnext_base_stage_2_block_20_gelu True
# 191 convnext_base_stage_2_block_20_pointwise_conv_2 True
# 192 convnext_base_stage_2_block_20_layer_scale True
# 193 convnext_base_stage_2_block_20_identity True
# 194 convnext_base_stage_2_block_21_depthwise_conv True
# 195 convnext_base_stage_2_block_21_layernorm False
# 196 convnext_base_stage_2_block_21_pointwise_conv_1 True
# 197 convnext_base_stage_2_block_21_gelu True
# 198 convnext_base_stage_2_block_21_pointwise_conv_2 True
# 199 convnext_base_stage_2_block_21_layer_scale True
# 200 convnext_base_stage_2_block_21_identity True
# 201 convnext_base_stage_2_block_22_depthwise_conv True
# 202 convnext_base_stage_2_block_22_layernorm False
# 203 convnext_base_stage_2_block_22_pointwise_conv_1 True
# 204 convnext_base_stage_2_block_22_gelu True
# 205 convnext_base_stage_2_block_22_pointwise_conv_2 True
# 206 convnext_base_stage_2_block_22_layer_scale True
# 207 convnext_base_stage_2_block_22_identity True
# 208 convnext_base_stage_2_block_23_depthwise_conv True
# 209 convnext_base_stage_2_block_23_layernorm False
# 210 convnext_base_stage_2_block_23_pointwise_conv_1 True
# 211 convnext_base_stage_2_block_23_gelu True
# 212 convnext_base_stage_2_block_23_pointwise_conv_2 True
# 213 convnext_base_stage_2_block_23_layer_scale True
# 214 convnext_base_stage_2_block_23_identity True
# 215 convnext_base_stage_2_block_24_depthwise_conv True
# 216 convnext_base_stage_2_block_24_layernorm False
# 217 convnext_base_stage_2_block_24_pointwise_conv_1 True
# 218 convnext_base_stage_2_block_24_gelu True
# 219 convnext_base_stage_2_block_24_pointwise_conv_2 True
# 220 convnext_base_stage_2_block_24_layer_scale True
# 221 convnext_base_stage_2_block_24_identity True
# 222 convnext_base_stage_2_block_25_depthwise_conv True
# 223 convnext_base_stage_2_block_25_layernorm False
# 224 convnext_base_stage_2_block_25_pointwise_conv_1 True
# 225 convnext_base_stage_2_block_25_gelu True
# 226 convnext_base_stage_2_block_25_pointwise_conv_2 True
# 227 convnext_base_stage_2_block_25_layer_scale True
# 228 convnext_base_stage_2_block_25_identity True
# 229 convnext_base_stage_2_block_26_depthwise_conv True
# 230 convnext_base_stage_2_block_26_layernorm False
# 231 convnext_base_stage_2_block_26_pointwise_conv_1 True
# 232 convnext_base_stage_2_block_26_gelu True
# 233 convnext_base_stage_2_block_26_pointwise_conv_2 True
# 234 convnext_base_stage_2_block_26_layer_scale True
# 235 convnext_base_stage_2_block_26_identity True
# 236 convnext_base_downsampling_block_2 True
# 237 convnext_base_stage_3_block_0_depthwise_conv True
# 238 convnext_base_stage_3_block_0_layernorm False
# 239 convnext_base_stage_3_block_0_pointwise_conv_1 True
# 240 convnext_base_stage_3_block_0_gelu True
# 241 convnext_base_stage_3_block_0_pointwise_conv_2 True
# 242 convnext_base_stage_3_block_0_layer_scale True
# 243 convnext_base_stage_3_block_0_identity True
# 244 convnext_base_stage_3_block_1_depthwise_conv True
# 245 convnext_base_stage_3_block_1_layernorm False
# 246 convnext_base_stage_3_block_1_pointwise_conv_1 True
# 247 convnext_base_stage_3_block_1_gelu True
# 248 convnext_base_stage_3_block_1_pointwise_conv_2 True
# 249 convnext_base_stage_3_block_1_layer_scale True
# 250 convnext_base_stage_3_block_1_identity True
# 251 convnext_base_stage_3_block_2_depthwise_conv True
# 252 convnext_base_stage_3_block_2_layernorm False
# 253 convnext_base_stage_3_block_2_pointwise_conv_1 True
# 254 convnext_base_stage_3_block_2_gelu True
# 255 convnext_base_stage_3_block_2_pointwise_conv_2 True
# 256 convnext_base_stage_3_block_2_layer_scale True
# 257 convnext_base_stage_3_block_2_identity True
# 258 global_average_pooling2d True
# 259 layer_normalization False

# %%
# Display a summary of the model 1 architecture
ft_model1.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(ft_model1, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Compile the model
ft_model1.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics=['accuracy'])

# %%
# Fine-tune the model
ft_history1 = ft_model1.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history1['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase1_FTinitial_' + str(final_val_accuracy) + '.keras'
ft_model1.save(model_filename)

# Delete the model to free up resources
del ft_model1
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 124s 202ms/step - accuracy: 0.8704 - loss: 0.3579 - val_accuracy: 0.8376 - val_loss: 0.5451 - learning_rate: 1.0000e-04
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9419 - loss: 0.1639 - val_accuracy: 0.8716 - val_loss: 0.4447 - learning_rate: 1.0000e-04
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9784 - loss: 0.0634 - val_accuracy: 0.8691 - val_loss: 0.4698 - learning_rate: 1.0000e-04
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9907 - loss: 0.0304 - val_accuracy: 0.8791 - val_loss: 0.4678 - learning_rate: 1.0000e-04
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9929 - loss: 0.0214 - val_accuracy: 0.8802 - val_loss: 0.4748 - learning_rate: 1.0000e-04
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9942 - loss: 0.0177 - val_accuracy: 0.8839 - val_loss: 0.4784 - learning_rate: 1.0000e-04
# Epoch 7/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9940 - loss: 0.0200
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9940 - loss: 0.0201 - val_accuracy: 0.8613 - val_loss: 0.5928 - learning_rate: 1.0000e-04
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9915 - loss: 0.0270 - val_accuracy: 0.8816 - val_loss: 0.4886 - learning_rate: 5.0000e-05
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9937 - loss: 0.0155 - val_accuracy: 0.8823 - val_loss: 0.5034 - learning_rate: 5.0000e-05
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9945 - loss: 0.0132 - val_accuracy: 0.8850 - val_loss: 0.5019 - learning_rate: 5.0000e-05
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9947 - loss: 0.0119 - val_accuracy: 0.8847 - val_loss: 0.5114 - learning_rate: 5.0000e-05
# Epoch 12/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9954 - loss: 0.0112
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9954 - loss: 0.0112 - val_accuracy: 0.8853 - val_loss: 0.5128 - learning_rate: 5.0000e-05
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9955 - loss: 0.0102 - val_accuracy: 0.8883 - val_loss: 0.4908 - learning_rate: 2.5000e-05
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9960 - loss: 0.0097 - val_accuracy: 0.8892 - val_loss: 0.4959 - learning_rate: 2.5000e-05
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9958 - loss: 0.0096 - val_accuracy: 0.8881 - val_loss: 0.5047 - learning_rate: 2.5000e-05
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0095 - val_accuracy: 0.8851 - val_loss: 0.5225 - learning_rate: 2.5000e-05
# Epoch 17/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9956 - loss: 0.0091
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9956 - loss: 0.0091 - val_accuracy: 0.8804 - val_loss: 0.5549 - learning_rate: 2.5000e-05
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9957 - loss: 0.0093 - val_accuracy: 0.8865 - val_loss: 0.5183 - learning_rate: 1.2500e-05
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9963 - loss: 0.0079 - val_accuracy: 0.8840 - val_loss: 0.5374 - learning_rate: 1.2500e-05
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9966 - loss: 0.0077 - val_accuracy: 0.8837 - val_loss: 0.5481 - learning_rate: 1.2500e-05
# Epoch 21/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9966 - loss: 0.0077 - val_accuracy: 0.8839 - val_loss: 0.5572 - learning_rate: 1.2500e-05
# Epoch 22/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9968 - loss: 0.0070
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9968 - loss: 0.0070 - val_accuracy: 0.8846 - val_loss: 0.5520 - learning_rate: 1.2500e-05
# Epoch 23/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9968 - loss: 0.0066 - val_accuracy: 0.8811 - val_loss: 0.5615 - learning_rate: 6.2500e-06
# Epoch 24/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9976 - loss: 0.0059 - val_accuracy: 0.8821 - val_loss: 0.5614 - learning_rate: 6.2500e-06
# Epoch 25/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 0.8829 - val_loss: 0.5673 - learning_rate: 6.2500e-06
# Epoch 26/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9982 - loss: 0.0047 - val_accuracy: 0.8844 - val_loss: 0.5627 - learning_rate: 6.2500e-06
# Epoch 27/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9982 - loss: 0.0046
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9982 - loss: 0.0046 - val_accuracy: 0.8825 - val_loss: 0.5714 - learning_rate: 6.2500e-06
# Epoch 28/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.8832 - val_loss: 0.5770 - learning_rate: 3.1250e-06
# Epoch 29/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.8812 - val_loss: 0.5763 - learning_rate: 3.1250e-06
# Epoch 30/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.8818 - val_loss: 0.5934 - learning_rate: 3.1250e-06
# Epoch 31/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.8822 - val_loss: 0.5838 - learning_rate: 3.1250e-06
# Epoch 32/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9990 - loss: 0.0033
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.8798 - val_loss: 0.5861 - learning_rate: 3.1250e-06
# Epoch 33/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.8805 - val_loss: 0.5791 - learning_rate: 1.5625e-06
# Epoch 34/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 116ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.8808 - val_loss: 0.5816 - learning_rate: 1.5625e-06
# Final validation accuracy: 88.92%

# %%
# Compute and print the final validation loss
final_val_loss = round(min(ft_history1['val_loss']), 4)
print(f'Final validation loss: {final_val_loss}')
# Out:
# Final validation loss: 0.4447

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history1['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history1['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history1['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history1['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history1['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history1['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history1['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history1['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy')

# Dynamically calculate y-axis limits for accuracy
all_accuracies = (
    tl_history1['accuracy'] +
    tl_history1['val_accuracy'] +
    ft_history1['accuracy'] +
    ft_history1['val_accuracy']
)
ax2.set_ylim([min(all_accuracies) * 0.95, max(all_accuracies) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Full Fine Tuning

# %%
# Re-load the model after the initial fine tuning
ft_model1 = tfk.models.load_model('ConvNeXtBase1_FTinitial_88.92.keras')

# %%
# Unfreeze all layers in 'convnext_base'
for layer in ft_model1.get_layer('convnext_base').layers:
    layer.trainable = True

# Optional: Keep BatchNorm layers frozen
for layer in ft_model1.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False

# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model1.get_layer('convnext_base').layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_layer True
# 1 convnext_base_prestem_normalization True
# 2 convnext_base_stem True
# 3 convnext_base_stage_0_block_0_depthwise_conv True
# 4 convnext_base_stage_0_block_0_layernorm False
# 5 convnext_base_stage_0_block_0_pointwise_conv_1 True
# 6 convnext_base_stage_0_block_0_gelu True
# 7 convnext_base_stage_0_block_0_pointwise_conv_2 True
# 8 convnext_base_stage_0_block_0_layer_scale True
# 9 convnext_base_stage_0_block_0_identity True
# 10 convnext_base_stage_0_block_1_depthwise_conv True
# 11 convnext_base_stage_0_block_1_layernorm False
# 12 convnext_base_stage_0_block_1_pointwise_conv_1 True
# 13 convnext_base_stage_0_block_1_gelu True
# 14 convnext_base_stage_0_block_1_pointwise_conv_2 True
# 15 convnext_base_stage_0_block_1_layer_scale True
# 16 convnext_base_stage_0_block_1_identity True
# 17 convnext_base_stage_0_block_2_depthwise_conv True
# 18 convnext_base_stage_0_block_2_layernorm False
# 19 convnext_base_stage_0_block_2_pointwise_conv_1 True
# 20 convnext_base_stage_0_block_2_gelu True
# 21 convnext_base_stage_0_block_2_pointwise_conv_2 True
# 22 convnext_base_stage_0_block_2_layer_scale True
# 23 convnext_base_stage_0_block_2_identity True
# 24 convnext_base_downsampling_block_0 True
# 25 convnext_base_stage_1_block_0_depthwise_conv True
# 26 convnext_base_stage_1_block_0_layernorm False
# 27 convnext_base_stage_1_block_0_pointwise_conv_1 True
# 28 convnext_base_stage_1_block_0_gelu True
# 29 convnext_base_stage_1_block_0_pointwise_conv_2 True
# 30 convnext_base_stage_1_block_0_layer_scale True
# 31 convnext_base_stage_1_block_0_identity True
# 32 convnext_base_stage_1_block_1_depthwise_conv True
# 33 convnext_base_stage_1_block_1_layernorm False
# 34 convnext_base_stage_1_block_1_pointwise_conv_1 True
# 35 convnext_base_stage_1_block_1_gelu True
# 36 convnext_base_stage_1_block_1_pointwise_conv_2 True
# 37 convnext_base_stage_1_block_1_layer_scale True
# 38 convnext_base_stage_1_block_1_identity True
# 39 convnext_base_stage_1_block_2_depthwise_conv True
# 40 convnext_base_stage_1_block_2_layernorm False
# 41 convnext_base_stage_1_block_2_pointwise_conv_1 True
# 42 convnext_base_stage_1_block_2_gelu True
# 43 convnext_base_stage_1_block_2_pointwise_conv_2 True
# 44 convnext_base_stage_1_block_2_layer_scale True
# 45 convnext_base_stage_1_block_2_identity True
# 46 convnext_base_downsampling_block_1 True
# 47 convnext_base_stage_2_block_0_depthwise_conv True
# 48 convnext_base_stage_2_block_0_layernorm False
# 49 convnext_base_stage_2_block_0_pointwise_conv_1 True
# 50 convnext_base_stage_2_block_0_gelu True
# 51 convnext_base_stage_2_block_0_pointwise_conv_2 True
# 52 convnext_base_stage_2_block_0_layer_scale True
# 53 convnext_base_stage_2_block_0_identity True
# 54 convnext_base_stage_2_block_1_depthwise_conv True
# 55 convnext_base_stage_2_block_1_layernorm False
# 56 convnext_base_stage_2_block_1_pointwise_conv_1 True
# 57 convnext_base_stage_2_block_1_gelu True
# 58 convnext_base_stage_2_block_1_pointwise_conv_2 True
# 59 convnext_base_stage_2_block_1_layer_scale True
# 60 convnext_base_stage_2_block_1_identity True
# 61 convnext_base_stage_2_block_2_depthwise_conv True
# 62 convnext_base_stage_2_block_2_layernorm False
# 63 convnext_base_stage_2_block_2_pointwise_conv_1 True
# 64 convnext_base_stage_2_block_2_gelu True
# 65 convnext_base_stage_2_block_2_pointwise_conv_2 True
# 66 convnext_base_stage_2_block_2_layer_scale True
# 67 convnext_base_stage_2_block_2_identity True
# 68 convnext_base_stage_2_block_3_depthwise_conv True
# 69 convnext_base_stage_2_block_3_layernorm False
# 70 convnext_base_stage_2_block_3_pointwise_conv_1 True
# 71 convnext_base_stage_2_block_3_gelu True
# 72 convnext_base_stage_2_block_3_pointwise_conv_2 True
# 73 convnext_base_stage_2_block_3_layer_scale True
# 74 convnext_base_stage_2_block_3_identity True
# 75 convnext_base_stage_2_block_4_depthwise_conv True
# 76 convnext_base_stage_2_block_4_layernorm False
# 77 convnext_base_stage_2_block_4_pointwise_conv_1 True
# 78 convnext_base_stage_2_block_4_gelu True
# 79 convnext_base_stage_2_block_4_pointwise_conv_2 True
# 80 convnext_base_stage_2_block_4_layer_scale True
# 81 convnext_base_stage_2_block_4_identity True
# 82 convnext_base_stage_2_block_5_depthwise_conv True
# 83 convnext_base_stage_2_block_5_layernorm False
# 84 convnext_base_stage_2_block_5_pointwise_conv_1 True
# 85 convnext_base_stage_2_block_5_gelu True
# 86 convnext_base_stage_2_block_5_pointwise_conv_2 True
# 87 convnext_base_stage_2_block_5_layer_scale True
# 88 convnext_base_stage_2_block_5_identity True
# 89 convnext_base_stage_2_block_6_depthwise_conv True
# 90 convnext_base_stage_2_block_6_layernorm False
# 91 convnext_base_stage_2_block_6_pointwise_conv_1 True
# 92 convnext_base_stage_2_block_6_gelu True
# 93 convnext_base_stage_2_block_6_pointwise_conv_2 True
# 94 convnext_base_stage_2_block_6_layer_scale True
# 95 convnext_base_stage_2_block_6_identity True
# 96 convnext_base_stage_2_block_7_depthwise_conv True
# 97 convnext_base_stage_2_block_7_layernorm False
# 98 convnext_base_stage_2_block_7_pointwise_conv_1 True
# 99 convnext_base_stage_2_block_7_gelu True
# 100 convnext_base_stage_2_block_7_pointwise_conv_2 True
# 101 convnext_base_stage_2_block_7_layer_scale True
# 102 convnext_base_stage_2_block_7_identity True
# 103 convnext_base_stage_2_block_8_depthwise_conv True
# 104 convnext_base_stage_2_block_8_layernorm False
# 105 convnext_base_stage_2_block_8_pointwise_conv_1 True
# 106 convnext_base_stage_2_block_8_gelu True
# 107 convnext_base_stage_2_block_8_pointwise_conv_2 True
# 108 convnext_base_stage_2_block_8_layer_scale True
# 109 convnext_base_stage_2_block_8_identity True
# 110 convnext_base_stage_2_block_9_depthwise_conv True
# 111 convnext_base_stage_2_block_9_layernorm False
# 112 convnext_base_stage_2_block_9_pointwise_conv_1 True
# 113 convnext_base_stage_2_block_9_gelu True
# 114 convnext_base_stage_2_block_9_pointwise_conv_2 True
# 115 convnext_base_stage_2_block_9_layer_scale True
# 116 convnext_base_stage_2_block_9_identity True
# 117 convnext_base_stage_2_block_10_depthwise_conv True
# 118 convnext_base_stage_2_block_10_layernorm False
# 119 convnext_base_stage_2_block_10_pointwise_conv_1 True
# 120 convnext_base_stage_2_block_10_gelu True
# 121 convnext_base_stage_2_block_10_pointwise_conv_2 True
# 122 convnext_base_stage_2_block_10_layer_scale True
# 123 convnext_base_stage_2_block_10_identity True
# 124 convnext_base_stage_2_block_11_depthwise_conv True
# 125 convnext_base_stage_2_block_11_layernorm False
# 126 convnext_base_stage_2_block_11_pointwise_conv_1 True
# 127 convnext_base_stage_2_block_11_gelu True
# 128 convnext_base_stage_2_block_11_pointwise_conv_2 True
# 129 convnext_base_stage_2_block_11_layer_scale True
# 130 convnext_base_stage_2_block_11_identity True
# 131 convnext_base_stage_2_block_12_depthwise_conv True
# 132 convnext_base_stage_2_block_12_layernorm False
# 133 convnext_base_stage_2_block_12_pointwise_conv_1 True
# 134 convnext_base_stage_2_block_12_gelu True
# 135 convnext_base_stage_2_block_12_pointwise_conv_2 True
# 136 convnext_base_stage_2_block_12_layer_scale True
# 137 convnext_base_stage_2_block_12_identity True
# 138 convnext_base_stage_2_block_13_depthwise_conv True
# 139 convnext_base_stage_2_block_13_layernorm False
# 140 convnext_base_stage_2_block_13_pointwise_conv_1 True
# 141 convnext_base_stage_2_block_13_gelu True
# 142 convnext_base_stage_2_block_13_pointwise_conv_2 True
# 143 convnext_base_stage_2_block_13_layer_scale True
# 144 convnext_base_stage_2_block_13_identity True
# 145 convnext_base_stage_2_block_14_depthwise_conv True
# 146 convnext_base_stage_2_block_14_layernorm False
# 147 convnext_base_stage_2_block_14_pointwise_conv_1 True
# 148 convnext_base_stage_2_block_14_gelu True
# 149 convnext_base_stage_2_block_14_pointwise_conv_2 True
# 150 convnext_base_stage_2_block_14_layer_scale True
# 151 convnext_base_stage_2_block_14_identity True
# 152 convnext_base_stage_2_block_15_depthwise_conv True
# 153 convnext_base_stage_2_block_15_layernorm False
# 154 convnext_base_stage_2_block_15_pointwise_conv_1 True
# 155 convnext_base_stage_2_block_15_gelu True
# 156 convnext_base_stage_2_block_15_pointwise_conv_2 True
# 157 convnext_base_stage_2_block_15_layer_scale True
# 158 convnext_base_stage_2_block_15_identity True
# 159 convnext_base_stage_2_block_16_depthwise_conv True
# 160 convnext_base_stage_2_block_16_layernorm False
# 161 convnext_base_stage_2_block_16_pointwise_conv_1 True
# 162 convnext_base_stage_2_block_16_gelu True
# 163 convnext_base_stage_2_block_16_pointwise_conv_2 True
# 164 convnext_base_stage_2_block_16_layer_scale True
# 165 convnext_base_stage_2_block_16_identity True
# 166 convnext_base_stage_2_block_17_depthwise_conv True
# 167 convnext_base_stage_2_block_17_layernorm False
# 168 convnext_base_stage_2_block_17_pointwise_conv_1 True
# 169 convnext_base_stage_2_block_17_gelu True
# 170 convnext_base_stage_2_block_17_pointwise_conv_2 True
# 171 convnext_base_stage_2_block_17_layer_scale True
# 172 convnext_base_stage_2_block_17_identity True
# 173 convnext_base_stage_2_block_18_depthwise_conv True
# 174 convnext_base_stage_2_block_18_layernorm False
# 175 convnext_base_stage_2_block_18_pointwise_conv_1 True
# 176 convnext_base_stage_2_block_18_gelu True
# 177 convnext_base_stage_2_block_18_pointwise_conv_2 True
# 178 convnext_base_stage_2_block_18_layer_scale True
# 179 convnext_base_stage_2_block_18_identity True
# 180 convnext_base_stage_2_block_19_depthwise_conv True
# 181 convnext_base_stage_2_block_19_layernorm False
# 182 convnext_base_stage_2_block_19_pointwise_conv_1 True
# 183 convnext_base_stage_2_block_19_gelu True
# 184 convnext_base_stage_2_block_19_pointwise_conv_2 True
# 185 convnext_base_stage_2_block_19_layer_scale True
# 186 convnext_base_stage_2_block_19_identity True
# 187 convnext_base_stage_2_block_20_depthwise_conv True
# 188 convnext_base_stage_2_block_20_layernorm False
# 189 convnext_base_stage_2_block_20_pointwise_conv_1 True
# 190 convnext_base_stage_2_block_20_gelu True
# 191 convnext_base_stage_2_block_20_pointwise_conv_2 True
# 192 convnext_base_stage_2_block_20_layer_scale True
# 193 convnext_base_stage_2_block_20_identity True
# 194 convnext_base_stage_2_block_21_depthwise_conv True
# 195 convnext_base_stage_2_block_21_layernorm False
# 196 convnext_base_stage_2_block_21_pointwise_conv_1 True
# 197 convnext_base_stage_2_block_21_gelu True
# 198 convnext_base_stage_2_block_21_pointwise_conv_2 True
# 199 convnext_base_stage_2_block_21_layer_scale True
# 200 convnext_base_stage_2_block_21_identity True
# 201 convnext_base_stage_2_block_22_depthwise_conv True
# 202 convnext_base_stage_2_block_22_layernorm False
# 203 convnext_base_stage_2_block_22_pointwise_conv_1 True
# 204 convnext_base_stage_2_block_22_gelu True
# 205 convnext_base_stage_2_block_22_pointwise_conv_2 True
# 206 convnext_base_stage_2_block_22_layer_scale True
# 207 convnext_base_stage_2_block_22_identity True
# 208 convnext_base_stage_2_block_23_depthwise_conv True
# 209 convnext_base_stage_2_block_23_layernorm False
# 210 convnext_base_stage_2_block_23_pointwise_conv_1 True
# 211 convnext_base_stage_2_block_23_gelu True
# 212 convnext_base_stage_2_block_23_pointwise_conv_2 True
# 213 convnext_base_stage_2_block_23_layer_scale True
# 214 convnext_base_stage_2_block_23_identity True
# 215 convnext_base_stage_2_block_24_depthwise_conv True
# 216 convnext_base_stage_2_block_24_layernorm False
# 217 convnext_base_stage_2_block_24_pointwise_conv_1 True
# 218 convnext_base_stage_2_block_24_gelu True
# 219 convnext_base_stage_2_block_24_pointwise_conv_2 True
# 220 convnext_base_stage_2_block_24_layer_scale True
# 221 convnext_base_stage_2_block_24_identity True
# 222 convnext_base_stage_2_block_25_depthwise_conv True
# 223 convnext_base_stage_2_block_25_layernorm False
# 224 convnext_base_stage_2_block_25_pointwise_conv_1 True
# 225 convnext_base_stage_2_block_25_gelu True
# 226 convnext_base_stage_2_block_25_pointwise_conv_2 True
# 227 convnext_base_stage_2_block_25_layer_scale True
# 228 convnext_base_stage_2_block_25_identity True
# 229 convnext_base_stage_2_block_26_depthwise_conv True
# 230 convnext_base_stage_2_block_26_layernorm False
# 231 convnext_base_stage_2_block_26_pointwise_conv_1 True
# 232 convnext_base_stage_2_block_26_gelu True
# 233 convnext_base_stage_2_block_26_pointwise_conv_2 True
# 234 convnext_base_stage_2_block_26_layer_scale True
# 235 convnext_base_stage_2_block_26_identity True
# 236 convnext_base_downsampling_block_2 True
# 237 convnext_base_stage_3_block_0_depthwise_conv True
# 238 convnext_base_stage_3_block_0_layernorm False
# 239 convnext_base_stage_3_block_0_pointwise_conv_1 True
# 240 convnext_base_stage_3_block_0_gelu True
# 241 convnext_base_stage_3_block_0_pointwise_conv_2 True
# 242 convnext_base_stage_3_block_0_layer_scale True
# 243 convnext_base_stage_3_block_0_identity True
# 244 convnext_base_stage_3_block_1_depthwise_conv True
# 245 convnext_base_stage_3_block_1_layernorm False
# 246 convnext_base_stage_3_block_1_pointwise_conv_1 True
# 247 convnext_base_stage_3_block_1_gelu True
# 248 convnext_base_stage_3_block_1_pointwise_conv_2 True
# 249 convnext_base_stage_3_block_1_layer_scale True
# 250 convnext_base_stage_3_block_1_identity True
# 251 convnext_base_stage_3_block_2_depthwise_conv True
# 252 convnext_base_stage_3_block_2_layernorm False
# 253 convnext_base_stage_3_block_2_pointwise_conv_1 True
# 254 convnext_base_stage_3_block_2_gelu True
# 255 convnext_base_stage_3_block_2_pointwise_conv_2 True
# 256 convnext_base_stage_3_block_2_layer_scale True
# 257 convnext_base_stage_3_block_2_identity True
# 258 global_average_pooling2d True
# 259 layer_normalization False

# %%
# Display a summary of the model 1 architecture
ft_model1.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(ft_model1, expand_nested=False, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "model1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ convnext_base (Functional)           │ (None, 1024)                │      87,566,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └ input_layer (InputLayer)        │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 96, 96, 3)           │               0 │
# │ convnext_base_prestem_normalization  │                             │                 │
# │ (Normalization)                      │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └ convnext_base_stem (Sequential) │ (None, 24, 24, 128)         │           6,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └ convnext_base_stem_conv      │ (None, 24, 24, 128)         │           6,272 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └ convnext_base_stem_layernorm │ (None, 24, 24, 128)         │             256 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │           6,400 │
# │ convnext_base_stage_0_block_0_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │             256 │
# │ convnext_base_stage_0_block_0_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 512)         │          66,048 │
# │ convnext_base_stage_0_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 512)         │               0 │
# │ convnext_base_stage_0_block_0_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │          65,664 │
# │ convnext_base_stage_0_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │             128 │
# │ convnext_base_stage_0_block_0_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │               0 │
# │ convnext_base_stage_0_block_0_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │           6,400 │
# │ convnext_base_stage_0_block_1_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │             256 │
# │ convnext_base_stage_0_block_1_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 512)         │          66,048 │
# │ convnext_base_stage_0_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 512)         │               0 │
# │ convnext_base_stage_0_block_1_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │          65,664 │
# │ convnext_base_stage_0_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │             128 │
# │ convnext_base_stage_0_block_1_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │               0 │
# │ convnext_base_stage_0_block_1_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │           6,400 │
# │ convnext_base_stage_0_block_2_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │             256 │
# │ convnext_base_stage_0_block_2_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 512)         │          66,048 │
# │ convnext_base_stage_0_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 512)         │               0 │
# │ convnext_base_stage_0_block_2_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │          65,664 │
# │ convnext_base_stage_0_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │             128 │
# │ convnext_base_stage_0_block_2_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 24, 24, 128)         │               0 │
# │ convnext_base_stage_0_block_2_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │         131,584 │
# │ convnext_base_downsampling_block_0   │                             │                 │
# │ (Sequential)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └                              │ (None, 24, 24, 128)         │             256 │
# │ convnext_base_downsampling_layernor… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └                              │ (None, 12, 12, 256)         │         131,328 │
# │ convnext_base_downsampling_conv_0    │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │          12,800 │
# │ convnext_base_stage_1_block_0_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │             512 │
# │ convnext_base_stage_1_block_0_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 1024)        │         263,168 │
# │ convnext_base_stage_1_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 1024)        │               0 │
# │ convnext_base_stage_1_block_0_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │         262,400 │
# │ convnext_base_stage_1_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │             256 │
# │ convnext_base_stage_1_block_0_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │               0 │
# │ convnext_base_stage_1_block_0_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │          12,800 │
# │ convnext_base_stage_1_block_1_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │             512 │
# │ convnext_base_stage_1_block_1_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 1024)        │         263,168 │
# │ convnext_base_stage_1_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 1024)        │               0 │
# │ convnext_base_stage_1_block_1_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │         262,400 │
# │ convnext_base_stage_1_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │             256 │
# │ convnext_base_stage_1_block_1_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │               0 │
# │ convnext_base_stage_1_block_1_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │          12,800 │
# │ convnext_base_stage_1_block_2_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │             512 │
# │ convnext_base_stage_1_block_2_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 1024)        │         263,168 │
# │ convnext_base_stage_1_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 1024)        │               0 │
# │ convnext_base_stage_1_block_2_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │         262,400 │
# │ convnext_base_stage_1_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │             256 │
# │ convnext_base_stage_1_block_2_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 12, 12, 256)         │               0 │
# │ convnext_base_stage_1_block_2_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │         525,312 │
# │ convnext_base_downsampling_block_1   │                             │                 │
# │ (Sequential)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └                              │ (None, 12, 12, 256)         │             512 │
# │ convnext_base_downsampling_layernor… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └                              │ (None, 6, 6, 512)           │         524,800 │
# │ convnext_base_downsampling_conv_1    │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_0_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_0_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_0_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_0_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_0_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_1_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_1_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_1_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_1_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_1_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_2_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_2_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_2_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_2_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_2_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_3_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_3_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_3_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_3_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_3_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_3_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_3_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_4_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_4_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_4_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_4_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_4_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_4_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_4_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_5_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_5_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_5_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_5_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_5_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_5_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_5_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_6_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_6_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_6_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_6_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_6_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_6_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_6_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_7_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_7_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_7_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_7_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_7_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_7_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_7_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_8_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_8_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_8_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_8_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_8_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_8_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_8_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_9_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_9_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_9_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_9_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_9_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_9_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_9_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_10_dept… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_10_laye… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_10_poin… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_10_gelu  │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_10_poin… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_10_laye… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_10_iden… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_11_dept… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_11_laye… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_11_poin… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_11_gelu  │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_11_poin… │                             │                 │
# ...
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_24_laye… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_24_iden… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_25_dept… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_25_laye… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_25_poin… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_25_gelu  │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_25_poin… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_25_laye… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_25_iden… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │          25,600 │
# │ convnext_base_stage_2_block_26_dept… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_stage_2_block_26_laye… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │       1,050,624 │
# │ convnext_base_stage_2_block_26_poin… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 2048)          │               0 │
# │ convnext_base_stage_2_block_26_gelu  │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │       1,049,088 │
# │ convnext_base_stage_2_block_26_poin… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │             512 │
# │ convnext_base_stage_2_block_26_laye… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 6, 6, 512)           │               0 │
# │ convnext_base_stage_2_block_26_iden… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │       2,099,200 │
# │ convnext_base_downsampling_block_2   │                             │                 │
# │ (Sequential)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └                              │ (None, 6, 6, 512)           │           1,024 │
# │ convnext_base_downsampling_layernor… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │       └                              │ (None, 3, 3, 1024)          │       2,098,176 │
# │ convnext_base_downsampling_conv_2    │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │          51,200 │
# │ convnext_base_stage_3_block_0_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │           2,048 │
# │ convnext_base_stage_3_block_0_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 4096)          │       4,198,400 │
# │ convnext_base_stage_3_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 4096)          │               0 │
# │ convnext_base_stage_3_block_0_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │       4,195,328 │
# │ convnext_base_stage_3_block_0_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │           1,024 │
# │ convnext_base_stage_3_block_0_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │               0 │
# │ convnext_base_stage_3_block_0_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │          51,200 │
# │ convnext_base_stage_3_block_1_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │           2,048 │
# │ convnext_base_stage_3_block_1_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 4096)          │       4,198,400 │
# │ convnext_base_stage_3_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 4096)          │               0 │
# │ convnext_base_stage_3_block_1_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │       4,195,328 │
# │ convnext_base_stage_3_block_1_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │           1,024 │
# │ convnext_base_stage_3_block_1_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │               0 │
# │ convnext_base_stage_3_block_1_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │          51,200 │
# │ convnext_base_stage_3_block_2_depth… │                             │                 │
# │ (Conv2D)                             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │           2,048 │
# │ convnext_base_stage_3_block_2_layer… │                             │                 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 4096)          │       4,198,400 │
# │ convnext_base_stage_3_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 4096)          │               0 │
# │ convnext_base_stage_3_block_2_gelu   │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │       4,195,328 │
# │ convnext_base_stage_3_block_2_point… │                             │                 │
# │ (Dense)                              │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │           1,024 │
# │ convnext_base_stage_3_block_2_layer… │                             │                 │
# │ (LayerScale)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └                                 │ (None, 3, 3, 1024)          │               0 │
# │ convnext_base_stage_3_block_2_ident… │                             │                 │
# │ (Activation)                         │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └ global_average_pooling2d        │ (None, 1024)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │    └ layer_normalization             │ (None, 1024)                │           2,048 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense1 (Dense)                       │ (None, 128)                 │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_norm1 (BatchNormalization)     │ (None, 128)                 │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation1 (Activation)             │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout1 (Dropout)                   │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output_layer (Dense)                 │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 253,434,394 (966.78 MB)
#  Trainable params: 84,898,184 (323.86 MB)
#  Non-trainable params: 2,801,024 (10.69 MB)
#  Optimizer params: 165,735,186 (632.23 MB)

# %%
# Compile the model
ft_model1.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-5), metrics=['accuracy'])

# %%
# Fine-tune the model 1
ft_history1 = ft_model1.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history1['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase1_FTfull_' + str(final_val_accuracy) + '.keras'
ft_model1.save(model_filename)

# Delete the model to free up resources
del ft_model1
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 144s 244ms/step - accuracy: 0.9959 - loss: 0.0095 - val_accuracy: 0.8807 - val_loss: 0.5468 - learning_rate: 1.0000e-05
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 151ms/step - accuracy: 0.9958 - loss: 0.0091 - val_accuracy: 0.8835 - val_loss: 0.5408 - learning_rate: 1.0000e-05
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 50s 150ms/step - accuracy: 0.9965 - loss: 0.0088 - val_accuracy: 0.8818 - val_loss: 0.5995 - learning_rate: 1.0000e-05
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9957 - loss: 0.0082 - val_accuracy: 0.8832 - val_loss: 0.5773 - learning_rate: 1.0000e-05
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 50s 150ms/step - accuracy: 0.9965 - loss: 0.0077 - val_accuracy: 0.8775 - val_loss: 0.6064 - learning_rate: 1.0000e-05
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9968 - loss: 0.0070 - val_accuracy: 0.8826 - val_loss: 0.5933 - learning_rate: 1.0000e-05
# Epoch 7/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9965 - loss: 0.0072
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9965 - loss: 0.0072 - val_accuracy: 0.8807 - val_loss: 0.6003 - learning_rate: 1.0000e-05
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9975 - loss: 0.0059 - val_accuracy: 0.8865 - val_loss: 0.5740 - learning_rate: 5.0000e-06
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9978 - loss: 0.0050 - val_accuracy: 0.8840 - val_loss: 0.5823 - learning_rate: 5.0000e-06
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9973 - loss: 0.0055 - val_accuracy: 0.8862 - val_loss: 0.5855 - learning_rate: 5.0000e-06
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 0.8839 - val_loss: 0.6035 - learning_rate: 5.0000e-06
# Epoch 12/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9983 - loss: 0.0042
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9983 - loss: 0.0042 - val_accuracy: 0.8846 - val_loss: 0.5914 - learning_rate: 5.0000e-06
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9984 - loss: 0.0038 - val_accuracy: 0.8825 - val_loss: 0.5923 - learning_rate: 2.5000e-06
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9984 - loss: 0.0040 - val_accuracy: 0.8841 - val_loss: 0.5865 - learning_rate: 2.5000e-06
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.8854 - val_loss: 0.5922 - learning_rate: 2.5000e-06
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.8846 - val_loss: 0.5990 - learning_rate: 2.5000e-06
# Epoch 17/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9989 - loss: 0.0036
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.8851 - val_loss: 0.5947 - learning_rate: 2.5000e-06
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.8840 - val_loss: 0.5958 - learning_rate: 1.2500e-06
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9986 - loss: 0.0032 - val_accuracy: 0.8839 - val_loss: 0.5934 - learning_rate: 1.2500e-06
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 150ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 0.8851 - val_loss: 0.5993 - learning_rate: 1.2500e-06
# Final validation accuracy: 88.65%

# %%
# Compute and print the final validation loss
final_val_loss = round(min(ft_history1['val_loss']), 4)
print(f'Final validation loss: {final_val_loss}')
# Out:
# Final validation loss: 0.5408

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history1['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history1['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history1['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history1['val_loss'], label='Full Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy ')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history1['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history1['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history1['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history1['val_accuracy'], label='Full Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy')

# Dynamically calculate y-axis limits for accuracy
all_accuracies = (
    tl_history1['accuracy'] +
    tl_history1['val_accuracy'] +
    ft_history1['accuracy'] +
    ft_history1['val_accuracy']
)
ax2.set_ylim([min(all_accuracies) * 0.95, max(all_accuracies) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🕹️ Use the Model - Make Inference

# %% [markdown]
# ### Test model on test set

# %%
# Load the fine-tuned ConvNeXtBase model for prediction on external images
ft_model1 = tfk.models.load_model('ConvNeXtBase1_FTinitial_88.92.keras')
ft_model2 = tfk.models.load_model('ConvNeXtBase1_FTfull_88.65.keras')

# %% [markdown]
# #### 1. Test set without augmentation

# %%
# Predict labels for the entire test set
predictions1 = ft_model1.predict(X_test, verbose=0)

# Convert predictions to class labels
pred_classes1 = np.argmax(predictions1, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy1 = accuracy_score(true_classes, pred_classes1)
print(f'Accuracy 1 score over the test set: {round(accuracy1, 4)}')

# Calculate and display test set precision
precision1 = precision_score(true_classes, pred_classes1, average='weighted')
print(f'Precision 1 score over the test set: {round(precision1, 4)}')

# Calculate and display test set recall
recall1 = recall_score(true_classes, pred_classes1, average='weighted')
print(f'Recall score 1 over the test set: {round(recall1, 4)}')

# Calculate and display test set F1 score
f11 = f1_score(true_classes, pred_classes1, average='weighted')
print(f'F1 score 1 over the test set: {round(f11, 4)}')

# Compute the confusion matrix
cm1 = confusion_matrix(true_classes, pred_classes1)

# Combine numbers and percentages into a single string for annotation
annot1 = np.array([f"{num}" for num in cm1.flatten()]).reshape(cm1.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm1.T, annot=annot1, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 1 score over the test set: 0.9778
# Precision 1 score over the test set: 0.9784
# Recall score 1 over the test set: 0.9778
# F1 score 1 over the test set: 0.9779

# %%
# Predict labels for the entire test set
predictions2 = ft_model2.predict(X_test, verbose=0)

# Convert predictions to class labels
pred_classes2 = np.argmax(predictions2, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy2 = accuracy_score(true_classes, pred_classes2)
print(f'Accuracy 2 score over the test set: {round(accuracy2, 4)}')

# Calculate and display test set precision
precision2 = precision_score(true_classes, pred_classes2, average='weighted')
print(f'Precision 2 score over the test set: {round(precision2, 4)}')

# Calculate and display test set recall
recall2 = recall_score(true_classes, pred_classes2, average='weighted')
print(f'Recall score 2 over the test set: {round(recall2, 4)}')

# Calculate and display test set F1 score
f12 = f1_score(true_classes, pred_classes2, average='weighted')
print(f'F1 score 2 over the test set: {round(f12, 4)}')

# Compute the confusion matrix
cm2 = confusion_matrix(true_classes, pred_classes2)

# Combine numbers and percentages into a single string for annotation
annot2 = np.array([f"{num}" for num in cm2.flatten()]).reshape(cm2.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm2.T, annot=annot2, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 2 score over the test set: 0.9741
# Precision 2 score over the test set: 0.9749
# Recall score 2 over the test set: 0.9741
# F1 score 2 over the test set: 0.9741

# %% [markdown]
# #### 2. Test set with augmentation

# %%
# Predict labels for the entire test set
predictions1_aug = ft_model1.predict(X_test_augmented, verbose=0)

# Convert predictions to class labels
pred_classes1_aug = np.argmax(predictions1_aug, axis=-1)

# Extract ground truth classes
true_classes_aug = np.argmax(y_test_augmented, axis=-1)

# Calculate and display test set accuracy
accuracy1_aug = accuracy_score(true_classes_aug, pred_classes1_aug)
print(f'Accuracy 1 score over the test set augmented: {round(accuracy1_aug, 4)}')

# Calculate and display test set precision
precision1_aug = precision_score(true_classes_aug, pred_classes1_aug, average='weighted')
print(f'Precision 1 score over the test set augmented: {round(precision1_aug, 4)}')

# Calculate and display test set recall
recall1_aug = recall_score(true_classes_aug, pred_classes1_aug, average='weighted')
print(f'Recall score 1 over the test set augmented: {round(recall1_aug, 4)}')

# Calculate and display test set F1 score
f11_aug = f1_score(true_classes_aug, pred_classes1_aug, average='weighted')
print(f'F1 score 1 over the test set augmented: {round(f11_aug, 4)}')

# Compute the confusion matrix
cm1_aug = confusion_matrix(true_classes_aug, pred_classes1_aug)

# Combine numbers and percentages into a single string for annotation
annot1_aug = np.array([f"{num}" for num in cm1_aug.flatten()]).reshape(cm1_aug.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm1_aug.T, annot=annot1_aug, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 1 score over the test set augmented: 0.7683
# Precision 1 score over the test set augmented: 0.78
# Recall score 1 over the test set augmented: 0.7683
# F1 score 1 over the test set augmented: 0.7714

# %%
# Predict labels for the entire test set
predictions2_aug = ft_model2.predict(X_test_augmented, verbose=0)

# Convert predictions to class labels
pred_classes2_aug = np.argmax(predictions2_aug, axis=-1)

# Extract ground truth classes
true_classes_aug = np.argmax(y_test_augmented, axis=-1)

# Calculate and display test set accuracy
accuracy2_aug = accuracy_score(true_classes_aug, pred_classes2_aug)
print(f'Accuracy 2 score over the test set augmented: {round(accuracy2_aug, 4)}')

# Calculate and display test set precision
precision2_aug = precision_score(true_classes_aug, pred_classes2_aug, average='weighted')
print(f'Precision 2 score over the test set augmented: {round(precision2_aug, 4)}')

# Calculate and display test set recall
recall2_aug = recall_score(true_classes_aug, pred_classes2_aug, average='weighted')
print(f'Recall score 2 over the test set augmented: {round(recall2_aug, 4)}')

# Calculate and display test set F1 score
f12_aug = f1_score(true_classes_aug, pred_classes2_aug, average='weighted')
print(f'F1 score 2 over the test set augmented: {round(f12_aug, 4)}')

# Compute the confusion matrix
cm2_aug = confusion_matrix(true_classes_aug, pred_classes2_aug)

# Combine numbers and percentages into a single string for annotation
annot2_aug = np.array([f"{num}" for num in cm2_aug.flatten()]).reshape(cm2_aug.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm2_aug.T, annot=annot2_aug, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 2 score over the test set augmented: 0.7646
# Precision 2 score over the test set augmented: 0.7749
# Recall score 2 over the test set augmented: 0.7646
# F1 score 2 over the test set augmented: 0.7669

# %% [markdown]
# ## 📊 Prepare Your Submission
#
# To prepare your submission, create a `.zip` file that includes all the necessary code to run your model. It **must** include a `model.py` file with the following class:
#
# ```python
#
# # file: model.py
#
# import tensorflow as tf
# import numpy as np
#
# class Model:
#     def __init__(self):
#         """Initialize the internal state of the model."""
#
#         # Load the pre-trained model weights
#         self.model = tf.keras.models.load_model('weights.keras')  # Path to your saved weights
#
#     def predict(self, X):
#         """
#         Return a numpy array with the labels corresponding to the input X.
#         X: numpy array of input images.
#         """
#         predictions = self.model.predict(X)
#         # Return the class labels as a numpy array
#         return np.argmax(predictions, axis=-1)
#
# The next cell shows an example implementation of the `model.py` file, which includes loading model weights from the `weights.keras` file and conducting predictions on provided input data. The `.zip` file is created and downloaded in the last notebook cell.
#
# ❗ Feel free to modify the method implementations to better fit your specific requirements, but please ensure that the class name and method interfaces remain unchanged.

# %%
# %%writefile model.py

import numpy as np
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.
        """
        # Load the specific model file
        self.neural_network = tfk.models.load_model('ConvNeXtBase1_FT_89.32.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must not be one-hot
        encoded.

        This function returns class labels as integers.
        """
        # Get predictions and convert to label format
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Overwriting model.py

# %%
from datetime import datetime

filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py ConvNeXtBase1_FT_89.32.keras

from google.colab import files
files.download(filename)
# Out:
#   adding: model.py (deflated 52%)
#   adding: ConvNeXtBase1_FT_89.32.keras (deflated 7%)
