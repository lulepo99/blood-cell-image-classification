# %% [markdown]
# # Artificial Neural Networks and Deep Learning - Homework 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# - Team: Bio.log(y)
#
#
#
#
#
#
#
# - Members: Luca Lepore, Arianna Rigamonti, Michele Sala, Jacopo Libero Tettamanti
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## ConvNeXtBase on pre-processed data

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/[2024 - 2025] AN2DL/Homework 1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/[2024 - 2025] AN2DL/Homework 1

# %% [markdown]
# ### ⚙️ Import Libraries

# %%
# !pip uninstall -y tensorflow keras
# Out:
# Found existing installation: tensorflow 2.17.1
# Uninstalling tensorflow-2.17.1:
#   Successfully uninstalled tensorflow-2.17.1
# Found existing installation: keras 3.5.0
# Uninstalling keras-3.5.0:
#   Successfully uninstalled keras-3.5.0

# %%
# !pip install tensorflow==2.17.0 keras==3.4.1
# Out:
# Collecting tensorflow==2.17.0
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting keras==3.4.1
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.0) (0.45.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.4.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.4.1) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.4.1) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.0.2)
# Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.1 MB/s eta 0:00:00
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.9 MB/s eta 0:00:00
# Installing collected packages: keras, tensorflow
# Successfully installed keras-3.4.1 tensorflow-2.17.0

# %%
# !pip install keras-cv --upgrade
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.7)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.5)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.66.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 13.3 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 43.0 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np
import pandas as pd

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
import keras as tfk
from keras.layers import Input, Dense, Dropout, Lambda
from keras import layers as tfkl
import keras_cv.layers as cv_layers

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {tfk.__version__}")

# Import other libraries
import cv2
from keras.applications import ConvNeXtBase
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from PIL import Image
import matplotlib.gridspec as gridspec
import requests
from io import BytesIO
from sklearn.utils import resample, shuffle
from sklearn.utils.class_weight import compute_class_weight
from ipywidgets import interact, IntSlider, Dropdown
from tensorflow.keras.utils import to_categorical
import plotly.express as px
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# TensorFlow version: 2.17.0
# Keras version: 3.4.1

# %% [markdown]
# ## ⏳ Load Data

# %%
# Load your dataset
train_augmented = np.load('X_train_augmented_3x.npz')
X_train = train_augmented['images']
y_train = train_augmented['labels']

val_augmented = np.load('X_val_augmented_3x.npz')
X_val = val_augmented['images']
y_val = val_augmented['labels']

test = np.load('X_test.npz')
X_test = test['images']
y_test = test['labels']

test_augmented = np.load('X_test_augmented_4x.npz')
X_test_augmented = test_augmented['images']
y_test_augmented = test_augmented['labels']

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Save unique labels
unique_labels = list(labels.values())
print(f'Unique labels: {unique_labels}')
# Out:
# Unique labels: ['Basophil', 'Eosinophil', 'Erythroblast', 'Immature granulocytes', 'Lymphocyte', 'Monocyte', 'Neutrophil', 'Platelet']

# %%
# Check the shape of the loaded images
print(f"Loaded X_train images shape: {X_train.shape}")
print(f"Loaded y_train labels shape: {y_train.shape}")
print(f"Min value X_train: {X_train.min()}, Max value X_train: {X_train.max()}\n")

print(f"Loaded X_val images shape: {X_val.shape}")
print(f"Loaded y_val labels shape: {y_val.shape}")
print(f"Min value X_val: {X_val.min()}, Max value X_val: {X_val.max()}\n")

print(f"Loaded X_test images shape: {X_test.shape}")
print(f"Loaded y_test labels shape: {y_test.shape}")
print(f"Min value X_test: {X_test.min()}, Max value X_test: {X_test.max()}\n")

print(f"Loaded X_test_augmented images shape: {X_test_augmented.shape}")
print(f"Loaded y_test_augmented labels shape: {y_test_augmented.shape}")
print(f"Min value X_test_augmented: {X_test_augmented.min()}, Max value X_test_augmented: {X_test_augmented.max()}")
# Out:
# Loaded X_train images shape: (21513, 96, 96, 3)
# Loaded y_train labels shape: (21513, 8)
# Min value X_train: 0.0, Max value X_train: 255.0
#
# Loaded X_val images shape: (7173, 96, 96, 3)
# Loaded y_val labels shape: (7173, 8)
# Min value X_val: 0.0, Max value X_val: 255.0
#
# Loaded X_test images shape: (2391, 96, 96, 3)
# Loaded y_test labels shape: (2391, 8)
# Min value X_test: 0, Max value X_test: 255
#
# Loaded X_test_augmented images shape: (9564, 96, 96, 3)
# Loaded y_test_augmented labels shape: (9564, 8)
# Min value X_test_augmented: 0.0, Max value X_test_augmented: 255.0

# %% [markdown]
# ## 🔎 Inspect Data

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_train)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_train[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_train[idx])
    label = labels[label_index]

    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_val)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_val[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_val[idx])
    label = labels[label_index]
    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_test)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_test[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_test[idx])
    label = labels[label_index]
    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Number of images to display
num_img = 10

# Set a random seed for reproducibility
random.seed(seed)

# Select random indices
random_indices = random.sample(range(len(X_test_augmented)), num_img)

# Create subplots
fig, axes = plt.subplots(1, num_img, figsize=(20, 5))

for i, idx in enumerate(random_indices):
    ax = axes[i]

    # Get the image and cast it to uint8
    image = X_test_augmented[idx]
    image_uint8 = (image).astype(np.uint8)

    # Handle color and grayscale images
    if image_uint8.shape[-1] == 1:
        image_uint8 = np.squeeze(image_uint8, axis=-1)
        ax.imshow(image_uint8, cmap='gray', vmin=0, vmax=255)
    else:
        ax.imshow(image_uint8)

    # Set the title based on the label
    label_index = np.argmax(y_test_augmented[idx])
    label = labels[label_index]
    ax.set_title(f'{label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Class balancing

# %%
# Flatten the labels to class indices since they're in one-hot encoding
y_train_flat = np.argmax(y_train, axis=1)

# Calculate class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_flat),
    y=y_train_flat
)

# Convert the class weights to a dictionary
class_weight_dict = dict(enumerate(class_weights))

# Print the calculated class weights
print("Class weights:")
for class_index, weight in class_weight_dict.items():
    print(f"Class {class_index}: Weight {weight:.2f}")
# Out:
# Class weights:
# Class 0: Weight 1.75
# Class 1: Weight 0.69
# Class 2: Weight 1.38
# Class 3: Weight 0.74
# Class 4: Weight 1.76
# Class 5: Weight 1.50
# Class 6: Weight 0.64
# Class 7: Weight 0.91

# %% [markdown]
# ## 🧮 Define Network Parameters

# %%
# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %%
# Number of training epochs
epochs = 200

# Batch size for training
batch_size = 64

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
# Out:
# Epochs: 200
# Batch Size: 64

# %% [markdown]
# ## **Inverted Residual Bottleneck with SE (MobileNetV3, 2019)**
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img src="https://www.researchgate.net/publication/378806327/figure/fig5/AS:11431281232045939@1711587010842/MobileNetV3-network-structure.jpg" width="600"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---
#
#
#
#
#
#
#
# **Key Features and Achievements**
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# *   Pioneered platform-aware Neural Architecture Search (NAS)
#
#
#
#
#
#
#
# *   Introduced hardware-aware network design
#
#
#
#
#
#
#
# *   Combined manual design with automated search
#
#
#
#
#
#
#
# *   Optimized for mobile inference latency
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Key building block:**
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# *   "Enhanced" Inverted Residual Block (Expansion ratio tuned per block, SE module redesigned for efficiency, Hard-Swish activation function(h-swish))
#
#
#
#
#
#
#
# *   Efficient last stage design (Reduced channels in first layer, moved SE to cheaper layers, platform-aware operator selection)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Impact:**
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# *   Set new SOTA for mobile networks
#
#
#
#
#
#
#
# *   Demonstrated successful NAS and human design fusion
#
#
#
#
#
#
#
# *   Showed importance of hardware-aware architecture design
#
#
#
#
#
#
#
# *   Influenced automated architecture search methods
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **📜 Paper:** ["Searching for MobileNetV3", Howard et al.](https://arxiv.org/pdf/1905.02244)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img src="https://drive.google.com/uc?export=view&id=1EcBp60nEorTDLROT_1L4a4Mvw9kLdKqd" width="300"/>

# %% [markdown]
# ## 🛠️ Transfer Learning
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img src="https://radekosmulski.com/content/images/2021/08/imagenet_banner.jpeg" width="700"/>

# %%
# Initialise ConvNeXtBase model with pretrained weights, for transfer learning

mymodel = tf.keras.applications.ConvNeXtBase(
        include_top = False,
        include_preprocessing = True,
        weights = "imagenet",
        input_shape = input_shape,
        pooling = "avg",
    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Display a summary of the model architecture
mymodel.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(mymodel, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### Model with 1 dense layer

# %%
# Freeze all layers in ConvNeXtBase to use it solely as a feature extractor
mymodel.trainable = False  # Freeze pretrained weights

# Define input layer with shape matching the input images
inputs = tfk.Input(shape=input_shape, name='input_layer')

# Pass inputs through the MobileNetV3Small feature extractor
x = mymodel(inputs)
print("Shape after ConvNeXtBase:", x.shape)

# Add a Dropout layer for regularisation
x = tfkl.Dropout(0.3, name='dropout1')(x)
print("Shape after Dropout1:", x.shape)

# Add a final Dense layer for classification with softmax activation
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense1')(x)
print("Shape after Dense1:", outputs.shape)

# Define the complete model linking input and output
tl_model1 = tfk.Model(inputs=inputs, outputs=outputs, name='model1')

# Compile the model with categorical cross-entropy loss and Adam optimiser
tl_model1.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])  # default learning rate = 0.001
# Out:
# Shape after ConvNeXtBase: (None, 1024)
# Shape after Dropout1: (None, 1024)
# Shape after Dense1: (None, 8)

# %%
# Display a summary of the model architecture
tl_model1.summary()

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(tl_model1, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### Model with 2 dense layer

# %%
# Freeze all layers in MobileNetV3Small to use it solely as a feature extractor
mymodel.trainable = False

# Define input layer with shape matching the input images
inputs = tfk.Input(shape=input_shape, name='input_layer')

# Pass inputs through the MobileNetV3Small feature extractor
x = mymodel(inputs)
print("Shape after MobileNetV3Small:", x.shape)

# Add a Dense layer without activation
x = tfkl.Dense(512, name='dense1')(x)
print("Shape after Dense1:", x.shape)

# Add Batch Normalization
x = tfkl.BatchNormalization(name='batch_norm1')(x)
print("Shape after BatchNorm1:", x.shape)

# Add ReLU activation
x = tfkl.Activation('relu', name='activation1')(x)
print("Shape after Activation1:", x.shape)

# Add a Dropout layer for regularisation
x = tfkl.Dropout(0.3, name='dropout1')(x)
print("Shape after Dropout1:", x.shape)

# Add final Dense layer for classification with softmax activation
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense3')(x)
print("Shape after Dense3:", outputs.shape)

# Define the complete model linking input and output
tl_model2 = tfk.Model(inputs=inputs, outputs=outputs, name='model2')

# Compile the model with categorical cross-entropy loss and Adam optimiser
tl_model2.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])  # default learning rate = 0.001
# Out:
# Shape after MobileNetV3Small: (None, 1024)
# Shape after Dense1: (None, 512)
# Shape after BatchNorm1: (None, 512)
# Shape after Activation1: (None, 512)
# Shape after Dropout1: (None, 512)
# Shape after Dense3: (None, 8)

# %%
# Display a summary of the model architecture
tl_model2.summary()

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(tl_model2, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### Model with 3 dense layers

# %%
# Freeze all layers in MobileNetV3Small to use it solely as a feature extractor
mymodel.trainable = False

# Define input layer with shape matching the input images
inputs = tfk.Input(shape=input_shape, name='input_layer')

# Pass inputs through the MobileNetV3Small feature extractor
x = mymodel(inputs)
print("Shape after ConvNeXtBase:", x.shape)

# Add a Dense layer without activation
x = tfkl.Dense(512, name='dense1')(x)
print("Shape after Dense1:", x.shape)

# Add Batch Normalization
x = tfkl.BatchNormalization(name='batch_norm1')(x)
print("Shape after BatchNorm1:", x.shape)

# Add ReLU activation
x = tfkl.Activation('relu', name='activation1')(x)
print("Shape after Activation1:", x.shape)

# Add a Dropout layer for regularisation
x = tfkl.Dropout(0.3, name='dropout1')(x)
print("Shape after Dropout1:", x.shape)

# Add another Dense layer without activation
x = tfkl.Dense(256, name='dense2')(x)
print("Shape after Dense2:", x.shape)

# Add Batch Normalization
x = tfkl.BatchNormalization(name='batch_norm2')(x)
print("Shape after BatchNorm2:", x.shape)

# Add ReLU activation
x = tfkl.Activation('relu', name='activation2')(x)
print("Shape after Activation2:", x.shape)

# Add another Dropout layer for regularisation
x = tfkl.Dropout(0.3, name='dropout2')(x)
print("Shape after Dropout2:", x.shape)

# Add final Dense layer for classification with softmax activation
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense3')(x)
print("Shape after Dense3:", outputs.shape)

# Define the complete model linking input and output
tl_model3 = tfk.Model(inputs=inputs, outputs=outputs, name='model3')

# Compile the model with categorical cross-entropy loss and Adam optimiser
tl_model3.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])  # default learning rate = 0.001
# Out:
# Shape after ConvNeXtBase: (None, 1024)
# Shape after Dense1: (None, 512)
# Shape after BatchNorm1: (None, 512)
# Shape after Activation1: (None, 512)
# Shape after Dropout1: (None, 512)
# Shape after Dense2: (None, 256)
# Shape after BatchNorm2: (None, 256)
# Shape after Activation2: (None, 256)
# Shape after Dropout2: (None, 256)
# Shape after Dense3: (None, 8)

# %%
# Display a summary of the model architecture
tl_model3.summary()

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(tl_model3, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Define the EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',       # Metric to monitor
    mode='max',                   # Mode ('max' for accuracy)
    patience=20,                  # Number of epochs with no improvement before stopping
    restore_best_weights=True     # Restore the model weights from the epoch with the best value of the monitored metric
)

# %%
# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',           # Metric to monitor
    factor=0.5,                   # Factor by which the learning rate will be reduced
    patience=5,                   # Number of epochs with no improvement before reducing learning rate
    verbose=1,                    # Verbosity mode (0 = silent, 1 = updates messages)
    min_lr=1e-6                   # Lower bound on the learning rate
)

# %%
# Train the model 1
tl_history1 = tl_model1.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy1 = round(max(tl_history1['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 1: {final_val_accuracy1}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = f'ConvNeXtBase1_{final_val_accuracy1}.keras'
tl_model1.save(model_filename)

# Free memory by deleting the model instance
del tl_model1
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 71s 127ms/step - accuracy: 0.4126 - loss: 1.7590 - val_accuracy: 0.6784 - val_loss: 0.9407 - learning_rate: 0.0010
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6247 - loss: 1.0861 - val_accuracy: 0.7090 - val_loss: 0.8455 - learning_rate: 0.0010
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6657 - loss: 0.9782 - val_accuracy: 0.7281 - val_loss: 0.7937 - learning_rate: 0.0010
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6773 - loss: 0.9461 - val_accuracy: 0.7353 - val_loss: 0.7701 - learning_rate: 0.0010
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6816 - loss: 0.9131 - val_accuracy: 0.7358 - val_loss: 0.7648 - learning_rate: 0.0010
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6921 - loss: 0.8977 - val_accuracy: 0.7447 - val_loss: 0.7552 - learning_rate: 0.0010
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6919 - loss: 0.8920 - val_accuracy: 0.7436 - val_loss: 0.7576 - learning_rate: 0.0010
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6903 - loss: 0.8978 - val_accuracy: 0.7524 - val_loss: 0.7346 - learning_rate: 0.0010
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6928 - loss: 0.8867 - val_accuracy: 0.7527 - val_loss: 0.7363 - learning_rate: 0.0010
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6935 - loss: 0.8822 - val_accuracy: 0.7484 - val_loss: 0.7387 - learning_rate: 0.0010
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7010 - loss: 0.8702 - val_accuracy: 0.7530 - val_loss: 0.7340 - learning_rate: 0.0010
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6950 - loss: 0.8821 - val_accuracy: 0.7534 - val_loss: 0.7269 - learning_rate: 0.0010
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6961 - loss: 0.8902 - val_accuracy: 0.7518 - val_loss: 0.7301 - learning_rate: 0.0010
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6942 - loss: 0.8945 - val_accuracy: 0.7516 - val_loss: 0.7363 - learning_rate: 0.0010
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6904 - loss: 0.8937 - val_accuracy: 0.7534 - val_loss: 0.7271 - learning_rate: 0.0010
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6982 - loss: 0.8861 - val_accuracy: 0.7548 - val_loss: 0.7224 - learning_rate: 0.0010
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6946 - loss: 0.8872 - val_accuracy: 0.7474 - val_loss: 0.7416 - learning_rate: 0.0010
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6938 - loss: 0.8895 - val_accuracy: 0.7507 - val_loss: 0.7298 - learning_rate: 0.0010
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6967 - loss: 0.8885 - val_accuracy: 0.7530 - val_loss: 0.7298 - learning_rate: 0.0010
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7006 - loss: 0.8858 - val_accuracy: 0.7499 - val_loss: 0.7415 - learning_rate: 0.0010
# Epoch 21/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6933 - loss: 0.8808
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.6933 - loss: 0.8808 - val_accuracy: 0.7535 - val_loss: 0.7237 - learning_rate: 0.0010
# Epoch 22/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7065 - loss: 0.8595 - val_accuracy: 0.7535 - val_loss: 0.7213 - learning_rate: 5.0000e-04
# Epoch 23/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7084 - loss: 0.8495 - val_accuracy: 0.7528 - val_loss: 0.7332 - learning_rate: 5.0000e-04
# Epoch 24/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7120 - loss: 0.8430 - val_accuracy: 0.7491 - val_loss: 0.7372 - learning_rate: 5.0000e-04
# Epoch 25/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7039 - loss: 0.8521 - val_accuracy: 0.7531 - val_loss: 0.7219 - learning_rate: 5.0000e-04
# Epoch 26/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7003 - loss: 0.8546 - val_accuracy: 0.7530 - val_loss: 0.7268 - learning_rate: 5.0000e-04
# Epoch 27/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7047 - loss: 0.8404
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7047 - loss: 0.8404 - val_accuracy: 0.7520 - val_loss: 0.7362 - learning_rate: 5.0000e-04
# Epoch 28/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7062 - loss: 0.8380 - val_accuracy: 0.7583 - val_loss: 0.7187 - learning_rate: 2.5000e-04
# Epoch 29/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7158 - loss: 0.8315 - val_accuracy: 0.7567 - val_loss: 0.7228 - learning_rate: 2.5000e-04
# Epoch 30/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7125 - loss: 0.8343 - val_accuracy: 0.7570 - val_loss: 0.7229 - learning_rate: 2.5000e-04
# Epoch 31/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7112 - loss: 0.8273 - val_accuracy: 0.7573 - val_loss: 0.7174 - learning_rate: 2.5000e-04
# Epoch 32/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7099 - loss: 0.8304 - val_accuracy: 0.7562 - val_loss: 0.7207 - learning_rate: 2.5000e-04
# Epoch 33/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7130 - loss: 0.8359 - val_accuracy: 0.7601 - val_loss: 0.7201 - learning_rate: 2.5000e-04
# Epoch 34/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7081 - loss: 0.8272 - val_accuracy: 0.7556 - val_loss: 0.7249 - learning_rate: 2.5000e-04
# Epoch 35/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7108 - loss: 0.8335 - val_accuracy: 0.7588 - val_loss: 0.7171 - learning_rate: 2.5000e-04
# Epoch 36/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7099 - loss: 0.8290 - val_accuracy: 0.7599 - val_loss: 0.7188 - learning_rate: 2.5000e-04
# Epoch 37/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7130 - loss: 0.8334 - val_accuracy: 0.7562 - val_loss: 0.7251 - learning_rate: 2.5000e-04
# Epoch 38/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7112 - loss: 0.8260 - val_accuracy: 0.7591 - val_loss: 0.7204 - learning_rate: 2.5000e-04
# Epoch 39/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7212 - loss: 0.8157 - val_accuracy: 0.7595 - val_loss: 0.7151 - learning_rate: 2.5000e-04
# Epoch 40/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7158 - loss: 0.8253 - val_accuracy: 0.7580 - val_loss: 0.7171 - learning_rate: 2.5000e-04
# Epoch 41/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7162 - loss: 0.8125 - val_accuracy: 0.7590 - val_loss: 0.7180 - learning_rate: 2.5000e-04
# Epoch 42/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7124 - loss: 0.8243 - val_accuracy: 0.7587 - val_loss: 0.7197 - learning_rate: 2.5000e-04
# Epoch 43/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7172 - loss: 0.8161 - val_accuracy: 0.7609 - val_loss: 0.7194 - learning_rate: 2.5000e-04
# Epoch 44/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7131 - loss: 0.8220 - val_accuracy: 0.7620 - val_loss: 0.7146 - learning_rate: 2.5000e-04
# Epoch 45/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7204 - loss: 0.8180 - val_accuracy: 0.7584 - val_loss: 0.7188 - learning_rate: 2.5000e-04
# Epoch 46/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7157 - loss: 0.8117 - val_accuracy: 0.7581 - val_loss: 0.7244 - learning_rate: 2.5000e-04
# Epoch 47/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7186 - loss: 0.8112 - val_accuracy: 0.7577 - val_loss: 0.7179 - learning_rate: 2.5000e-04
# Epoch 48/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7167 - loss: 0.8194 - val_accuracy: 0.7574 - val_loss: 0.7201 - learning_rate: 2.5000e-04
# Epoch 49/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7073 - loss: 0.8340
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7074 - loss: 0.8340 - val_accuracy: 0.7623 - val_loss: 0.7157 - learning_rate: 2.5000e-04
# Epoch 50/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7144 - loss: 0.8153 - val_accuracy: 0.7588 - val_loss: 0.7173 - learning_rate: 1.2500e-04
# Epoch 51/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7160 - loss: 0.8167 - val_accuracy: 0.7587 - val_loss: 0.7168 - learning_rate: 1.2500e-04
# Epoch 52/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7207 - loss: 0.8098 - val_accuracy: 0.7584 - val_loss: 0.7182 - learning_rate: 1.2500e-04
# Epoch 53/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7144 - loss: 0.8207 - val_accuracy: 0.7577 - val_loss: 0.7231 - learning_rate: 1.2500e-04
# Epoch 54/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7138 - loss: 0.8145
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7139 - loss: 0.8145 - val_accuracy: 0.7588 - val_loss: 0.7201 - learning_rate: 1.2500e-04
# Epoch 55/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7178 - loss: 0.8169 - val_accuracy: 0.7578 - val_loss: 0.7217 - learning_rate: 6.2500e-05
# Epoch 56/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7164 - loss: 0.8061 - val_accuracy: 0.7585 - val_loss: 0.7188 - learning_rate: 6.2500e-05
# Epoch 57/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7207 - loss: 0.8040 - val_accuracy: 0.7587 - val_loss: 0.7193 - learning_rate: 6.2500e-05
# Epoch 58/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7160 - loss: 0.8101 - val_accuracy: 0.7574 - val_loss: 0.7200 - learning_rate: 6.2500e-05
# Epoch 59/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7185 - loss: 0.8093
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7185 - loss: 0.8092 - val_accuracy: 0.7580 - val_loss: 0.7196 - learning_rate: 6.2500e-05
# Epoch 60/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7159 - loss: 0.8033 - val_accuracy: 0.7580 - val_loss: 0.7199 - learning_rate: 3.1250e-05
# Epoch 61/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7185 - loss: 0.8071 - val_accuracy: 0.7576 - val_loss: 0.7199 - learning_rate: 3.1250e-05
# Epoch 62/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7191 - loss: 0.8114 - val_accuracy: 0.7577 - val_loss: 0.7191 - learning_rate: 3.1250e-05
# Epoch 63/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7172 - loss: 0.8089 - val_accuracy: 0.7587 - val_loss: 0.7195 - learning_rate: 3.1250e-05
# Epoch 64/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7115 - loss: 0.8254
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7115 - loss: 0.8253 - val_accuracy: 0.7588 - val_loss: 0.7188 - learning_rate: 3.1250e-05
# Epoch 65/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7187 - loss: 0.8037 - val_accuracy: 0.7595 - val_loss: 0.7175 - learning_rate: 1.5625e-05
# Epoch 66/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7180 - loss: 0.8066 - val_accuracy: 0.7583 - val_loss: 0.7182 - learning_rate: 1.5625e-05
# Epoch 67/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7193 - loss: 0.8048 - val_accuracy: 0.7588 - val_loss: 0.7175 - learning_rate: 1.5625e-05
# Epoch 68/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7150 - loss: 0.8059 - val_accuracy: 0.7590 - val_loss: 0.7173 - learning_rate: 1.5625e-05
# Epoch 69/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7180 - loss: 0.8110
# Epoch 69: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7180 - loss: 0.8109 - val_accuracy: 0.7588 - val_loss: 0.7170 - learning_rate: 1.5625e-05
# Final validation accuracy 1: 76.23%

# %%
# Train the model 2
tl_history2 = tl_model2.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy2 = round(max(tl_history2['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 2: {final_val_accuracy2}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = f'ConvNeXtBase2_{final_val_accuracy2}.keras'
tl_model2.save(model_filename)

# Free memory by deleting the model instance
del tl_model2
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 55s 99ms/step - accuracy: 0.5513 - loss: 1.3068 - val_accuracy: 0.7157 - val_loss: 0.8134 - learning_rate: 0.0010
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7273 - loss: 0.7698 - val_accuracy: 0.7390 - val_loss: 0.7530 - learning_rate: 0.0010
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7737 - loss: 0.6339 - val_accuracy: 0.7478 - val_loss: 0.7347 - learning_rate: 0.0010
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8049 - loss: 0.5520 - val_accuracy: 0.7531 - val_loss: 0.7338 - learning_rate: 0.0010
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8313 - loss: 0.4740 - val_accuracy: 0.7552 - val_loss: 0.7384 - learning_rate: 0.0010
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8545 - loss: 0.4137 - val_accuracy: 0.7627 - val_loss: 0.7398 - learning_rate: 0.0010
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8702 - loss: 0.3577 - val_accuracy: 0.7612 - val_loss: 0.7580 - learning_rate: 0.0010
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.8863 - loss: 0.3123 - val_accuracy: 0.7592 - val_loss: 0.7781 - learning_rate: 0.0010
# Epoch 9/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8988 - loss: 0.2767
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8988 - loss: 0.2766 - val_accuracy: 0.7580 - val_loss: 0.8072 - learning_rate: 0.0010
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9141 - loss: 0.2268 - val_accuracy: 0.7725 - val_loss: 0.7591 - learning_rate: 5.0000e-04
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9399 - loss: 0.1679 - val_accuracy: 0.7743 - val_loss: 0.7810 - learning_rate: 5.0000e-04
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9471 - loss: 0.1464 - val_accuracy: 0.7786 - val_loss: 0.7877 - learning_rate: 5.0000e-04
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9527 - loss: 0.1287 - val_accuracy: 0.7675 - val_loss: 0.8356 - learning_rate: 5.0000e-04
# Epoch 14/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9613 - loss: 0.1143
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9613 - loss: 0.1143 - val_accuracy: 0.7751 - val_loss: 0.8405 - learning_rate: 5.0000e-04
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9655 - loss: 0.1011 - val_accuracy: 0.7751 - val_loss: 0.8276 - learning_rate: 2.5000e-04
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9718 - loss: 0.0820 - val_accuracy: 0.7806 - val_loss: 0.8331 - learning_rate: 2.5000e-04
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9769 - loss: 0.0723 - val_accuracy: 0.7782 - val_loss: 0.8557 - learning_rate: 2.5000e-04
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9776 - loss: 0.0700 - val_accuracy: 0.7757 - val_loss: 0.8572 - learning_rate: 2.5000e-04
# Epoch 19/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9823 - loss: 0.0612
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9823 - loss: 0.0612 - val_accuracy: 0.7781 - val_loss: 0.8846 - learning_rate: 2.5000e-04
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9807 - loss: 0.0610 - val_accuracy: 0.7778 - val_loss: 0.8760 - learning_rate: 1.2500e-04
# Epoch 21/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9836 - loss: 0.0534 - val_accuracy: 0.7786 - val_loss: 0.8835 - learning_rate: 1.2500e-04
# Epoch 22/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9845 - loss: 0.0496 - val_accuracy: 0.7818 - val_loss: 0.8845 - learning_rate: 1.2500e-04
# Epoch 23/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9869 - loss: 0.0464 - val_accuracy: 0.7767 - val_loss: 0.8998 - learning_rate: 1.2500e-04
# Epoch 24/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9866 - loss: 0.0465
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9866 - loss: 0.0465 - val_accuracy: 0.7785 - val_loss: 0.9067 - learning_rate: 1.2500e-04
# Epoch 25/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9868 - loss: 0.0439 - val_accuracy: 0.7829 - val_loss: 0.8971 - learning_rate: 6.2500e-05
# Epoch 26/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9899 - loss: 0.0395 - val_accuracy: 0.7829 - val_loss: 0.9019 - learning_rate: 6.2500e-05
# Epoch 27/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9891 - loss: 0.0391 - val_accuracy: 0.7815 - val_loss: 0.9095 - learning_rate: 6.2500e-05
# Epoch 28/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9894 - loss: 0.0389 - val_accuracy: 0.7806 - val_loss: 0.9135 - learning_rate: 6.2500e-05
# Epoch 29/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9902 - loss: 0.0367
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9902 - loss: 0.0367 - val_accuracy: 0.7807 - val_loss: 0.9166 - learning_rate: 6.2500e-05
# Epoch 30/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9901 - loss: 0.0355 - val_accuracy: 0.7838 - val_loss: 0.9175 - learning_rate: 3.1250e-05
# Epoch 31/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9913 - loss: 0.0347 - val_accuracy: 0.7841 - val_loss: 0.9198 - learning_rate: 3.1250e-05
# Epoch 32/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9916 - loss: 0.0326 - val_accuracy: 0.7845 - val_loss: 0.9218 - learning_rate: 3.1250e-05
# Epoch 33/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9913 - loss: 0.0329 - val_accuracy: 0.7829 - val_loss: 0.9263 - learning_rate: 3.1250e-05
# Epoch 34/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9923 - loss: 0.0312
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9923 - loss: 0.0312 - val_accuracy: 0.7839 - val_loss: 0.9312 - learning_rate: 3.1250e-05
# Epoch 35/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9927 - loss: 0.0301 - val_accuracy: 0.7849 - val_loss: 0.9316 - learning_rate: 1.5625e-05
# Epoch 36/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9913 - loss: 0.0315 - val_accuracy: 0.7836 - val_loss: 0.9310 - learning_rate: 1.5625e-05
# Epoch 37/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9915 - loss: 0.0321 - val_accuracy: 0.7854 - val_loss: 0.9308 - learning_rate: 1.5625e-05
# Epoch 38/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9921 - loss: 0.0305 - val_accuracy: 0.7846 - val_loss: 0.9339 - learning_rate: 1.5625e-05
# Epoch 39/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9932 - loss: 0.0290
# Epoch 39: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9932 - loss: 0.0291 - val_accuracy: 0.7845 - val_loss: 0.9356 - learning_rate: 1.5625e-05
# Epoch 40/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9913 - loss: 0.0303 - val_accuracy: 0.7852 - val_loss: 0.9361 - learning_rate: 7.8125e-06
# Epoch 41/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9938 - loss: 0.0290 - val_accuracy: 0.7850 - val_loss: 0.9360 - learning_rate: 7.8125e-06
# Epoch 42/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9928 - loss: 0.0293 - val_accuracy: 0.7853 - val_loss: 0.9372 - learning_rate: 7.8125e-06
# Epoch 43/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9931 - loss: 0.0289 - val_accuracy: 0.7856 - val_loss: 0.9375 - learning_rate: 7.8125e-06
# Epoch 44/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9933 - loss: 0.0291
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9933 - loss: 0.0291 - val_accuracy: 0.7852 - val_loss: 0.9384 - learning_rate: 7.8125e-06
# Epoch 45/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9926 - loss: 0.0290 - val_accuracy: 0.7857 - val_loss: 0.9386 - learning_rate: 3.9063e-06
# Epoch 46/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9925 - loss: 0.0282 - val_accuracy: 0.7857 - val_loss: 0.9388 - learning_rate: 3.9063e-06
# Epoch 47/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9931 - loss: 0.0287 - val_accuracy: 0.7856 - val_loss: 0.9394 - learning_rate: 3.9063e-06
# Epoch 48/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9915 - loss: 0.0288 - val_accuracy: 0.7854 - val_loss: 0.9398 - learning_rate: 3.9063e-06
# Epoch 49/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9931 - loss: 0.0293
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9931 - loss: 0.0293 - val_accuracy: 0.7853 - val_loss: 0.9404 - learning_rate: 3.9063e-06
# Epoch 50/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9932 - loss: 0.0282 - val_accuracy: 0.7852 - val_loss: 0.9408 - learning_rate: 1.9531e-06
# Epoch 51/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9933 - loss: 0.0282 - val_accuracy: 0.7852 - val_loss: 0.9411 - learning_rate: 1.9531e-06
# Epoch 52/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9935 - loss: 0.0273 - val_accuracy: 0.7857 - val_loss: 0.9412 - learning_rate: 1.9531e-06
# Epoch 53/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9929 - loss: 0.0283 - val_accuracy: 0.7857 - val_loss: 0.9412 - learning_rate: 1.9531e-06
# Epoch 54/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9930 - loss: 0.0280
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9930 - loss: 0.0280 - val_accuracy: 0.7849 - val_loss: 0.9412 - learning_rate: 1.9531e-06
# Epoch 55/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9936 - loss: 0.0282 - val_accuracy: 0.7846 - val_loss: 0.9412 - learning_rate: 1.0000e-06
# Epoch 56/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9938 - loss: 0.0278 - val_accuracy: 0.7846 - val_loss: 0.9413 - learning_rate: 1.0000e-06
# Epoch 57/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9934 - loss: 0.0280 - val_accuracy: 0.7849 - val_loss: 0.9413 - learning_rate: 1.0000e-06
# Epoch 58/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9926 - loss: 0.0292 - val_accuracy: 0.7846 - val_loss: 0.9414 - learning_rate: 1.0000e-06
# Epoch 59/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9927 - loss: 0.0289 - val_accuracy: 0.7847 - val_loss: 0.9416 - learning_rate: 1.0000e-06
# Epoch 60/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9936 - loss: 0.0278 - val_accuracy: 0.7849 - val_loss: 0.9417 - learning_rate: 1.0000e-06
# Epoch 61/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9930 - loss: 0.0293 - val_accuracy: 0.7847 - val_loss: 0.9418 - learning_rate: 1.0000e-06
# Epoch 62/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9931 - loss: 0.0271 - val_accuracy: 0.7850 - val_loss: 0.9419 - learning_rate: 1.0000e-06
# Epoch 63/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9943 - loss: 0.0261 - val_accuracy: 0.7854 - val_loss: 0.9420 - learning_rate: 1.0000e-06
# Epoch 64/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9933 - loss: 0.0273 - val_accuracy: 0.7852 - val_loss: 0.9420 - learning_rate: 1.0000e-06
# Epoch 65/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9934 - loss: 0.0277 - val_accuracy: 0.7850 - val_loss: 0.9420 - learning_rate: 1.0000e-06
# Final validation accuracy 2: 78.57%

# %%
# Train the model 3
tl_history3 = tl_model3.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy3 = round(max(tl_history3['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 3: {final_val_accuracy3}%')

# Save the trained model to a file, including final accuracy in the filename
model_filename = f'ConvNeXtBase3_{final_val_accuracy3}.keras'
tl_model3.save(model_filename)

# Free memory by deleting the model instance
del tl_model3
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 59s 107ms/step - accuracy: 0.5053 - loss: 1.4249 - val_accuracy: 0.7132 - val_loss: 0.8107 - learning_rate: 0.0010
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.6924 - loss: 0.8779 - val_accuracy: 0.7273 - val_loss: 0.7604 - learning_rate: 0.0010
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7376 - loss: 0.7391 - val_accuracy: 0.7464 - val_loss: 0.7303 - learning_rate: 0.0010
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.7650 - loss: 0.6529 - val_accuracy: 0.7513 - val_loss: 0.7220 - learning_rate: 0.0010
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7914 - loss: 0.5780 - val_accuracy: 0.7559 - val_loss: 0.7125 - learning_rate: 0.0010
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8044 - loss: 0.5227 - val_accuracy: 0.7404 - val_loss: 0.7814 - learning_rate: 0.0010
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8274 - loss: 0.4674 - val_accuracy: 0.7484 - val_loss: 0.7693 - learning_rate: 0.0010
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8391 - loss: 0.4244 - val_accuracy: 0.7690 - val_loss: 0.7552 - learning_rate: 0.0010
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8502 - loss: 0.3865 - val_accuracy: 0.7465 - val_loss: 0.8224 - learning_rate: 0.0010
# Epoch 10/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8704 - loss: 0.3381
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8705 - loss: 0.3380 - val_accuracy: 0.7486 - val_loss: 0.8497 - learning_rate: 0.0010
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.8903 - loss: 0.2808 - val_accuracy: 0.7687 - val_loss: 0.7842 - learning_rate: 5.0000e-04
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9135 - loss: 0.2179 - val_accuracy: 0.7696 - val_loss: 0.8141 - learning_rate: 5.0000e-04
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.9241 - loss: 0.1862 - val_accuracy: 0.7779 - val_loss: 0.8203 - learning_rate: 5.0000e-04
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9299 - loss: 0.1726 - val_accuracy: 0.7722 - val_loss: 0.8657 - learning_rate: 5.0000e-04
# Epoch 15/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9341 - loss: 0.1625
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9341 - loss: 0.1625 - val_accuracy: 0.7736 - val_loss: 0.8998 - learning_rate: 5.0000e-04
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9437 - loss: 0.1366 - val_accuracy: 0.7754 - val_loss: 0.8847 - learning_rate: 2.5000e-04
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9538 - loss: 0.1108 - val_accuracy: 0.7758 - val_loss: 0.8998 - learning_rate: 2.5000e-04
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9586 - loss: 0.1026 - val_accuracy: 0.7783 - val_loss: 0.9211 - learning_rate: 2.5000e-04
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9633 - loss: 0.0911 - val_accuracy: 0.7792 - val_loss: 0.9319 - learning_rate: 2.5000e-04
# Epoch 20/200
# 335/337 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9652 - loss: 0.0873
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 16s 48ms/step - accuracy: 0.9652 - loss: 0.0874 - val_accuracy: 0.7739 - val_loss: 0.9629 - learning_rate: 2.5000e-04
# Final validation accuracy 3: 77.92%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(tl_history1['loss'], label='Training loss 1', alpha=.8)
plt.plot(tl_history1['val_loss'], label='Validation loss 1', alpha=.8)
plt.plot(tl_history2['loss'], label='Training loss 2', alpha=.8)
plt.plot(tl_history2['val_loss'], label='Validation loss 2', alpha=.8)
plt.plot(tl_history3['loss'], label='Training loss 3', alpha=.8)
plt.plot(tl_history3['val_loss'], label='Validation loss 3', alpha=.8)
plt.title('Loss before fine tuning')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(tl_history1['accuracy'], label='Training accuracy 1', alpha=.8)
plt.plot(tl_history1['val_accuracy'], label='Validation accuracy 1', alpha=.8)
plt.plot(tl_history2['accuracy'], label='Training accuracy 2', alpha=.8)
plt.plot(tl_history2['val_accuracy'], label='Validation accuracy 2', alpha=.8)
plt.plot(tl_history3['accuracy'], label='Training accuracy 3', alpha=.8)
plt.plot(tl_history3['val_accuracy'], label='Validation accuracy 3', alpha=.8)
plt.title('Accuracy before fine tuning')
plt.legend()
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# ## 🛠️ Fine Tuning
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img src="https://www.researchgate.net/publication/359405075/figure/fig2/AS:1182999492214798@1659060466845/Concept-of-fine-tuning-and-feature-extraction_W640.jpg" width="700"/>

# %%
# Re-load the model after transfer learning
ft_model1 = tfk.models.load_model('ConvNeXtBase1_76.23.keras') # model 1
ft_model2 = tfk.models.load_model('ConvNeXtBase2_78.57.keras') # model 2
ft_model3 = tfk.models.load_model('ConvNeXtBase3_77.92.keras') # model 3

# %%
# Set the MobileNetV3Small model layers as trainable
ft_model1.get_layer('convnext_base').trainable = True
ft_model2.get_layer('convnext_base').trainable = True
ft_model3.get_layer('convnext_base').trainable = True

# %%
# Unfreeze the layers in the last two stages
trainable = False

for layer in ft_model1.get_layer('convnext_base').layers:
    if "stage_2" in layer.name or "stage_3" in layer.name:
        trainable = True
    layer.trainable = trainable

# Set the BatchNorm layers as non-trainable
for layer in ft_model1.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False

# Unfreeze the layers in the last two stages
trainable = False

for layer in ft_model2.get_layer('convnext_base').layers:
    if "stage_2" in layer.name or "stage_3" in layer.name:
        trainable = True
    layer.trainable = trainable

# Set the BatchNorm layers as non-trainable
for layer in ft_model2.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False

# Unfreeze the layers in the last two stages
trainable = False

for layer in ft_model3.get_layer('convnext_base').layers:
    if "stage_2" in layer.name or "stage_3" in layer.name:
        trainable = True
    layer.trainable = trainable

# Set the BatchNorm layers as non-trainable
for layer in ft_model3.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False



# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model1.get_layer('convnext_base').layers):
    print(i, layer.name, layer.trainable)

for i, layer in enumerate(ft_model2.get_layer('convnext_base').layers):
    print(i, layer.name, layer.trainable)

for i, layer in enumerate(ft_model3.get_layer('convnext_base').layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_layer False
# 1 convnext_base_prestem_normalization False
# 2 convnext_base_stem False
# 3 convnext_base_stage_0_block_0_depthwise_conv False
# 4 convnext_base_stage_0_block_0_layernorm False
# 5 convnext_base_stage_0_block_0_pointwise_conv_1 False
# 6 convnext_base_stage_0_block_0_gelu False
# 7 convnext_base_stage_0_block_0_pointwise_conv_2 False
# 8 convnext_base_stage_0_block_0_layer_scale False
# 9 convnext_base_stage_0_block_0_identity False
# 10 convnext_base_stage_0_block_1_depthwise_conv False
# 11 convnext_base_stage_0_block_1_layernorm False
# 12 convnext_base_stage_0_block_1_pointwise_conv_1 False
# 13 convnext_base_stage_0_block_1_gelu False
# 14 convnext_base_stage_0_block_1_pointwise_conv_2 False
# 15 convnext_base_stage_0_block_1_layer_scale False
# 16 convnext_base_stage_0_block_1_identity False
# 17 convnext_base_stage_0_block_2_depthwise_conv False
# 18 convnext_base_stage_0_block_2_layernorm False
# 19 convnext_base_stage_0_block_2_pointwise_conv_1 False
# 20 convnext_base_stage_0_block_2_gelu False
# 21 convnext_base_stage_0_block_2_pointwise_conv_2 False
# 22 convnext_base_stage_0_block_2_layer_scale False
# 23 convnext_base_stage_0_block_2_identity False
# 24 convnext_base_downsampling_block_0 False
# 25 convnext_base_stage_1_block_0_depthwise_conv False
# 26 convnext_base_stage_1_block_0_layernorm False
# 27 convnext_base_stage_1_block_0_pointwise_conv_1 False
# 28 convnext_base_stage_1_block_0_gelu False
# 29 convnext_base_stage_1_block_0_pointwise_conv_2 False
# 30 convnext_base_stage_1_block_0_layer_scale False
# 31 convnext_base_stage_1_block_0_identity False
# 32 convnext_base_stage_1_block_1_depthwise_conv False
# 33 convnext_base_stage_1_block_1_layernorm False
# 34 convnext_base_stage_1_block_1_pointwise_conv_1 False
# 35 convnext_base_stage_1_block_1_gelu False
# 36 convnext_base_stage_1_block_1_pointwise_conv_2 False
# 37 convnext_base_stage_1_block_1_layer_scale False
# 38 convnext_base_stage_1_block_1_identity False
# 39 convnext_base_stage_1_block_2_depthwise_conv False
# 40 convnext_base_stage_1_block_2_layernorm False
# 41 convnext_base_stage_1_block_2_pointwise_conv_1 False
# 42 convnext_base_stage_1_block_2_gelu False
# 43 convnext_base_stage_1_block_2_pointwise_conv_2 False
# 44 convnext_base_stage_1_block_2_layer_scale False
# 45 convnext_base_stage_1_block_2_identity False
# 46 convnext_base_downsampling_block_1 False
# 47 convnext_base_stage_2_block_0_depthwise_conv True
# 48 convnext_base_stage_2_block_0_layernorm False
# 49 convnext_base_stage_2_block_0_pointwise_conv_1 True
# 50 convnext_base_stage_2_block_0_gelu True
# 51 convnext_base_stage_2_block_0_pointwise_conv_2 True
# 52 convnext_base_stage_2_block_0_layer_scale True
# 53 convnext_base_stage_2_block_0_identity True
# 54 convnext_base_stage_2_block_1_depthwise_conv True
# 55 convnext_base_stage_2_block_1_layernorm False
# 56 convnext_base_stage_2_block_1_pointwise_conv_1 True
# 57 convnext_base_stage_2_block_1_gelu True
# 58 convnext_base_stage_2_block_1_pointwise_conv_2 True
# 59 convnext_base_stage_2_block_1_layer_scale True
# 60 convnext_base_stage_2_block_1_identity True
# 61 convnext_base_stage_2_block_2_depthwise_conv True
# 62 convnext_base_stage_2_block_2_layernorm False
# 63 convnext_base_stage_2_block_2_pointwise_conv_1 True
# 64 convnext_base_stage_2_block_2_gelu True
# 65 convnext_base_stage_2_block_2_pointwise_conv_2 True
# 66 convnext_base_stage_2_block_2_layer_scale True
# 67 convnext_base_stage_2_block_2_identity True
# 68 convnext_base_stage_2_block_3_depthwise_conv True
# 69 convnext_base_stage_2_block_3_layernorm False
# 70 convnext_base_stage_2_block_3_pointwise_conv_1 True
# 71 convnext_base_stage_2_block_3_gelu True
# 72 convnext_base_stage_2_block_3_pointwise_conv_2 True
# 73 convnext_base_stage_2_block_3_layer_scale True
# 74 convnext_base_stage_2_block_3_identity True
# 75 convnext_base_stage_2_block_4_depthwise_conv True
# 76 convnext_base_stage_2_block_4_layernorm False
# 77 convnext_base_stage_2_block_4_pointwise_conv_1 True
# 78 convnext_base_stage_2_block_4_gelu True
# 79 convnext_base_stage_2_block_4_pointwise_conv_2 True
# 80 convnext_base_stage_2_block_4_layer_scale True
# 81 convnext_base_stage_2_block_4_identity True
# 82 convnext_base_stage_2_block_5_depthwise_conv True
# 83 convnext_base_stage_2_block_5_layernorm False
# 84 convnext_base_stage_2_block_5_pointwise_conv_1 True
# 85 convnext_base_stage_2_block_5_gelu True
# 86 convnext_base_stage_2_block_5_pointwise_conv_2 True
# 87 convnext_base_stage_2_block_5_layer_scale True
# 88 convnext_base_stage_2_block_5_identity True
# 89 convnext_base_stage_2_block_6_depthwise_conv True
# 90 convnext_base_stage_2_block_6_layernorm False
# 91 convnext_base_stage_2_block_6_pointwise_conv_1 True
# 92 convnext_base_stage_2_block_6_gelu True
# 93 convnext_base_stage_2_block_6_pointwise_conv_2 True
# 94 convnext_base_stage_2_block_6_layer_scale True
# 95 convnext_base_stage_2_block_6_identity True
# 96 convnext_base_stage_2_block_7_depthwise_conv True
# 97 convnext_base_stage_2_block_7_layernorm False
# 98 convnext_base_stage_2_block_7_pointwise_conv_1 True
# 99 convnext_base_stage_2_block_7_gelu True
# 100 convnext_base_stage_2_block_7_pointwise_conv_2 True
# 101 convnext_base_stage_2_block_7_layer_scale True
# 102 convnext_base_stage_2_block_7_identity True
# 103 convnext_base_stage_2_block_8_depthwise_conv True
# 104 convnext_base_stage_2_block_8_layernorm False
# 105 convnext_base_stage_2_block_8_pointwise_conv_1 True
# 106 convnext_base_stage_2_block_8_gelu True
# 107 convnext_base_stage_2_block_8_pointwise_conv_2 True
# 108 convnext_base_stage_2_block_8_layer_scale True
# 109 convnext_base_stage_2_block_8_identity True
# 110 convnext_base_stage_2_block_9_depthwise_conv True
# 111 convnext_base_stage_2_block_9_layernorm False
# 112 convnext_base_stage_2_block_9_pointwise_conv_1 True
# 113 convnext_base_stage_2_block_9_gelu True
# 114 convnext_base_stage_2_block_9_pointwise_conv_2 True
# 115 convnext_base_stage_2_block_9_layer_scale True
# 116 convnext_base_stage_2_block_9_identity True
# 117 convnext_base_stage_2_block_10_depthwise_conv True
# 118 convnext_base_stage_2_block_10_layernorm False
# 119 convnext_base_stage_2_block_10_pointwise_conv_1 True
# 120 convnext_base_stage_2_block_10_gelu True
# 121 convnext_base_stage_2_block_10_pointwise_conv_2 True
# 122 convnext_base_stage_2_block_10_layer_scale True
# 123 convnext_base_stage_2_block_10_identity True
# 124 convnext_base_stage_2_block_11_depthwise_conv True
# 125 convnext_base_stage_2_block_11_layernorm False
# 126 convnext_base_stage_2_block_11_pointwise_conv_1 True
# 127 convnext_base_stage_2_block_11_gelu True
# 128 convnext_base_stage_2_block_11_pointwise_conv_2 True
# 129 convnext_base_stage_2_block_11_layer_scale True
# 130 convnext_base_stage_2_block_11_identity True
# 131 convnext_base_stage_2_block_12_depthwise_conv True
# 132 convnext_base_stage_2_block_12_layernorm False
# 133 convnext_base_stage_2_block_12_pointwise_conv_1 True
# 134 convnext_base_stage_2_block_12_gelu True
# 135 convnext_base_stage_2_block_12_pointwise_conv_2 True
# 136 convnext_base_stage_2_block_12_layer_scale True
# 137 convnext_base_stage_2_block_12_identity True
# 138 convnext_base_stage_2_block_13_depthwise_conv True
# 139 convnext_base_stage_2_block_13_layernorm False
# 140 convnext_base_stage_2_block_13_pointwise_conv_1 True
# 141 convnext_base_stage_2_block_13_gelu True
# 142 convnext_base_stage_2_block_13_pointwise_conv_2 True
# 143 convnext_base_stage_2_block_13_layer_scale True
# 144 convnext_base_stage_2_block_13_identity True
# 145 convnext_base_stage_2_block_14_depthwise_conv True
# 146 convnext_base_stage_2_block_14_layernorm False
# 147 convnext_base_stage_2_block_14_pointwise_conv_1 True
# 148 convnext_base_stage_2_block_14_gelu True
# 149 convnext_base_stage_2_block_14_pointwise_conv_2 True
# 150 convnext_base_stage_2_block_14_layer_scale True
# 151 convnext_base_stage_2_block_14_identity True
# 152 convnext_base_stage_2_block_15_depthwise_conv True
# 153 convnext_base_stage_2_block_15_layernorm False
# 154 convnext_base_stage_2_block_15_pointwise_conv_1 True
# 155 convnext_base_stage_2_block_15_gelu True
# 156 convnext_base_stage_2_block_15_pointwise_conv_2 True
# 157 convnext_base_stage_2_block_15_layer_scale True
# 158 convnext_base_stage_2_block_15_identity True
# 159 convnext_base_stage_2_block_16_depthwise_conv True
# 160 convnext_base_stage_2_block_16_layernorm False
# 161 convnext_base_stage_2_block_16_pointwise_conv_1 True
# 162 convnext_base_stage_2_block_16_gelu True
# 163 convnext_base_stage_2_block_16_pointwise_conv_2 True
# 164 convnext_base_stage_2_block_16_layer_scale True
# 165 convnext_base_stage_2_block_16_identity True
# 166 convnext_base_stage_2_block_17_depthwise_conv True
# 167 convnext_base_stage_2_block_17_layernorm False
# 168 convnext_base_stage_2_block_17_pointwise_conv_1 True
# 169 convnext_base_stage_2_block_17_gelu True
# 170 convnext_base_stage_2_block_17_pointwise_conv_2 True
# 171 convnext_base_stage_2_block_17_layer_scale True
# 172 convnext_base_stage_2_block_17_identity True
# 173 convnext_base_stage_2_block_18_depthwise_conv True
# 174 convnext_base_stage_2_block_18_layernorm False
# 175 convnext_base_stage_2_block_18_pointwise_conv_1 True
# 176 convnext_base_stage_2_block_18_gelu True
# 177 convnext_base_stage_2_block_18_pointwise_conv_2 True
# 178 convnext_base_stage_2_block_18_layer_scale True
# 179 convnext_base_stage_2_block_18_identity True
# 180 convnext_base_stage_2_block_19_depthwise_conv True
# 181 convnext_base_stage_2_block_19_layernorm False
# 182 convnext_base_stage_2_block_19_pointwise_conv_1 True
# 183 convnext_base_stage_2_block_19_gelu True
# 184 convnext_base_stage_2_block_19_pointwise_conv_2 True
# 185 convnext_base_stage_2_block_19_layer_scale True
# 186 convnext_base_stage_2_block_19_identity True
# 187 convnext_base_stage_2_block_20_depthwise_conv True
# 188 convnext_base_stage_2_block_20_layernorm False
# 189 convnext_base_stage_2_block_20_pointwise_conv_1 True
# 190 convnext_base_stage_2_block_20_gelu True
# 191 convnext_base_stage_2_block_20_pointwise_conv_2 True
# 192 convnext_base_stage_2_block_20_layer_scale True
# 193 convnext_base_stage_2_block_20_identity True
# 194 convnext_base_stage_2_block_21_depthwise_conv True
# 195 convnext_base_stage_2_block_21_layernorm False
# 196 convnext_base_stage_2_block_21_pointwise_conv_1 True
# 197 convnext_base_stage_2_block_21_gelu True
# 198 convnext_base_stage_2_block_21_pointwise_conv_2 True
# 199 convnext_base_stage_2_block_21_layer_scale True
# 200 convnext_base_stage_2_block_21_identity True
# 201 convnext_base_stage_2_block_22_depthwise_conv True
# 202 convnext_base_stage_2_block_22_layernorm False
# 203 convnext_base_stage_2_block_22_pointwise_conv_1 True
# 204 convnext_base_stage_2_block_22_gelu True
# 205 convnext_base_stage_2_block_22_pointwise_conv_2 True
# 206 convnext_base_stage_2_block_22_layer_scale True
# 207 convnext_base_stage_2_block_22_identity True
# 208 convnext_base_stage_2_block_23_depthwise_conv True
# 209 convnext_base_stage_2_block_23_layernorm False
# 210 convnext_base_stage_2_block_23_pointwise_conv_1 True
# 211 convnext_base_stage_2_block_23_gelu True
# 212 convnext_base_stage_2_block_23_pointwise_conv_2 True
# 213 convnext_base_stage_2_block_23_layer_scale True
# 214 convnext_base_stage_2_block_23_identity True
# 215 convnext_base_stage_2_block_24_depthwise_conv True
# 216 convnext_base_stage_2_block_24_layernorm False
# 217 convnext_base_stage_2_block_24_pointwise_conv_1 True
# 218 convnext_base_stage_2_block_24_gelu True
# 219 convnext_base_stage_2_block_24_pointwise_conv_2 True
# 220 convnext_base_stage_2_block_24_layer_scale True
# 221 convnext_base_stage_2_block_24_identity True
# 222 convnext_base_stage_2_block_25_depthwise_conv True
# 223 convnext_base_stage_2_block_25_layernorm False
# 224 convnext_base_stage_2_block_25_pointwise_conv_1 True
# 225 convnext_base_stage_2_block_25_gelu True
# 226 convnext_base_stage_2_block_25_pointwise_conv_2 True
# 227 convnext_base_stage_2_block_25_layer_scale True
# 228 convnext_base_stage_2_block_25_identity True
# 229 convnext_base_stage_2_block_26_depthwise_conv True
# 230 convnext_base_stage_2_block_26_layernorm False
# 231 convnext_base_stage_2_block_26_pointwise_conv_1 True
# 232 convnext_base_stage_2_block_26_gelu True
# 233 convnext_base_stage_2_block_26_pointwise_conv_2 True
# 234 convnext_base_stage_2_block_26_layer_scale True
# 235 convnext_base_stage_2_block_26_identity True
# 236 convnext_base_downsampling_block_2 True
# 237 convnext_base_stage_3_block_0_depthwise_conv True
# 238 convnext_base_stage_3_block_0_layernorm False
# 239 convnext_base_stage_3_block_0_pointwise_conv_1 True
# 240 convnext_base_stage_3_block_0_gelu True
# 241 convnext_base_stage_3_block_0_pointwise_conv_2 True
# 242 convnext_base_stage_3_block_0_layer_scale True
# 243 convnext_base_stage_3_block_0_identity True
# 244 convnext_base_stage_3_block_1_depthwise_conv True
# 245 convnext_base_stage_3_block_1_layernorm False
# 246 convnext_base_stage_3_block_1_pointwise_conv_1 True
# 247 convnext_base_stage_3_block_1_gelu True
# 248 convnext_base_stage_3_block_1_pointwise_conv_2 True
# 249 convnext_base_stage_3_block_1_layer_scale True
# 250 convnext_base_stage_3_block_1_identity True
# 251 convnext_base_stage_3_block_2_depthwise_conv True
# 252 convnext_base_stage_3_block_2_layernorm False
# 253 convnext_base_stage_3_block_2_pointwise_conv_1 True
# 254 convnext_base_stage_3_block_2_gelu True
# 255 convnext_base_stage_3_block_2_pointwise_conv_2 True
# 256 convnext_base_stage_3_block_2_layer_scale True
# 257 convnext_base_stage_3_block_2_identity True
# 258 global_average_pooling2d True
# 259 layer_normalization False
# 0 input_layer False
# 1 convnext_base_prestem_normalization False
# 2 convnext_base_stem False
# 3 convnext_base_stage_0_block_0_depthwise_conv False
# 4 convnext_base_stage_0_block_0_layernorm False
# 5 convnext_base_stage_0_block_0_pointwise_conv_1 False
# 6 convnext_base_stage_0_block_0_gelu False
# 7 convnext_base_stage_0_block_0_pointwise_conv_2 False
# 8 convnext_base_stage_0_block_0_layer_scale False
# 9 convnext_base_stage_0_block_0_identity False
# 10 convnext_base_stage_0_block_1_depthwise_conv False
# 11 convnext_base_stage_0_block_1_layernorm False
# 12 convnext_base_stage_0_block_1_pointwise_conv_1 False
# 13 convnext_base_stage_0_block_1_gelu False
# 14 convnext_base_stage_0_block_1_pointwise_conv_2 False
# 15 convnext_base_stage_0_block_1_layer_scale False
# 16 convnext_base_stage_0_block_1_identity False
# 17 convnext_base_stage_0_block_2_depthwise_conv False
# 18 convnext_base_stage_0_block_2_layernorm False
# 19 convnext_base_stage_0_block_2_pointwise_conv_1 False
# 20 convnext_base_stage_0_block_2_gelu False
# 21 convnext_base_stage_0_block_2_pointwise_conv_2 False
# 22 convnext_base_stage_0_block_2_layer_scale False
# 23 convnext_base_stage_0_block_2_identity False
# 24 convnext_base_downsampling_block_0 False
# 25 convnext_base_stage_1_block_0_depthwise_conv False
# 26 convnext_base_stage_1_block_0_layernorm False
# 27 convnext_base_stage_1_block_0_pointwise_conv_1 False
# 28 convnext_base_stage_1_block_0_gelu False
# 29 convnext_base_stage_1_block_0_pointwise_conv_2 False
# 30 convnext_base_stage_1_block_0_layer_scale False
# 31 convnext_base_stage_1_block_0_identity False
# 32 convnext_base_stage_1_block_1_depthwise_conv False
# 33 convnext_base_stage_1_block_1_layernorm False
# 34 convnext_base_stage_1_block_1_pointwise_conv_1 False
# 35 convnext_base_stage_1_block_1_gelu False
# 36 convnext_base_stage_1_block_1_pointwise_conv_2 False
# 37 convnext_base_stage_1_block_1_layer_scale False
# 38 convnext_base_stage_1_block_1_identity False
# 39 convnext_base_stage_1_block_2_depthwise_conv False
# 40 convnext_base_stage_1_block_2_layernorm False
# 41 convnext_base_stage_1_block_2_pointwise_conv_1 False
# 42 convnext_base_stage_1_block_2_gelu False
# 43 convnext_base_stage_1_block_2_pointwise_conv_2 False
# 44 convnext_base_stage_1_block_2_layer_scale False
# 45 convnext_base_stage_1_block_2_identity False
# 46 convnext_base_downsampling_block_1 False
# 47 convnext_base_stage_2_block_0_depthwise_conv True
# 48 convnext_base_stage_2_block_0_layernorm False
# 49 convnext_base_stage_2_block_0_pointwise_conv_1 True
# 50 convnext_base_stage_2_block_0_gelu True
# 51 convnext_base_stage_2_block_0_pointwise_conv_2 True
# 52 convnext_base_stage_2_block_0_layer_scale True
# 53 convnext_base_stage_2_block_0_identity True
# 54 convnext_base_stage_2_block_1_depthwise_conv True
# 55 convnext_base_stage_2_block_1_layernorm False
# 56 convnext_base_stage_2_block_1_pointwise_conv_1 True
# 57 convnext_base_stage_2_block_1_gelu True
# 58 convnext_base_stage_2_block_1_pointwise_conv_2 True
# 59 convnext_base_stage_2_block_1_layer_scale True
# 60 convnext_base_stage_2_block_1_identity True
# 61 convnext_base_stage_2_block_2_depthwise_conv True
# 62 convnext_base_stage_2_block_2_layernorm False
# 63 convnext_base_stage_2_block_2_pointwise_conv_1 True
# 64 convnext_base_stage_2_block_2_gelu True
# 65 convnext_base_stage_2_block_2_pointwise_conv_2 True
# 66 convnext_base_stage_2_block_2_layer_scale True
# 67 convnext_base_stage_2_block_2_identity True
# 68 convnext_base_stage_2_block_3_depthwise_conv True
# 69 convnext_base_stage_2_block_3_layernorm False
# 70 convnext_base_stage_2_block_3_pointwise_conv_1 True
# 71 convnext_base_stage_2_block_3_gelu True
# 72 convnext_base_stage_2_block_3_pointwise_conv_2 True
# 73 convnext_base_stage_2_block_3_layer_scale True
# 74 convnext_base_stage_2_block_3_identity True
# 75 convnext_base_stage_2_block_4_depthwise_conv True
# 76 convnext_base_stage_2_block_4_layernorm False
# 77 convnext_base_stage_2_block_4_pointwise_conv_1 True
# 78 convnext_base_stage_2_block_4_gelu True
# 79 convnext_base_stage_2_block_4_pointwise_conv_2 True
# 80 convnext_base_stage_2_block_4_layer_scale True
# 81 convnext_base_stage_2_block_4_identity True
# 82 convnext_base_stage_2_block_5_depthwise_conv True
# 83 convnext_base_stage_2_block_5_layernorm False
# 84 convnext_base_stage_2_block_5_pointwise_conv_1 True
# 85 convnext_base_stage_2_block_5_gelu True
# 86 convnext_base_stage_2_block_5_pointwise_conv_2 True
# 87 convnext_base_stage_2_block_5_layer_scale True
# 88 convnext_base_stage_2_block_5_identity True
# 89 convnext_base_stage_2_block_6_depthwise_conv True
# 90 convnext_base_stage_2_block_6_layernorm False
# 91 convnext_base_stage_2_block_6_pointwise_conv_1 True
# 92 convnext_base_stage_2_block_6_gelu True
# 93 convnext_base_stage_2_block_6_pointwise_conv_2 True
# 94 convnext_base_stage_2_block_6_layer_scale True
# 95 convnext_base_stage_2_block_6_identity True
# 96 convnext_base_stage_2_block_7_depthwise_conv True
# 97 convnext_base_stage_2_block_7_layernorm False
# 98 convnext_base_stage_2_block_7_pointwise_conv_1 True
# 99 convnext_base_stage_2_block_7_gelu True
# 100 convnext_base_stage_2_block_7_pointwise_conv_2 True
# 101 convnext_base_stage_2_block_7_layer_scale True
# 102 convnext_base_stage_2_block_7_identity True
# 103 convnext_base_stage_2_block_8_depthwise_conv True
# 104 convnext_base_stage_2_block_8_layernorm False
# 105 convnext_base_stage_2_block_8_pointwise_conv_1 True
# 106 convnext_base_stage_2_block_8_gelu True
# 107 convnext_base_stage_2_block_8_pointwise_conv_2 True
# 108 convnext_base_stage_2_block_8_layer_scale True
# 109 convnext_base_stage_2_block_8_identity True
# 110 convnext_base_stage_2_block_9_depthwise_conv True
# 111 convnext_base_stage_2_block_9_layernorm False
# 112 convnext_base_stage_2_block_9_pointwise_conv_1 True
# 113 convnext_base_stage_2_block_9_gelu True
# 114 convnext_base_stage_2_block_9_pointwise_conv_2 True
# 115 convnext_base_stage_2_block_9_layer_scale True
# 116 convnext_base_stage_2_block_9_identity True
# 117 convnext_base_stage_2_block_10_depthwise_conv True
# 118 convnext_base_stage_2_block_10_layernorm False
# 119 convnext_base_stage_2_block_10_pointwise_conv_1 True
# 120 convnext_base_stage_2_block_10_gelu True
# 121 convnext_base_stage_2_block_10_pointwise_conv_2 True
# 122 convnext_base_stage_2_block_10_layer_scale True
# 123 convnext_base_stage_2_block_10_identity True
# 124 convnext_base_stage_2_block_11_depthwise_conv True
# 125 convnext_base_stage_2_block_11_layernorm False
# 126 convnext_base_stage_2_block_11_pointwise_conv_1 True
# 127 convnext_base_stage_2_block_11_gelu True
# 128 convnext_base_stage_2_block_11_pointwise_conv_2 True
# 129 convnext_base_stage_2_block_11_layer_scale True
# 130 convnext_base_stage_2_block_11_identity True
# 131 convnext_base_stage_2_block_12_depthwise_conv True
# 132 convnext_base_stage_2_block_12_layernorm False
# 133 convnext_base_stage_2_block_12_pointwise_conv_1 True
# 134 convnext_base_stage_2_block_12_gelu True
# 135 convnext_base_stage_2_block_12_pointwise_conv_2 True
# 136 convnext_base_stage_2_block_12_layer_scale True
# 137 convnext_base_stage_2_block_12_identity True
# 138 convnext_base_stage_2_block_13_depthwise_conv True
# 139 convnext_base_stage_2_block_13_layernorm False
# 140 convnext_base_stage_2_block_13_pointwise_conv_1 True
# 141 convnext_base_stage_2_block_13_gelu True
# 142 convnext_base_stage_2_block_13_pointwise_conv_2 True
# 143 convnext_base_stage_2_block_13_layer_scale True
# 144 convnext_base_stage_2_block_13_identity True
# 145 convnext_base_stage_2_block_14_depthwise_conv True
# 146 convnext_base_stage_2_block_14_layernorm False
# 147 convnext_base_stage_2_block_14_pointwise_conv_1 True
# 148 convnext_base_stage_2_block_14_gelu True
# 149 convnext_base_stage_2_block_14_pointwise_conv_2 True
# 150 convnext_base_stage_2_block_14_layer_scale True
# 151 convnext_base_stage_2_block_14_identity True
# 152 convnext_base_stage_2_block_15_depthwise_conv True
# 153 convnext_base_stage_2_block_15_layernorm False
# 154 convnext_base_stage_2_block_15_pointwise_conv_1 True
# 155 convnext_base_stage_2_block_15_gelu True
# 156 convnext_base_stage_2_block_15_pointwise_conv_2 True
# 157 convnext_base_stage_2_block_15_layer_scale True
# 158 convnext_base_stage_2_block_15_identity True
# 159 convnext_base_stage_2_block_16_depthwise_conv True
# 160 convnext_base_stage_2_block_16_layernorm False
# 161 convnext_base_stage_2_block_16_pointwise_conv_1 True
# 162 convnext_base_stage_2_block_16_gelu True
# 163 convnext_base_stage_2_block_16_pointwise_conv_2 True
# 164 convnext_base_stage_2_block_16_layer_scale True
# 165 convnext_base_stage_2_block_16_identity True
# 166 convnext_base_stage_2_block_17_depthwise_conv True
# 167 convnext_base_stage_2_block_17_layernorm False
# 168 convnext_base_stage_2_block_17_pointwise_conv_1 True
# 169 convnext_base_stage_2_block_17_gelu True
# 170 convnext_base_stage_2_block_17_pointwise_conv_2 True
# 171 convnext_base_stage_2_block_17_layer_scale True
# 172 convnext_base_stage_2_block_17_identity True
# 173 convnext_base_stage_2_block_18_depthwise_conv True
# 174 convnext_base_stage_2_block_18_layernorm False
# 175 convnext_base_stage_2_block_18_pointwise_conv_1 True
# 176 convnext_base_stage_2_block_18_gelu True
# 177 convnext_base_stage_2_block_18_pointwise_conv_2 True
# 178 convnext_base_stage_2_block_18_layer_scale True
# 179 convnext_base_stage_2_block_18_identity True
# 180 convnext_base_stage_2_block_19_depthwise_conv True
# 181 convnext_base_stage_2_block_19_layernorm False
# 182 convnext_base_stage_2_block_19_pointwise_conv_1 True
# 183 convnext_base_stage_2_block_19_gelu True
# 184 convnext_base_stage_2_block_19_pointwise_conv_2 True
# 185 convnext_base_stage_2_block_19_layer_scale True
# 186 convnext_base_stage_2_block_19_identity True
# 187 convnext_base_stage_2_block_20_depthwise_conv True
# 188 convnext_base_stage_2_block_20_layernorm False
# 189 convnext_base_stage_2_block_20_pointwise_conv_1 True
# 190 convnext_base_stage_2_block_20_gelu True
# 191 convnext_base_stage_2_block_20_pointwise_conv_2 True
# 192 convnext_base_stage_2_block_20_layer_scale True
# 193 convnext_base_stage_2_block_20_identity True
# 194 convnext_base_stage_2_block_21_depthwise_conv True
# 195 convnext_base_stage_2_block_21_layernorm False
# 196 convnext_base_stage_2_block_21_pointwise_conv_1 True
# 197 convnext_base_stage_2_block_21_gelu True
# 198 convnext_base_stage_2_block_21_pointwise_conv_2 True
# 199 convnext_base_stage_2_block_21_layer_scale True
# 200 convnext_base_stage_2_block_21_identity True
# 201 convnext_base_stage_2_block_22_depthwise_conv True
# 202 convnext_base_stage_2_block_22_layernorm False
# 203 convnext_base_stage_2_block_22_pointwise_conv_1 True
# 204 convnext_base_stage_2_block_22_gelu True
# 205 convnext_base_stage_2_block_22_pointwise_conv_2 True
# 206 convnext_base_stage_2_block_22_layer_scale True
# 207 convnext_base_stage_2_block_22_identity True
# 208 convnext_base_stage_2_block_23_depthwise_conv True
# 209 convnext_base_stage_2_block_23_layernorm False
# 210 convnext_base_stage_2_block_23_pointwise_conv_1 True
# 211 convnext_base_stage_2_block_23_gelu True
# 212 convnext_base_stage_2_block_23_pointwise_conv_2 True
# 213 convnext_base_stage_2_block_23_layer_scale True
# 214 convnext_base_stage_2_block_23_identity True
# 215 convnext_base_stage_2_block_24_depthwise_conv True
# 216 convnext_base_stage_2_block_24_layernorm False
# 217 convnext_base_stage_2_block_24_pointwise_conv_1 True
# 218 convnext_base_stage_2_block_24_gelu True
# 219 convnext_base_stage_2_block_24_pointwise_conv_2 True
# 220 convnext_base_stage_2_block_24_layer_scale True
# 221 convnext_base_stage_2_block_24_identity True
# 222 convnext_base_stage_2_block_25_depthwise_conv True
# 223 convnext_base_stage_2_block_25_layernorm False
# 224 convnext_base_stage_2_block_25_pointwise_conv_1 True
# 225 convnext_base_stage_2_block_25_gelu True
# 226 convnext_base_stage_2_block_25_pointwise_conv_2 True
# 227 convnext_base_stage_2_block_25_layer_scale True
# 228 convnext_base_stage_2_block_25_identity True
# 229 convnext_base_stage_2_block_26_depthwise_conv True
# 230 convnext_base_stage_2_block_26_layernorm False
# 231 convnext_base_stage_2_block_26_pointwise_conv_1 True
# 232 convnext_base_stage_2_block_26_gelu True
# 233 convnext_base_stage_2_block_26_pointwise_conv_2 True
# 234 convnext_base_stage_2_block_26_layer_scale True
# 235 convnext_base_stage_2_block_26_identity True
# 236 convnext_base_downsampling_block_2 True
# 237 convnext_base_stage_3_block_0_depthwise_conv True
# 238 convnext_base_stage_3_block_0_layernorm False
# 239 convnext_base_stage_3_block_0_pointwise_conv_1 True
# 240 convnext_base_stage_3_block_0_gelu True
# 241 convnext_base_stage_3_block_0_pointwise_conv_2 True
# 242 convnext_base_stage_3_block_0_layer_scale True
# 243 convnext_base_stage_3_block_0_identity True
# 244 convnext_base_stage_3_block_1_depthwise_conv True
# 245 convnext_base_stage_3_block_1_layernorm False
# 246 convnext_base_stage_3_block_1_pointwise_conv_1 True
# 247 convnext_base_stage_3_block_1_gelu True
# 248 convnext_base_stage_3_block_1_pointwise_conv_2 True
# 249 convnext_base_stage_3_block_1_layer_scale True
# 250 convnext_base_stage_3_block_1_identity True
# 251 convnext_base_stage_3_block_2_depthwise_conv True
# 252 convnext_base_stage_3_block_2_layernorm False
# 253 convnext_base_stage_3_block_2_pointwise_conv_1 True
# 254 convnext_base_stage_3_block_2_gelu True
# 255 convnext_base_stage_3_block_2_pointwise_conv_2 True
# 256 convnext_base_stage_3_block_2_layer_scale True
# 257 convnext_base_stage_3_block_2_identity True
# 258 global_average_pooling2d True
# 259 layer_normalization False
# 0 input_layer False
# 1 convnext_base_prestem_normalization False
# 2 convnext_base_stem False
# 3 convnext_base_stage_0_block_0_depthwise_conv False
# 4 convnext_base_stage_0_block_0_layernorm False
# 5 convnext_base_stage_0_block_0_pointwise_conv_1 False
# 6 convnext_base_stage_0_block_0_gelu False
# 7 convnext_base_stage_0_block_0_pointwise_conv_2 False
# 8 convnext_base_stage_0_block_0_layer_scale False
# 9 convnext_base_stage_0_block_0_identity False
# 10 convnext_base_stage_0_block_1_depthwise_conv False
# 11 convnext_base_stage_0_block_1_layernorm False
# 12 convnext_base_stage_0_block_1_pointwise_conv_1 False
# 13 convnext_base_stage_0_block_1_gelu False
# 14 convnext_base_stage_0_block_1_pointwise_conv_2 False
# 15 convnext_base_stage_0_block_1_layer_scale False
# 16 convnext_base_stage_0_block_1_identity False
# 17 convnext_base_stage_0_block_2_depthwise_conv False
# 18 convnext_base_stage_0_block_2_layernorm False
# 19 convnext_base_stage_0_block_2_pointwise_conv_1 False
# 20 convnext_base_stage_0_block_2_gelu False
# 21 convnext_base_stage_0_block_2_pointwise_conv_2 False
# 22 convnext_base_stage_0_block_2_layer_scale False
# 23 convnext_base_stage_0_block_2_identity False
# 24 convnext_base_downsampling_block_0 False
# 25 convnext_base_stage_1_block_0_depthwise_conv False
# 26 convnext_base_stage_1_block_0_layernorm False
# 27 convnext_base_stage_1_block_0_pointwise_conv_1 False
# 28 convnext_base_stage_1_block_0_gelu False
# 29 convnext_base_stage_1_block_0_pointwise_conv_2 False
# 30 convnext_base_stage_1_block_0_layer_scale False
# 31 convnext_base_stage_1_block_0_identity False
# 32 convnext_base_stage_1_block_1_depthwise_conv False
# 33 convnext_base_stage_1_block_1_layernorm False
# 34 convnext_base_stage_1_block_1_pointwise_conv_1 False
# 35 convnext_base_stage_1_block_1_gelu False
# 36 convnext_base_stage_1_block_1_pointwise_conv_2 False
# 37 convnext_base_stage_1_block_1_layer_scale False
# 38 convnext_base_stage_1_block_1_identity False
# 39 convnext_base_stage_1_block_2_depthwise_conv False
# 40 convnext_base_stage_1_block_2_layernorm False
# 41 convnext_base_stage_1_block_2_pointwise_conv_1 False
# 42 convnext_base_stage_1_block_2_gelu False
# 43 convnext_base_stage_1_block_2_pointwise_conv_2 False
# 44 convnext_base_stage_1_block_2_layer_scale False
# 45 convnext_base_stage_1_block_2_identity False
# 46 convnext_base_downsampling_block_1 False
# 47 convnext_base_stage_2_block_0_depthwise_conv True
# 48 convnext_base_stage_2_block_0_layernorm False
# 49 convnext_base_stage_2_block_0_pointwise_conv_1 True
# 50 convnext_base_stage_2_block_0_gelu True
# 51 convnext_base_stage_2_block_0_pointwise_conv_2 True
# 52 convnext_base_stage_2_block_0_layer_scale True
# 53 convnext_base_stage_2_block_0_identity True
# 54 convnext_base_stage_2_block_1_depthwise_conv True
# 55 convnext_base_stage_2_block_1_layernorm False
# 56 convnext_base_stage_2_block_1_pointwise_conv_1 True
# 57 convnext_base_stage_2_block_1_gelu True
# 58 convnext_base_stage_2_block_1_pointwise_conv_2 True
# 59 convnext_base_stage_2_block_1_layer_scale True
# 60 convnext_base_stage_2_block_1_identity True
# 61 convnext_base_stage_2_block_2_depthwise_conv True
# 62 convnext_base_stage_2_block_2_layernorm False
# 63 convnext_base_stage_2_block_2_pointwise_conv_1 True
# 64 convnext_base_stage_2_block_2_gelu True
# 65 convnext_base_stage_2_block_2_pointwise_conv_2 True
# 66 convnext_base_stage_2_block_2_layer_scale True
# 67 convnext_base_stage_2_block_2_identity True
# 68 convnext_base_stage_2_block_3_depthwise_conv True
# 69 convnext_base_stage_2_block_3_layernorm False
# 70 convnext_base_stage_2_block_3_pointwise_conv_1 True
# 71 convnext_base_stage_2_block_3_gelu True
# 72 convnext_base_stage_2_block_3_pointwise_conv_2 True
# 73 convnext_base_stage_2_block_3_layer_scale True
# 74 convnext_base_stage_2_block_3_identity True
# 75 convnext_base_stage_2_block_4_depthwise_conv True
# 76 convnext_base_stage_2_block_4_layernorm False
# 77 convnext_base_stage_2_block_4_pointwise_conv_1 True
# 78 convnext_base_stage_2_block_4_gelu True
# 79 convnext_base_stage_2_block_4_pointwise_conv_2 True
# 80 convnext_base_stage_2_block_4_layer_scale True
# 81 convnext_base_stage_2_block_4_identity True
# 82 convnext_base_stage_2_block_5_depthwise_conv True
# 83 convnext_base_stage_2_block_5_layernorm False
# 84 convnext_base_stage_2_block_5_pointwise_conv_1 True
# 85 convnext_base_stage_2_block_5_gelu True
# 86 convnext_base_stage_2_block_5_pointwise_conv_2 True
# 87 convnext_base_stage_2_block_5_layer_scale True
# 88 convnext_base_stage_2_block_5_identity True
# 89 convnext_base_stage_2_block_6_depthwise_conv True
# 90 convnext_base_stage_2_block_6_layernorm False
# 91 convnext_base_stage_2_block_6_pointwise_conv_1 True
# 92 convnext_base_stage_2_block_6_gelu True
# 93 convnext_base_stage_2_block_6_pointwise_conv_2 True
# 94 convnext_base_stage_2_block_6_layer_scale True
# 95 convnext_base_stage_2_block_6_identity True
# 96 convnext_base_stage_2_block_7_depthwise_conv True
# 97 convnext_base_stage_2_block_7_layernorm False
# 98 convnext_base_stage_2_block_7_pointwise_conv_1 True
# 99 convnext_base_stage_2_block_7_gelu True
# 100 convnext_base_stage_2_block_7_pointwise_conv_2 True
# 101 convnext_base_stage_2_block_7_layer_scale True
# 102 convnext_base_stage_2_block_7_identity True
# 103 convnext_base_stage_2_block_8_depthwise_conv True
# 104 convnext_base_stage_2_block_8_layernorm False
# 105 convnext_base_stage_2_block_8_pointwise_conv_1 True
# 106 convnext_base_stage_2_block_8_gelu True
# 107 convnext_base_stage_2_block_8_pointwise_conv_2 True
# 108 convnext_base_stage_2_block_8_layer_scale True
# 109 convnext_base_stage_2_block_8_identity True
# 110 convnext_base_stage_2_block_9_depthwise_conv True
# 111 convnext_base_stage_2_block_9_layernorm False
# 112 convnext_base_stage_2_block_9_pointwise_conv_1 True
# 113 convnext_base_stage_2_block_9_gelu True
# 114 convnext_base_stage_2_block_9_pointwise_conv_2 True
# 115 convnext_base_stage_2_block_9_layer_scale True
# 116 convnext_base_stage_2_block_9_identity True
# 117 convnext_base_stage_2_block_10_depthwise_conv True
# 118 convnext_base_stage_2_block_10_layernorm False
# 119 convnext_base_stage_2_block_10_pointwise_conv_1 True
# 120 convnext_base_stage_2_block_10_gelu True
# 121 convnext_base_stage_2_block_10_pointwise_conv_2 True
# 122 convnext_base_stage_2_block_10_layer_scale True
# 123 convnext_base_stage_2_block_10_identity True
# 124 convnext_base_stage_2_block_11_depthwise_conv True
# 125 convnext_base_stage_2_block_11_layernorm False
# 126 convnext_base_stage_2_block_11_pointwise_conv_1 True
# 127 convnext_base_stage_2_block_11_gelu True
# 128 convnext_base_stage_2_block_11_pointwise_conv_2 True
# 129 convnext_base_stage_2_block_11_layer_scale True
# 130 convnext_base_stage_2_block_11_identity True
# 131 convnext_base_stage_2_block_12_depthwise_conv True
# 132 convnext_base_stage_2_block_12_layernorm False
# 133 convnext_base_stage_2_block_12_pointwise_conv_1 True
# 134 convnext_base_stage_2_block_12_gelu True
# 135 convnext_base_stage_2_block_12_pointwise_conv_2 True
# 136 convnext_base_stage_2_block_12_layer_scale True
# 137 convnext_base_stage_2_block_12_identity True
# 138 convnext_base_stage_2_block_13_depthwise_conv True
# 139 convnext_base_stage_2_block_13_layernorm False
# 140 convnext_base_stage_2_block_13_pointwise_conv_1 True
# 141 convnext_base_stage_2_block_13_gelu True
# 142 convnext_base_stage_2_block_13_pointwise_conv_2 True
# 143 convnext_base_stage_2_block_13_layer_scale True
# 144 convnext_base_stage_2_block_13_identity True
# 145 convnext_base_stage_2_block_14_depthwise_conv True
# 146 convnext_base_stage_2_block_14_layernorm False
# 147 convnext_base_stage_2_block_14_pointwise_conv_1 True
# 148 convnext_base_stage_2_block_14_gelu True
# 149 convnext_base_stage_2_block_14_pointwise_conv_2 True
# 150 convnext_base_stage_2_block_14_layer_scale True
# 151 convnext_base_stage_2_block_14_identity True
# 152 convnext_base_stage_2_block_15_depthwise_conv True
# 153 convnext_base_stage_2_block_15_layernorm False
# 154 convnext_base_stage_2_block_15_pointwise_conv_1 True
# 155 convnext_base_stage_2_block_15_gelu True
# 156 convnext_base_stage_2_block_15_pointwise_conv_2 True
# 157 convnext_base_stage_2_block_15_layer_scale True
# 158 convnext_base_stage_2_block_15_identity True
# 159 convnext_base_stage_2_block_16_depthwise_conv True
# 160 convnext_base_stage_2_block_16_layernorm False
# 161 convnext_base_stage_2_block_16_pointwise_conv_1 True
# 162 convnext_base_stage_2_block_16_gelu True
# 163 convnext_base_stage_2_block_16_pointwise_conv_2 True
# 164 convnext_base_stage_2_block_16_layer_scale True
# 165 convnext_base_stage_2_block_16_identity True
# 166 convnext_base_stage_2_block_17_depthwise_conv True
# 167 convnext_base_stage_2_block_17_layernorm False
# 168 convnext_base_stage_2_block_17_pointwise_conv_1 True
# 169 convnext_base_stage_2_block_17_gelu True
# 170 convnext_base_stage_2_block_17_pointwise_conv_2 True
# 171 convnext_base_stage_2_block_17_layer_scale True
# 172 convnext_base_stage_2_block_17_identity True
# 173 convnext_base_stage_2_block_18_depthwise_conv True
# 174 convnext_base_stage_2_block_18_layernorm False
# 175 convnext_base_stage_2_block_18_pointwise_conv_1 True
# 176 convnext_base_stage_2_block_18_gelu True
# 177 convnext_base_stage_2_block_18_pointwise_conv_2 True
# 178 convnext_base_stage_2_block_18_layer_scale True
# 179 convnext_base_stage_2_block_18_identity True
# 180 convnext_base_stage_2_block_19_depthwise_conv True
# 181 convnext_base_stage_2_block_19_layernorm False
# 182 convnext_base_stage_2_block_19_pointwise_conv_1 True
# 183 convnext_base_stage_2_block_19_gelu True
# 184 convnext_base_stage_2_block_19_pointwise_conv_2 True
# 185 convnext_base_stage_2_block_19_layer_scale True
# 186 convnext_base_stage_2_block_19_identity True
# 187 convnext_base_stage_2_block_20_depthwise_conv True
# 188 convnext_base_stage_2_block_20_layernorm False
# 189 convnext_base_stage_2_block_20_pointwise_conv_1 True
# 190 convnext_base_stage_2_block_20_gelu True
# 191 convnext_base_stage_2_block_20_pointwise_conv_2 True
# 192 convnext_base_stage_2_block_20_layer_scale True
# 193 convnext_base_stage_2_block_20_identity True
# 194 convnext_base_stage_2_block_21_depthwise_conv True
# 195 convnext_base_stage_2_block_21_layernorm False
# 196 convnext_base_stage_2_block_21_pointwise_conv_1 True
# 197 convnext_base_stage_2_block_21_gelu True
# 198 convnext_base_stage_2_block_21_pointwise_conv_2 True
# 199 convnext_base_stage_2_block_21_layer_scale True
# 200 convnext_base_stage_2_block_21_identity True
# 201 convnext_base_stage_2_block_22_depthwise_conv True
# 202 convnext_base_stage_2_block_22_layernorm False
# 203 convnext_base_stage_2_block_22_pointwise_conv_1 True
# 204 convnext_base_stage_2_block_22_gelu True
# 205 convnext_base_stage_2_block_22_pointwise_conv_2 True
# 206 convnext_base_stage_2_block_22_layer_scale True
# 207 convnext_base_stage_2_block_22_identity True
# 208 convnext_base_stage_2_block_23_depthwise_conv True
# 209 convnext_base_stage_2_block_23_layernorm False
# 210 convnext_base_stage_2_block_23_pointwise_conv_1 True
# 211 convnext_base_stage_2_block_23_gelu True
# 212 convnext_base_stage_2_block_23_pointwise_conv_2 True
# 213 convnext_base_stage_2_block_23_layer_scale True
# 214 convnext_base_stage_2_block_23_identity True
# 215 convnext_base_stage_2_block_24_depthwise_conv True
# 216 convnext_base_stage_2_block_24_layernorm False
# 217 convnext_base_stage_2_block_24_pointwise_conv_1 True
# 218 convnext_base_stage_2_block_24_gelu True
# 219 convnext_base_stage_2_block_24_pointwise_conv_2 True
# 220 convnext_base_stage_2_block_24_layer_scale True
# 221 convnext_base_stage_2_block_24_identity True
# 222 convnext_base_stage_2_block_25_depthwise_conv True
# 223 convnext_base_stage_2_block_25_layernorm False
# 224 convnext_base_stage_2_block_25_pointwise_conv_1 True
# 225 convnext_base_stage_2_block_25_gelu True
# 226 convnext_base_stage_2_block_25_pointwise_conv_2 True
# 227 convnext_base_stage_2_block_25_layer_scale True
# 228 convnext_base_stage_2_block_25_identity True
# 229 convnext_base_stage_2_block_26_depthwise_conv True
# 230 convnext_base_stage_2_block_26_layernorm False
# 231 convnext_base_stage_2_block_26_pointwise_conv_1 True
# 232 convnext_base_stage_2_block_26_gelu True
# 233 convnext_base_stage_2_block_26_pointwise_conv_2 True
# 234 convnext_base_stage_2_block_26_layer_scale True
# 235 convnext_base_stage_2_block_26_identity True
# 236 convnext_base_downsampling_block_2 True
# 237 convnext_base_stage_3_block_0_depthwise_conv True
# 238 convnext_base_stage_3_block_0_layernorm False
# 239 convnext_base_stage_3_block_0_pointwise_conv_1 True
# 240 convnext_base_stage_3_block_0_gelu True
# 241 convnext_base_stage_3_block_0_pointwise_conv_2 True
# 242 convnext_base_stage_3_block_0_layer_scale True
# 243 convnext_base_stage_3_block_0_identity True
# 244 convnext_base_stage_3_block_1_depthwise_conv True
# 245 convnext_base_stage_3_block_1_layernorm False
# 246 convnext_base_stage_3_block_1_pointwise_conv_1 True
# 247 convnext_base_stage_3_block_1_gelu True
# 248 convnext_base_stage_3_block_1_pointwise_conv_2 True
# 249 convnext_base_stage_3_block_1_layer_scale True
# 250 convnext_base_stage_3_block_1_identity True
# 251 convnext_base_stage_3_block_2_depthwise_conv True
# 252 convnext_base_stage_3_block_2_layernorm False
# 253 convnext_base_stage_3_block_2_pointwise_conv_1 True
# 254 convnext_base_stage_3_block_2_gelu True
# 255 convnext_base_stage_3_block_2_pointwise_conv_2 True
# 256 convnext_base_stage_3_block_2_layer_scale True
# 257 convnext_base_stage_3_block_2_identity True
# 258 global_average_pooling2d True
# 259 layer_normalization False

# %%
# Display a summary of the model 1 architecture
ft_model1.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(ft_model1, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Display a summary of the model 2 architecture
ft_model2.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(ft_model2, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Display a summary of the model 3 architecture
ft_model3.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
tfk.utils.plot_model(ft_model3, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Compile the model
ft_model1.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics=['accuracy'])
ft_model2.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics=['accuracy'])
ft_model3.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics=['accuracy'])

# %%
# Fine-tune the model 1
ft_history1 = ft_model1.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy1 = round(max(ft_history1['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 1: {final_val_accuracy1}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase1_FT_' + str(final_val_accuracy1) + '.keras'
ft_model1.save(model_filename)

# Delete the model to free up resources
del ft_model1
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 122s 201ms/step - accuracy: 0.7879 - loss: 0.6355 - val_accuracy: 0.8848 - val_loss: 0.3266 - learning_rate: 1.0000e-04
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 119ms/step - accuracy: 0.9326 - loss: 0.1857 - val_accuracy: 0.8861 - val_loss: 0.3917 - learning_rate: 1.0000e-04
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9725 - loss: 0.0728 - val_accuracy: 0.8857 - val_loss: 0.4619 - learning_rate: 1.0000e-04
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9801 - loss: 0.0573 - val_accuracy: 0.8832 - val_loss: 0.4942 - learning_rate: 1.0000e-04
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9859 - loss: 0.0405 - val_accuracy: 0.8897 - val_loss: 0.4677 - learning_rate: 1.0000e-04
# Epoch 6/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9901 - loss: 0.0262
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9901 - loss: 0.0262 - val_accuracy: 0.8744 - val_loss: 0.6435 - learning_rate: 1.0000e-04
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9911 - loss: 0.0228 - val_accuracy: 0.9055 - val_loss: 0.4220 - learning_rate: 5.0000e-05
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9949 - loss: 0.0110 - val_accuracy: 0.9069 - val_loss: 0.4343 - learning_rate: 5.0000e-05
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9952 - loss: 0.0107 - val_accuracy: 0.9070 - val_loss: 0.4382 - learning_rate: 5.0000e-05
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9955 - loss: 0.0104 - val_accuracy: 0.9055 - val_loss: 0.4460 - learning_rate: 5.0000e-05
# Epoch 11/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9957 - loss: 0.0100
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9957 - loss: 0.0100 - val_accuracy: 0.9077 - val_loss: 0.4462 - learning_rate: 5.0000e-05
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9955 - loss: 0.0105 - val_accuracy: 0.9069 - val_loss: 0.4491 - learning_rate: 2.5000e-05
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9953 - loss: 0.0099 - val_accuracy: 0.9080 - val_loss: 0.4504 - learning_rate: 2.5000e-05
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9956 - loss: 0.0097 - val_accuracy: 0.9084 - val_loss: 0.4523 - learning_rate: 2.5000e-05
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9954 - loss: 0.0099 - val_accuracy: 0.9095 - val_loss: 0.4537 - learning_rate: 2.5000e-05
# Epoch 16/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9953 - loss: 0.0099
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9953 - loss: 0.0099 - val_accuracy: 0.9092 - val_loss: 0.4566 - learning_rate: 2.5000e-05
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0094 - val_accuracy: 0.9087 - val_loss: 0.4586 - learning_rate: 1.2500e-05
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0094 - val_accuracy: 0.9085 - val_loss: 0.4589 - learning_rate: 1.2500e-05
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0096 - val_accuracy: 0.9087 - val_loss: 0.4603 - learning_rate: 1.2500e-05
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9955 - loss: 0.0095 - val_accuracy: 0.9099 - val_loss: 0.4628 - learning_rate: 1.2500e-05
# Epoch 21/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9956 - loss: 0.0098
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0098 - val_accuracy: 0.9095 - val_loss: 0.4651 - learning_rate: 1.2500e-05
# Epoch 22/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0095 - val_accuracy: 0.9097 - val_loss: 0.4652 - learning_rate: 6.2500e-06
# Epoch 23/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9955 - loss: 0.0099 - val_accuracy: 0.9098 - val_loss: 0.4664 - learning_rate: 6.2500e-06
# Epoch 24/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9957 - loss: 0.0096 - val_accuracy: 0.9098 - val_loss: 0.4691 - learning_rate: 6.2500e-06
# Epoch 25/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9956 - loss: 0.0096 - val_accuracy: 0.9094 - val_loss: 0.4702 - learning_rate: 6.2500e-06
# Epoch 26/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9954 - loss: 0.0093
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9954 - loss: 0.0093 - val_accuracy: 0.9095 - val_loss: 0.4732 - learning_rate: 6.2500e-06
# Epoch 27/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9955 - loss: 0.0094 - val_accuracy: 0.9098 - val_loss: 0.4746 - learning_rate: 3.1250e-06
# Epoch 28/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9953 - loss: 0.0094 - val_accuracy: 0.9097 - val_loss: 0.4746 - learning_rate: 3.1250e-06
# Epoch 29/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9954 - loss: 0.0096 - val_accuracy: 0.9099 - val_loss: 0.4758 - learning_rate: 3.1250e-06
# Epoch 30/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9957 - loss: 0.0095 - val_accuracy: 0.9105 - val_loss: 0.4768 - learning_rate: 3.1250e-06
# Epoch 31/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9956 - loss: 0.0096
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0096 - val_accuracy: 0.9102 - val_loss: 0.4780 - learning_rate: 3.1250e-06
# Epoch 32/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9961 - loss: 0.0095 - val_accuracy: 0.9111 - val_loss: 0.4787 - learning_rate: 1.5625e-06
# Epoch 33/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9961 - loss: 0.0095 - val_accuracy: 0.9109 - val_loss: 0.4798 - learning_rate: 1.5625e-06
# Epoch 34/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0090 - val_accuracy: 0.9105 - val_loss: 0.4801 - learning_rate: 1.5625e-06
# Epoch 35/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9958 - loss: 0.0093 - val_accuracy: 0.9105 - val_loss: 0.4808 - learning_rate: 1.5625e-06
# Epoch 36/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9958 - loss: 0.0094
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9958 - loss: 0.0094 - val_accuracy: 0.9112 - val_loss: 0.4817 - learning_rate: 1.5625e-06
# Epoch 37/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9954 - loss: 0.0094 - val_accuracy: 0.9108 - val_loss: 0.4820 - learning_rate: 1.0000e-06
# Epoch 38/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9959 - loss: 0.0092 - val_accuracy: 0.9111 - val_loss: 0.4827 - learning_rate: 1.0000e-06
# Epoch 39/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0092 - val_accuracy: 0.9111 - val_loss: 0.4835 - learning_rate: 1.0000e-06
# Epoch 40/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0092 - val_accuracy: 0.9112 - val_loss: 0.4845 - learning_rate: 1.0000e-06
# Epoch 41/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9960 - loss: 0.0093 - val_accuracy: 0.9113 - val_loss: 0.4855 - learning_rate: 1.0000e-06
# Epoch 42/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9960 - loss: 0.0090 - val_accuracy: 0.9116 - val_loss: 0.4864 - learning_rate: 1.0000e-06
# Epoch 43/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9954 - loss: 0.0095 - val_accuracy: 0.9119 - val_loss: 0.4877 - learning_rate: 1.0000e-06
# Epoch 44/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9954 - loss: 0.0092 - val_accuracy: 0.9122 - val_loss: 0.4888 - learning_rate: 1.0000e-06
# Epoch 45/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9953 - loss: 0.0093 - val_accuracy: 0.9116 - val_loss: 0.4894 - learning_rate: 1.0000e-06
# Epoch 46/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9959 - loss: 0.0090 - val_accuracy: 0.9120 - val_loss: 0.4904 - learning_rate: 1.0000e-06
# Epoch 47/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0093 - val_accuracy: 0.9115 - val_loss: 0.4913 - learning_rate: 1.0000e-06
# Epoch 48/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9953 - loss: 0.0095 - val_accuracy: 0.9119 - val_loss: 0.4928 - learning_rate: 1.0000e-06
# Epoch 49/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0093 - val_accuracy: 0.9122 - val_loss: 0.4938 - learning_rate: 1.0000e-06
# Epoch 50/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9959 - loss: 0.0091 - val_accuracy: 0.9120 - val_loss: 0.4954 - learning_rate: 1.0000e-06
# Epoch 51/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9955 - loss: 0.0093 - val_accuracy: 0.9123 - val_loss: 0.4961 - learning_rate: 1.0000e-06
# Epoch 52/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0093 - val_accuracy: 0.9122 - val_loss: 0.4977 - learning_rate: 1.0000e-06
# Epoch 53/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9960 - loss: 0.0092 - val_accuracy: 0.9123 - val_loss: 0.4981 - learning_rate: 1.0000e-06
# Epoch 54/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9959 - loss: 0.0092 - val_accuracy: 0.9124 - val_loss: 0.4995 - learning_rate: 1.0000e-06
# Epoch 55/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9957 - loss: 0.0090 - val_accuracy: 0.9130 - val_loss: 0.5005 - learning_rate: 1.0000e-06
# Epoch 56/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9962 - loss: 0.0089 - val_accuracy: 0.9131 - val_loss: 0.5017 - learning_rate: 1.0000e-06
# Epoch 57/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9955 - loss: 0.0093 - val_accuracy: 0.9130 - val_loss: 0.5023 - learning_rate: 1.0000e-06
# Epoch 58/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9958 - loss: 0.0092 - val_accuracy: 0.9130 - val_loss: 0.5033 - learning_rate: 1.0000e-06
# Epoch 59/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9961 - loss: 0.0091 - val_accuracy: 0.9124 - val_loss: 0.5046 - learning_rate: 1.0000e-06
# Epoch 60/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9960 - loss: 0.0091 - val_accuracy: 0.9130 - val_loss: 0.5052 - learning_rate: 1.0000e-06
# Epoch 61/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0092 - val_accuracy: 0.9130 - val_loss: 0.5064 - learning_rate: 1.0000e-06
# Epoch 62/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9955 - loss: 0.0094 - val_accuracy: 0.9131 - val_loss: 0.5071 - learning_rate: 1.0000e-06
# Epoch 63/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9958 - loss: 0.0094 - val_accuracy: 0.9134 - val_loss: 0.5082 - learning_rate: 1.0000e-06
# Epoch 64/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9964 - loss: 0.0089 - val_accuracy: 0.9136 - val_loss: 0.5088 - learning_rate: 1.0000e-06
# Epoch 65/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9958 - loss: 0.0093 - val_accuracy: 0.9129 - val_loss: 0.5097 - learning_rate: 1.0000e-06
# Epoch 66/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9961 - loss: 0.0092 - val_accuracy: 0.9133 - val_loss: 0.5105 - learning_rate: 1.0000e-06
# Epoch 67/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0095 - val_accuracy: 0.9134 - val_loss: 0.5115 - learning_rate: 1.0000e-06
# Epoch 68/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9964 - loss: 0.0088 - val_accuracy: 0.9136 - val_loss: 0.5123 - learning_rate: 1.0000e-06
# Epoch 69/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9958 - loss: 0.0092 - val_accuracy: 0.9133 - val_loss: 0.5129 - learning_rate: 1.0000e-06
# Epoch 70/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0092 - val_accuracy: 0.9133 - val_loss: 0.5142 - learning_rate: 1.0000e-06
# Epoch 71/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9962 - loss: 0.0090 - val_accuracy: 0.9131 - val_loss: 0.5150 - learning_rate: 1.0000e-06
# Epoch 72/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9960 - loss: 0.0091 - val_accuracy: 0.9133 - val_loss: 0.5158 - learning_rate: 1.0000e-06
# Epoch 73/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0092 - val_accuracy: 0.9130 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 74/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9965 - loss: 0.0088 - val_accuracy: 0.9131 - val_loss: 0.5180 - learning_rate: 1.0000e-06
# Epoch 75/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9959 - loss: 0.0090 - val_accuracy: 0.9130 - val_loss: 0.5191 - learning_rate: 1.0000e-06
# Epoch 76/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0089 - val_accuracy: 0.9133 - val_loss: 0.5196 - learning_rate: 1.0000e-06
# Epoch 77/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9958 - loss: 0.0090 - val_accuracy: 0.9138 - val_loss: 0.5204 - learning_rate: 1.0000e-06
# Epoch 78/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9958 - loss: 0.0090 - val_accuracy: 0.9138 - val_loss: 0.5211 - learning_rate: 1.0000e-06
# Epoch 79/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9959 - loss: 0.0090 - val_accuracy: 0.9134 - val_loss: 0.5219 - learning_rate: 1.0000e-06
# Epoch 80/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0093 - val_accuracy: 0.9133 - val_loss: 0.5224 - learning_rate: 1.0000e-06
# Epoch 81/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9959 - loss: 0.0091 - val_accuracy: 0.9133 - val_loss: 0.5231 - learning_rate: 1.0000e-06
# Epoch 82/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0094 - val_accuracy: 0.9133 - val_loss: 0.5239 - learning_rate: 1.0000e-06
# Epoch 83/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9959 - loss: 0.0090 - val_accuracy: 0.9129 - val_loss: 0.5245 - learning_rate: 1.0000e-06
# Epoch 84/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9954 - loss: 0.0093 - val_accuracy: 0.9129 - val_loss: 0.5252 - learning_rate: 1.0000e-06
# Epoch 85/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0092 - val_accuracy: 0.9130 - val_loss: 0.5258 - learning_rate: 1.0000e-06
# Epoch 86/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9962 - loss: 0.0089 - val_accuracy: 0.9131 - val_loss: 0.5266 - learning_rate: 1.0000e-06
# Epoch 87/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0092 - val_accuracy: 0.9127 - val_loss: 0.5267 - learning_rate: 1.0000e-06
# Epoch 88/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9961 - loss: 0.0089 - val_accuracy: 0.9130 - val_loss: 0.5272 - learning_rate: 1.0000e-06
# Epoch 89/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9958 - loss: 0.0089 - val_accuracy: 0.9129 - val_loss: 0.5279 - learning_rate: 1.0000e-06
# Epoch 90/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9962 - loss: 0.0091 - val_accuracy: 0.9129 - val_loss: 0.5284 - learning_rate: 1.0000e-06
# Epoch 91/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0092 - val_accuracy: 0.9126 - val_loss: 0.5285 - learning_rate: 1.0000e-06
# Epoch 92/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9955 - loss: 0.0091 - val_accuracy: 0.9126 - val_loss: 0.5291 - learning_rate: 1.0000e-06
# Epoch 93/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9960 - loss: 0.0090 - val_accuracy: 0.9127 - val_loss: 0.5299 - learning_rate: 1.0000e-06
# Epoch 94/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9957 - loss: 0.0093 - val_accuracy: 0.9131 - val_loss: 0.5305 - learning_rate: 1.0000e-06
# Epoch 95/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9955 - loss: 0.0092 - val_accuracy: 0.9129 - val_loss: 0.5307 - learning_rate: 1.0000e-06
# Epoch 96/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9956 - loss: 0.0091 - val_accuracy: 0.9129 - val_loss: 0.5310 - learning_rate: 1.0000e-06
# Epoch 97/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9962 - loss: 0.0090 - val_accuracy: 0.9131 - val_loss: 0.5315 - learning_rate: 1.0000e-06
# Final validation accuracy 1: 91.38%

# %%
# Fine-tune the model 2
ft_history2 = ft_model2.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy2 = round(max(ft_history2['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 2: {final_val_accuracy2}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase2_FT_' + str(final_val_accuracy2) + '.keras'
ft_model2.save(model_filename)

# Delete the model to free up resources
del ft_model2
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 119s 193ms/step - accuracy: 0.9219 - loss: 0.2333 - val_accuracy: 0.8317 - val_loss: 0.6617 - learning_rate: 1.0000e-04
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9576 - loss: 0.1207 - val_accuracy: 0.8420 - val_loss: 0.5986 - learning_rate: 1.0000e-04
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9798 - loss: 0.0485 - val_accuracy: 0.8479 - val_loss: 0.6377 - learning_rate: 1.0000e-04
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9903 - loss: 0.0276 - val_accuracy: 0.8642 - val_loss: 0.5876 - learning_rate: 1.0000e-04
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9926 - loss: 0.0218 - val_accuracy: 0.8578 - val_loss: 0.6128 - learning_rate: 1.0000e-04
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9886 - loss: 0.0308 - val_accuracy: 0.8585 - val_loss: 0.6796 - learning_rate: 1.0000e-04
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9858 - loss: 0.0397 - val_accuracy: 0.8565 - val_loss: 0.6533 - learning_rate: 1.0000e-04
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9858 - loss: 0.0352 - val_accuracy: 0.8439 - val_loss: 0.7392 - learning_rate: 1.0000e-04
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9901 - loss: 0.0248 - val_accuracy: 0.8745 - val_loss: 0.5711 - learning_rate: 1.0000e-04
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9920 - loss: 0.0192 - val_accuracy: 0.8664 - val_loss: 0.6550 - learning_rate: 1.0000e-04
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9899 - loss: 0.0291 - val_accuracy: 0.8709 - val_loss: 0.6254 - learning_rate: 1.0000e-04
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9920 - loss: 0.0178 - val_accuracy: 0.8839 - val_loss: 0.5744 - learning_rate: 1.0000e-04
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9944 - loss: 0.0132 - val_accuracy: 0.8748 - val_loss: 0.6262 - learning_rate: 1.0000e-04
# Epoch 14/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9942 - loss: 0.0134
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9942 - loss: 0.0134 - val_accuracy: 0.8695 - val_loss: 0.7090 - learning_rate: 1.0000e-04
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9945 - loss: 0.0123 - val_accuracy: 0.8853 - val_loss: 0.6019 - learning_rate: 5.0000e-05
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9961 - loss: 0.0089 - val_accuracy: 0.8816 - val_loss: 0.5928 - learning_rate: 5.0000e-05
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9967 - loss: 0.0077 - val_accuracy: 0.8814 - val_loss: 0.6184 - learning_rate: 5.0000e-05
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9969 - loss: 0.0073 - val_accuracy: 0.8777 - val_loss: 0.6353 - learning_rate: 5.0000e-05
# Epoch 19/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9968 - loss: 0.0074
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9968 - loss: 0.0074 - val_accuracy: 0.8766 - val_loss: 0.6504 - learning_rate: 5.0000e-05
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9977 - loss: 0.0060 - val_accuracy: 0.8790 - val_loss: 0.6421 - learning_rate: 2.5000e-05
# Final validation accuracy 2: 88.53%

# %%
# Fine-tune the model 3
ft_history3 = ft_model3.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy3 = round(max(ft_history3['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 3: {final_val_accuracy3}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase3_FT_' + str(final_val_accuracy3) + '.keras'
ft_model3.save(model_filename)

# Delete the model to free up resources
del ft_model3
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 118s 196ms/step - accuracy: 0.7905 - loss: 0.6128 - val_accuracy: 0.8724 - val_loss: 0.3589 - learning_rate: 1.0000e-04
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 119ms/step - accuracy: 0.9293 - loss: 0.2018 - val_accuracy: 0.8953 - val_loss: 0.3132 - learning_rate: 1.0000e-04
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9783 - loss: 0.0691 - val_accuracy: 0.8959 - val_loss: 0.3766 - learning_rate: 1.0000e-04
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 39s 117ms/step - accuracy: 0.9895 - loss: 0.0350 - val_accuracy: 0.8723 - val_loss: 0.5199 - learning_rate: 1.0000e-04
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9891 - loss: 0.0372 - val_accuracy: 0.8920 - val_loss: 0.4323 - learning_rate: 1.0000e-04
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9916 - loss: 0.0243 - val_accuracy: 0.8973 - val_loss: 0.4197 - learning_rate: 1.0000e-04
# Epoch 7/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9923 - loss: 0.0203
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9923 - loss: 0.0203 - val_accuracy: 0.9005 - val_loss: 0.4078 - learning_rate: 1.0000e-04
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9945 - loss: 0.0150 - val_accuracy: 0.9067 - val_loss: 0.4021 - learning_rate: 5.0000e-05
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9953 - loss: 0.0115 - val_accuracy: 0.9084 - val_loss: 0.4051 - learning_rate: 5.0000e-05
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9957 - loss: 0.0104 - val_accuracy: 0.9074 - val_loss: 0.4052 - learning_rate: 5.0000e-05
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9958 - loss: 0.0101 - val_accuracy: 0.9094 - val_loss: 0.4074 - learning_rate: 5.0000e-05
# Epoch 12/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9959 - loss: 0.0100
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9958 - loss: 0.0100 - val_accuracy: 0.9095 - val_loss: 0.4151 - learning_rate: 5.0000e-05
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9960 - loss: 0.0098 - val_accuracy: 0.9097 - val_loss: 0.4146 - learning_rate: 2.5000e-05
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9966 - loss: 0.0089 - val_accuracy: 0.9087 - val_loss: 0.4212 - learning_rate: 2.5000e-05
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9963 - loss: 0.0093 - val_accuracy: 0.9092 - val_loss: 0.4299 - learning_rate: 2.5000e-05
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9962 - loss: 0.0093 - val_accuracy: 0.9076 - val_loss: 0.4326 - learning_rate: 2.5000e-05
# Epoch 17/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9959 - loss: 0.0096
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9959 - loss: 0.0096 - val_accuracy: 0.9073 - val_loss: 0.4411 - learning_rate: 2.5000e-05
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9967 - loss: 0.0084 - val_accuracy: 0.9084 - val_loss: 0.4366 - learning_rate: 1.2500e-05
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.9965 - loss: 0.0081 - val_accuracy: 0.9076 - val_loss: 0.4364 - learning_rate: 1.2500e-05
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9970 - loss: 0.0078 - val_accuracy: 0.9066 - val_loss: 0.4553 - learning_rate: 1.2500e-05
# Final validation accuracy 3: 90.97%

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history1['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history1['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history1['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history1['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy 1')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history1['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history1['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history1['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history1['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy 1')

# Dynamically calculate y-axis limits for accuracy
all_accuracies = (
    tl_history1['accuracy'] +
    tl_history1['val_accuracy'] +
    ft_history1['accuracy'] +
    ft_history1['val_accuracy']
)
ax2.set_ylim([min(all_accuracies) * 0.95, max(all_accuracies) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history2['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history2['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history2['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history2['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy 1')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history2['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history2['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history2['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history2['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy 1')

# Dynamically calculate y-axis limits for accuracy
all_accuracies = (
    tl_history2['accuracy'] +
    tl_history2['val_accuracy'] +
    ft_history2['accuracy'] +
    ft_history2['val_accuracy']
)
ax2.set_ylim([min(all_accuracies) * 0.95, max(all_accuracies) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history3['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history3['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history3['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history3['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy 1')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history3['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history3['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history3['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history3['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy 1')

# Dynamically calculate y-axis limits for accuracy
all_accuracies = (
    tl_history3['accuracy'] +
    tl_history3['val_accuracy'] +
    ft_history3['accuracy'] +
    ft_history3['val_accuracy']
)
ax2.set_ylim([min(all_accuracies) * 0.95, max(all_accuracies) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Final fine tuning
# Unfreeze all layers

# %%
# Re-load the model after first fine tuning
ft_full_model1 = tfk.models.load_model('ConvNeXtBase1_FT_91.38.keras')  # model 1

# Unfreeze all layers
for layer in ft_full_model1.get_layer('convnext_base').layers:
    layer.trainable = True

# Set the BatchNorm layers as non-trainable
for layer in ft_full_model1.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False

# Recompile the model
ft_full_model1.compile(
    loss=tfk.losses.CategoricalCrossentropy(),
    optimizer=tfk.optimizers.Adam(learning_rate=1e-5),
    metrics=['accuracy']
)

# Training with full fine tuning
ft_history1_full = ft_full_model1.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy1_full = round(max(ft_history1_full['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 1 (full): {final_val_accuracy1_full}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase1_FTfull_' + str(final_val_accuracy1_full) + '.keras'
ft_full_model1.save(model_filename)

# Delete the model to free up resources
del ft_full_model1
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 145s 243ms/step - accuracy: 0.9962 - loss: 0.0097 - val_accuracy: 0.9081 - val_loss: 0.5441 - learning_rate: 1.0000e-05
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 153ms/step - accuracy: 0.9954 - loss: 0.0095 - val_accuracy: 0.9115 - val_loss: 0.5357 - learning_rate: 1.0000e-05
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 151ms/step - accuracy: 0.9951 - loss: 0.0098 - val_accuracy: 0.9092 - val_loss: 0.5338 - learning_rate: 1.0000e-05
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9955 - loss: 0.0096 - val_accuracy: 0.9109 - val_loss: 0.5360 - learning_rate: 1.0000e-05
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9954 - loss: 0.0096 - val_accuracy: 0.9113 - val_loss: 0.5396 - learning_rate: 1.0000e-05
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9954 - loss: 0.0095 - val_accuracy: 0.9116 - val_loss: 0.5385 - learning_rate: 1.0000e-05
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9958 - loss: 0.0095 - val_accuracy: 0.9120 - val_loss: 0.5393 - learning_rate: 1.0000e-05
# Epoch 8/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9958 - loss: 0.0095
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9958 - loss: 0.0095 - val_accuracy: 0.9113 - val_loss: 0.5406 - learning_rate: 1.0000e-05
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 151ms/step - accuracy: 0.9953 - loss: 0.0095 - val_accuracy: 0.9116 - val_loss: 0.5412 - learning_rate: 5.0000e-06
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9959 - loss: 0.0094 - val_accuracy: 0.9122 - val_loss: 0.5441 - learning_rate: 5.0000e-06
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9958 - loss: 0.0093 - val_accuracy: 0.9133 - val_loss: 0.5454 - learning_rate: 5.0000e-06
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 151ms/step - accuracy: 0.9955 - loss: 0.0094 - val_accuracy: 0.9138 - val_loss: 0.5459 - learning_rate: 5.0000e-06
# Epoch 13/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9953 - loss: 0.0097
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9953 - loss: 0.0097 - val_accuracy: 0.9108 - val_loss: 0.5482 - learning_rate: 5.0000e-06
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9956 - loss: 0.0098 - val_accuracy: 0.9095 - val_loss: 0.5396 - learning_rate: 2.5000e-06
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9954 - loss: 0.0095 - val_accuracy: 0.9101 - val_loss: 0.5387 - learning_rate: 2.5000e-06
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9957 - loss: 0.0093 - val_accuracy: 0.9113 - val_loss: 0.5383 - learning_rate: 2.5000e-06
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9955 - loss: 0.0095 - val_accuracy: 0.9109 - val_loss: 0.5389 - learning_rate: 2.5000e-06
# Epoch 18/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9960 - loss: 0.0092
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9960 - loss: 0.0092 - val_accuracy: 0.9116 - val_loss: 0.5407 - learning_rate: 2.5000e-06
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9960 - loss: 0.0091 - val_accuracy: 0.9113 - val_loss: 0.5412 - learning_rate: 1.2500e-06
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9956 - loss: 0.0091 - val_accuracy: 0.9112 - val_loss: 0.5413 - learning_rate: 1.2500e-06
# Final validation accuracy 1 (full): 91.38%

# %%
# Re-load the model after first fine tuning
ft_full_model2 = tfk.models.load_model('ConvNeXtBase2_FT_88.53.keras')  # model 2

# Unfreeze all layers
for layer in ft_full_model2.get_layer('convnext_base').layers:
    layer.trainable = True

# Set the BatchNorm layers as non-trainable
for layer in ft_full_model2.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False

# Recompile the model
ft_full_model2.compile(
    loss=tfk.losses.CategoricalCrossentropy(),
    optimizer=tfk.optimizers.Adam(learning_rate=1e-5),
    metrics=['accuracy']
)

# Training with full fine tuning
ft_history2_full = ft_full_model2.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy2_full = round(max(ft_history2_full['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 2 (full): {final_val_accuracy2_full}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase2_FTfull_' + str(final_val_accuracy2_full) + '.keras'
ft_full_model2.save(model_filename)

# Delete the model to free up resources
del ft_full_model2
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 142s 240ms/step - accuracy: 0.9632 - loss: 0.1050 - val_accuracy: 0.8504 - val_loss: 0.5651 - learning_rate: 1.0000e-05
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 153ms/step - accuracy: 0.9888 - loss: 0.0330 - val_accuracy: 0.8517 - val_loss: 0.5678 - learning_rate: 1.0000e-05
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 151ms/step - accuracy: 0.9935 - loss: 0.0222 - val_accuracy: 0.8542 - val_loss: 0.5702 - learning_rate: 1.0000e-05
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9950 - loss: 0.0177 - val_accuracy: 0.8545 - val_loss: 0.5778 - learning_rate: 1.0000e-05
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9962 - loss: 0.0144 - val_accuracy: 0.8549 - val_loss: 0.5824 - learning_rate: 1.0000e-05
# Epoch 6/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9954 - loss: 0.0134
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 151ms/step - accuracy: 0.9954 - loss: 0.0134 - val_accuracy: 0.8563 - val_loss: 0.5859 - learning_rate: 1.0000e-05
# Epoch 7/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9963 - loss: 0.0119 - val_accuracy: 0.8572 - val_loss: 0.5859 - learning_rate: 5.0000e-06
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9961 - loss: 0.0114 - val_accuracy: 0.8581 - val_loss: 0.5927 - learning_rate: 5.0000e-06
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9965 - loss: 0.0109 - val_accuracy: 0.8578 - val_loss: 0.5920 - learning_rate: 5.0000e-06
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 153ms/step - accuracy: 0.9963 - loss: 0.0104 - val_accuracy: 0.8570 - val_loss: 0.5974 - learning_rate: 5.0000e-06
# Epoch 11/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9965 - loss: 0.0097
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9965 - loss: 0.0097 - val_accuracy: 0.8578 - val_loss: 0.5950 - learning_rate: 5.0000e-06
# Epoch 12/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9969 - loss: 0.0097 - val_accuracy: 0.8584 - val_loss: 0.5995 - learning_rate: 2.5000e-06
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9971 - loss: 0.0091 - val_accuracy: 0.8578 - val_loss: 0.6022 - learning_rate: 2.5000e-06
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.8586 - val_loss: 0.6028 - learning_rate: 2.5000e-06
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9976 - loss: 0.0088 - val_accuracy: 0.8581 - val_loss: 0.6035 - learning_rate: 2.5000e-06
# Epoch 16/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9972 - loss: 0.0084
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9972 - loss: 0.0084 - val_accuracy: 0.8581 - val_loss: 0.6065 - learning_rate: 2.5000e-06
# Epoch 17/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9969 - loss: 0.0086 - val_accuracy: 0.8581 - val_loss: 0.6083 - learning_rate: 1.2500e-06
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9975 - loss: 0.0081 - val_accuracy: 0.8591 - val_loss: 0.6094 - learning_rate: 1.2500e-06
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9970 - loss: 0.0081 - val_accuracy: 0.8582 - val_loss: 0.6099 - learning_rate: 1.2500e-06
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9969 - loss: 0.0079 - val_accuracy: 0.8578 - val_loss: 0.6115 - learning_rate: 1.2500e-06
# Final validation accuracy 2 (full): 85.91%

# %%
# Re-load the model after first fine tuning
ft_full_model3 = tfk.models.load_model('ConvNeXtBase3_FT_90.97.keras')  # model 3

# Unfreeze all layers
for layer in ft_full_model3.get_layer('convnext_base').layers:
    layer.trainable = True

# Set the BatchNorm layers as non-trainable
for layer in ft_full_model3.get_layer('convnext_base').layers:
    if isinstance(layer, tf.keras.layers.LayerNormalization):
        layer.trainable = False

# Recompile the model
ft_full_model3.compile(
    loss=tfk.losses.CategoricalCrossentropy(),
    optimizer=tfk.optimizers.Adam(learning_rate=1e-5),
    metrics=['accuracy']
)

# Training with full fine tuning
ft_history3_full = ft_full_model3.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr]
).history

# Calculate and print the final validation accuracy
final_val_accuracy3_full = round(max(ft_history3_full['val_accuracy']) * 100, 2)
print(f'Final validation accuracy 3 (full): {final_val_accuracy3_full}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'ConvNeXtBase3_FTfull_' + str(final_val_accuracy3_full) + '.keras'
ft_full_model3.save(model_filename)

# Delete the model to free up resources
del ft_full_model3
# Out:
# Epoch 1/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 147s 248ms/step - accuracy: 0.9303 - loss: 0.1997 - val_accuracy: 0.9020 - val_loss: 0.2816 - learning_rate: 1.0000e-05
# Epoch 2/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 52s 153ms/step - accuracy: 0.9602 - loss: 0.1232 - val_accuracy: 0.9073 - val_loss: 0.2743 - learning_rate: 1.0000e-05
# Epoch 3/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 151ms/step - accuracy: 0.9791 - loss: 0.0766 - val_accuracy: 0.9053 - val_loss: 0.2848 - learning_rate: 1.0000e-05
# Epoch 4/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9883 - loss: 0.0469 - val_accuracy: 0.9073 - val_loss: 0.2954 - learning_rate: 1.0000e-05
# Epoch 5/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9932 - loss: 0.0316 - val_accuracy: 0.9078 - val_loss: 0.3093 - learning_rate: 1.0000e-05
# Epoch 6/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9943 - loss: 0.0239 - val_accuracy: 0.9076 - val_loss: 0.3182 - learning_rate: 1.0000e-05
# Epoch 7/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9953 - loss: 0.0190
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9953 - loss: 0.0190 - val_accuracy: 0.9052 - val_loss: 0.3357 - learning_rate: 1.0000e-05
# Epoch 8/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9957 - loss: 0.0164 - val_accuracy: 0.9078 - val_loss: 0.3371 - learning_rate: 5.0000e-06
# Epoch 9/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9958 - loss: 0.0152 - val_accuracy: 0.9069 - val_loss: 0.3453 - learning_rate: 5.0000e-06
# Epoch 10/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9961 - loss: 0.0141 - val_accuracy: 0.9058 - val_loss: 0.3516 - learning_rate: 5.0000e-06
# Epoch 11/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9963 - loss: 0.0134 - val_accuracy: 0.9055 - val_loss: 0.3594 - learning_rate: 5.0000e-06
# Epoch 12/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9958 - loss: 0.0132
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9958 - loss: 0.0132 - val_accuracy: 0.9066 - val_loss: 0.3689 - learning_rate: 5.0000e-06
# Epoch 13/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9958 - loss: 0.0127 - val_accuracy: 0.9053 - val_loss: 0.3652 - learning_rate: 2.5000e-06
# Epoch 14/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9959 - loss: 0.0123 - val_accuracy: 0.9060 - val_loss: 0.3694 - learning_rate: 2.5000e-06
# Epoch 15/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9959 - loss: 0.0119 - val_accuracy: 0.9060 - val_loss: 0.3746 - learning_rate: 2.5000e-06
# Epoch 16/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9963 - loss: 0.0117 - val_accuracy: 0.9052 - val_loss: 0.3807 - learning_rate: 2.5000e-06
# Epoch 17/200
# 336/337 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9959 - loss: 0.0116
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9959 - loss: 0.0116 - val_accuracy: 0.9055 - val_loss: 0.3841 - learning_rate: 2.5000e-06
# Epoch 18/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9957 - loss: 0.0115 - val_accuracy: 0.9051 - val_loss: 0.3847 - learning_rate: 1.2500e-06
# Epoch 19/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9961 - loss: 0.0110 - val_accuracy: 0.9049 - val_loss: 0.3862 - learning_rate: 1.2500e-06
# Epoch 20/200
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 51s 152ms/step - accuracy: 0.9963 - loss: 0.0109 - val_accuracy: 0.9039 - val_loss: 0.3893 - learning_rate: 1.2500e-06
# Final validation accuracy 3 (full): 90.78%

# %% [markdown]
# ## 🕹️ Use the Model - Make Inference

# %% [markdown]
# ### Test model on test set

# %% [markdown]
# #### 1. Test set without augmentation

# %%
# Load the fine-tuned MobileNetV3 model for prediction on external images
ft_model1 = tfk.models.load_model('ConvNeXtBase1_FTfull_91.38.keras')
ft_model2 = tfk.models.load_model('ConvNeXtBase2_FTfull_85.91.keras')
ft_model3 = tfk.models.load_model('ConvNeXtBase3_FTfull_90.78.keras')

# %%
# Predict labels for the entire test set
predictions1 = ft_model1.predict(X_test, verbose=0)

# Convert predictions to class labels
pred_classes1 = np.argmax(predictions1, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy1 = accuracy_score(true_classes, pred_classes1)
print(f'Accuracy 1 score over the test set: {round(accuracy1, 4)}')

# Calculate and display test set precision
precision1 = precision_score(true_classes, pred_classes1, average='weighted')
print(f'Precision 1 score over the test set: {round(precision1, 4)}')

# Calculate and display test set recall
recall1 = recall_score(true_classes, pred_classes1, average='weighted')
print(f'Recall score 1 over the test set: {round(recall1, 4)}')

# Calculate and display test set F1 score
f11 = f1_score(true_classes, pred_classes1, average='weighted')
print(f'F1 score 1 over the test set: {round(f11, 4)}')

# Compute the confusion matrix
cm1 = confusion_matrix(true_classes, pred_classes1)

# Combine numbers and percentages into a single string for annotation
annot1 = np.array([f"{num}" for num in cm1.flatten()]).reshape(cm1.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm1.T, annot=annot1, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 1 score over the test set: 0.9808
# Precision 1 score over the test set: 0.9813
# Recall score 1 over the test set: 0.9808
# F1 score 1 over the test set: 0.9808

# %%
# Predict labels for the entire test set
predictions2 = ft_model2.predict(X_test, verbose=0)

# Convert predictions to class labels
pred_classes2 = np.argmax(predictions2, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy2 = accuracy_score(true_classes, pred_classes2)
print(f'Accuracy 2 score over the test set: {round(accuracy2, 4)}')

# Calculate and display test set precision
precision2 = precision_score(true_classes, pred_classes2, average='weighted')
print(f'Precision 2 score over the test set: {round(precision2, 4)}')

# Calculate and display test set recall
recall2 = recall_score(true_classes, pred_classes2, average='weighted')
print(f'Recall score 2 over the test set: {round(recall2, 4)}')

# Calculate and display test set F1 score
f12 = f1_score(true_classes, pred_classes2, average='weighted')
print(f'F1 score 2 over the test set: {round(f12, 4)}')

# Compute the confusion matrix
cm2 = confusion_matrix(true_classes, pred_classes2)

# Combine numbers and percentages into a single string for annotation
annot2 = np.array([f"{num}" for num in cm2.flatten()]).reshape(cm2.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm2.T, annot=annot2, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 2 score over the test set: 0.9703
# Precision 2 score over the test set: 0.9709
# Recall score 2 over the test set: 0.9703
# F1 score 2 over the test set: 0.9704

# %%
# Predict labels for the entire test set
predictions3 = ft_model3.predict(X_test, verbose=0)

# Convert predictions to class labels
pred_classes3 = np.argmax(predictions3, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy3 = accuracy_score(true_classes, pred_classes3)
print(f'Accuracy 3 score over the test set: {round(accuracy3, 4)}')

# Calculate and display test set precision
precision3 = precision_score(true_classes, pred_classes3, average='weighted')
print(f'Precision 3 score over the test set: {round(precision3, 4)}')

# Calculate and display test set recall
recall3 = recall_score(true_classes, pred_classes3, average='weighted')
print(f'Recall score 3 over the test set: {round(recall3, 4)}')

# Calculate and display test set F1 score
f13 = f1_score(true_classes, pred_classes3, average='weighted')
print(f'F1 score 3 over the test set: {round(f13, 4)}')

# Compute the confusion matrix
cm3 = confusion_matrix(true_classes, pred_classes3)

# Combine numbers and percentages into a single string for annotation
annot3 = np.array([f"{num}" for num in cm3.flatten()]).reshape(cm3.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm3.T, annot=annot3, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 3 score over the test set: 0.9803
# Precision 3 score over the test set: 0.9808
# Recall score 3 over the test set: 0.9803
# F1 score 3 over the test set: 0.9803

# %% [markdown]
# #### 2. Test set with augmentation

# %%
# Predict labels for the entire test set
predictions1_aug = ft_model1.predict(X_test_augmented, verbose=0)

# Convert predictions to class labels
pred_classes1_aug = np.argmax(predictions1_aug, axis=-1)

# Extract ground truth classes
true_classes_aug = np.argmax(y_test_augmented, axis=-1)

# Calculate and display test set accuracy
accuracy1_aug = accuracy_score(true_classes_aug, pred_classes1_aug)
print(f'Accuracy 1 score over the test set augmented: {round(accuracy1_aug, 4)}')

# Calculate and display test set precision
precision1_aug = precision_score(true_classes_aug, pred_classes1_aug, average='weighted')
print(f'Precision 1 score over the test set augmented: {round(precision1_aug, 4)}')

# Calculate and display test set recall
recall1_aug = recall_score(true_classes_aug, pred_classes1_aug, average='weighted')
print(f'Recall score 1 over the test set augmented: {round(recall1_aug, 4)}')

# Calculate and display test set F1 score
f11_aug = f1_score(true_classes_aug, pred_classes1_aug, average='weighted')
print(f'F1 score 1 over the test set augmented: {round(f11_aug, 4)}')

# Compute the confusion matrix
cm1_aug = confusion_matrix(true_classes_aug, pred_classes1_aug)

# Combine numbers and percentages into a single string for annotation
annot1_aug = np.array([f"{num}" for num in cm1_aug.flatten()]).reshape(cm1_aug.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm1_aug.T, annot=annot1_aug, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 1 score over the test set augmented: 0.8001
# Precision 1 score over the test set augmented: 0.8058
# Recall score 1 over the test set augmented: 0.8001
# F1 score 1 over the test set augmented: 0.7992

# %%
# Predict labels for the entire test set
predictions2_aug = ft_model2.predict(X_test_augmented, verbose=0)

# Convert predictions to class labels
pred_classes2_aug = np.argmax(predictions2_aug, axis=-1)

# Extract ground truth classes
true_classes_aug = np.argmax(y_test_augmented, axis=-1)

# Calculate and display test set accuracy
accuracy2_aug = accuracy_score(true_classes_aug, pred_classes2_aug)
print(f'Accuracy 2 score over the test set augmented: {round(accuracy2_aug, 4)}')

# Calculate and display test set precision
precision2_aug = precision_score(true_classes_aug, pred_classes2_aug, average='weighted')
print(f'Precision 2 score over the test set augmented: {round(precision2_aug, 4)}')

# Calculate and display test set recall
recall2_aug = recall_score(true_classes_aug, pred_classes2_aug, average='weighted')
print(f'Recall score 2 over the test set augmented: {round(recall2_aug, 4)}')

# Calculate and display test set F1 score
f12_aug = f1_score(true_classes_aug, pred_classes2_aug, average='weighted')
print(f'F1 score 2 over the test set augmented: {round(f12_aug, 4)}')

# Compute the confusion matrix
cm2_aug = confusion_matrix(true_classes_aug, pred_classes2_aug)

# Combine numbers and percentages into a single string for annotation
annot2_aug = np.array([f"{num}" for num in cm2_aug.flatten()]).reshape(cm2_aug.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm2_aug.T, annot=annot2_aug, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 2 score over the test set augmented: 0.7157
# Precision 2 score over the test set augmented: 0.723
# Recall score 2 over the test set augmented: 0.7157
# F1 score 2 over the test set augmented: 0.7155

# %%
# Predict labels for the entire test set
predictions3_aug = ft_model3.predict(X_test_augmented, verbose=0)

# Convert predictions to class labels
pred_classes3_aug = np.argmax(predictions3_aug, axis=-1)

# Extract ground truth classes
true_classes_aug = np.argmax(y_test_augmented, axis=-1)

# Calculate and display test set accuracy
accuracy3_aug = accuracy_score(true_classes_aug, pred_classes3_aug)
print(f'Accuracy 3 score over the test set augmented: {round(accuracy3_aug, 4)}')

# Calculate and display test set precision
precision3_aug = precision_score(true_classes_aug, pred_classes3_aug, average='weighted')
print(f'Precision 3 score over the test set augmented: {round(precision3_aug, 4)}')

# Calculate and display test set recall
recall3_aug = recall_score(true_classes_aug, pred_classes3_aug, average='weighted')
print(f'Recall score 3 over the test set augmented: {round(recall3_aug, 4)}')

# Calculate and display test set F1 score
f13_aug = f1_score(true_classes_aug, pred_classes3_aug, average='weighted')
print(f'F1 score 3 over the test set augmented: {round(f13_aug, 4)}')

# Compute the confusion matrix
cm3_aug = confusion_matrix(true_classes_aug, pred_classes3_aug)

# Combine numbers and percentages into a single string for annotation
annot3_aug = np.array([f"{num}" for num in cm3_aug.flatten()]).reshape(cm3_aug.shape)

# Define class labels
labels = {0: "Basophil", 1: "Eosinophil", 2: "Erythroblast", 3: "Immature granulocytes",
          4: "Lymphocyte", 5: "Monocyte", 6: "Neutrophil", 7: "Platelet"}

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm3_aug.T, annot=annot3_aug, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy 3 score over the test set augmented: 0.7961
# Precision 3 score over the test set augmented: 0.8034
# Recall score 3 over the test set augmented: 0.7961
# F1 score 3 over the test set augmented: 0.7953

# %% [markdown]
# ## 📊 Prepare Your Submission
#
# To prepare your submission, create a `.zip` file that includes all the necessary code to run your model. It **must** include a `model.py` file with the following class:
#
# ```python
#
# # file: model.py
#
# import tensorflow as tf
# import numpy as np
#
# class Model:
#     def __init__(self):
#         """Initialize the internal state of the model."""
#
#         # Load the pre-trained model weights
#         self.model = tf.keras.models.load_model('weights.keras')  # Path to your saved weights
#
#     def predict(self, X):
#         """
#         Return a numpy array with the labels corresponding to the input X.
#         X: numpy array of input images.
#         """
#         predictions = self.model.predict(X)
#         # Return the class labels as a numpy array
#         return np.argmax(predictions, axis=-1)
#
# The next cell shows an example implementation of the `model.py` file, which includes loading model weights from the `weights.keras` file and conducting predictions on provided input data. The `.zip` file is created and downloaded in the last notebook cell.
#
# ❗ Feel free to modify the method implementations to better fit your specific requirements, but please ensure that the class name and method interfaces remain unchanged.

# %%
# %%writefile model.py

import numpy as np
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.
        """
        # Load the specific model file
        self.neural_network = tfk.models.load_model('ConvNeXtBase1_FTfull_91.38.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must not be one-hot
        encoded.

        This function returns class labels as integers.
        """
        # Get predictions and convert to label format
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Overwriting model.py

# %%
from datetime import datetime

filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py ConvNeXtBase1_FTfull_91.38.keras
# Out:
#   adding: model.py (deflated 52%)
#   adding: ConvNeXtBase1_FTfull_91.38.keras (deflated 6%)
